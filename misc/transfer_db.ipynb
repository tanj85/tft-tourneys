# %%
from sqlalchemy import create_engine, text
import psycopg2
import os
from hash_tournaments import hash_player_name

db_name = os.getenv("DB_NAME")
db_user = os.getenv("DB_USER")
db_password = os.getenv("DB_PASSWORD")
db_host = os.getenv("DB_HOST")
db_name_2 = "ptft"


# Create engine for the first database (db_host, where tbl_player_aliases resides)
engine_db_host = create_engine(
    f"postgresql+psycopg2://{db_user}:{db_password}@{db_host}/{db_name}"
)

# Create engine for the second database (ptft, where the player table resides)
engine_ptft = create_engine(
    f"postgresql+psycopg2://{db_user}:{db_password}@{db_host}/{db_name_2}"
)

# Start a session with the ptft database
with engine_ptft.connect() as connection_ptft:
    # Query players from the ptft database ordered by oldest entry first
    query = text('SELECT id, name, region, country, alias FROM player ORDER BY "createdAt" ASC')
    players = connection_ptft.execute(query).fetchall()

# Process each player
for player in players:
    player_id, player_name, player_region, player_country, player_alias = player
    new_hash = hash_player_name(player_name, region=player_region, country=player_country)
    print(player)
    all_names = [player_name] + (player_alias if player_alias else [])  # Include aliases
    print(all_names)

    # # Connect to the db_host database to check and update tbl_player_aliases
    with engine_db_host.begin() as connection_db_host:
        good_id = None
        for name in all_names:
            if not name:
                continue
            # Check if player or alias exists in tbl_player_aliases
            query_check = text("SELECT player_name, player_id, region, country FROM tbl_player_aliases WHERE player_name = :name")
            result = connection_db_host.execute(query_check, {"name": name}).fetchall()

            if len(result) > 1:
                detail_check = text("SELECT player_name, player_id, region, country FROM tbl_player_aliases WHERE player_name = :name AND region = :region AND country = :country ")
                result = connection_db_host.execute(detail_check, {"name": name, "region":player_region, "country":player_country}).fetchone()
            else:
                result = connection_db_host.execute(query_check, {"name": name}).fetchone()
                

            print(result)
            if result:
                alias_name, alias_id, alias_region, alias_country = result
                if alias_id:
                    good_id = alias_id


                if not alias_region or not alias_country:
                    # Update region/country if empty
                    query_update = text("""
                        UPDATE tbl_player_aliases
                        SET region = :region, country = :country
                        WHERE player_name = :name
                    """)
                    connection_db_host.execute(query_update, {
                        "region": player_region,
                        "country": player_country,
                        "name": alias_name
                    })
                elif alias_region != player_region or alias_country != player_country:
                    # Insert a new row if the region or country differ
                    query_insert = text("""
                        INSERT INTO tbl_player_aliases (player_name, player_id, region, country)
                        VALUES (:name, :player_id, :region, :country)
                    """)
                    connection_db_host.execute(query_insert, {
                        "name": name,
                        "player_id": new_hash if good_id is None or alias_region != player_region or alias_country != player_country else good_id,
                        "region": player_region,
                        "country": player_country
                    })
            else:
                # Insert new entry if the name or alias doesn't exist in tbl_player_aliases
                query_insert = text("""
                    INSERT INTO tbl_player_aliases (player_name, player_id, region, country)
                    VALUES (:name, :player_id, :region, :country)
                """)
                connection_db_host.execute(query_insert, {
                    "name": name,
                    "player_id": new_hash,
                    "region": player_region,
                    "country": player_country
                })
# Out:
# (77, 'vclf', 'BR', 'BRA', ['RED vclf', 'Yutaka Hoshino', 'Red vclf', 'did my best'])
# ['vclf', 'RED vclf', 'Yutaka Hoshino', 'Red vclf', 'did my best']
# ('vclf', 79038099, 'BR', 'BRA')
# ('RED vclf', 79038099, 'BR', 'BRA')
# ('Yutaka Hoshino', 79038099, 'BR', 'BRA')
# ('Red vclf', 79038099, 'BR', 'BRA')
# ('did my best', 79038099, 'BR', 'BRA')
# (104, 'Slooper', 'BR', 'BRA', ['INTZ Slooper'])
# ['Slooper', 'INTZ Slooper']
# ('Slooper', 95265227, 'BR', 'BRA')
# ('INTZ Slooper', 95265227, 'BR', 'BRA')
# (466, 'LilTop', 'NA', 'USA', [])
# ['LilTop']
# ('LilTop', 5072863, 'NA', 'USA')
# (376, 'KevChen', 'NA', 'USA', [])
# ['KevChen']
# ('KevChen', 18794348, 'NA', 'USA')
# (557, 'P1va', 'SEA', 'VNM', [])
# ['P1va']
# ('P1va', 93521172, 'SEA', 'VNM')
# (560, 'Qkt', 'SEA', 'TWN', [])
# ['Qkt']
# ('Qkt', 83606271, 'SEA', 'TWN')
# (380, 'Bradini', 'NA', 'USA', [])
# ['Bradini']
# ('Bradini', 57116891, 'NA', 'USA')
# (68, 'Un33d', 'EMEA', 'FRA', ['Um33d', 'AEG Un33d'])
# ['Un33d', 'Um33d', 'AEG Un33d']
# ('Un33d', 27141613, 'EMEA', 'FRA')
# ('Um33d', 27141613, 'EMEA', 'FRA')
# ('AEG Un33d', 27141613, 'EMEA', 'FRA')
# (66, 'Goose', 'NA', 'USA', ['GrandVice8'])
# ['Goose', 'GrandVice8']
# ('Goose', 61985025, 'NA', 'USA')
# ('GrandVice8', 61985025, 'NA', 'USA')
# (555, 'Nik', 'NA', 'CAN', [''])
# ['Nik', '']
# ('Nik', 69715130, 'NA', 'CAN')
# (91, 'XiLiGe', 'CN', 'CHN', ['犀利哥', '笨鸟先飞', 'BNXF'])
# ['XiLiGe', '犀利哥', '笨鸟先飞', 'BNXF']
# ('XiLiGe', 28479374, 'CN', 'CHN')
# ('犀利哥', 28479374, 'CN', 'CHN')
# ('笨鸟先飞', 28479374, 'CN', 'CHN')
# ('BNXF', 28479374, 'CN', 'CHN')
# (69, 'Math108', 'BR', 'BRA', [])
# ['Math108']
# ('Math108', 82341576, 'BR', 'BRA')
# (2154, 'Ticy', 'LA', 'CHL', [])
# ['Ticy']
# ('Ticy', 24612085, 'LA', 'CHL')
# (606, 'Lightygo', 'CN', 'CHN', ['B站丶LIGhtYgo'])
# ['Lightygo', 'B站丶LIGhtYgo']
# ('Lightygo', 67326910, 'CN', 'CHN')
# ('B站丶LIGhtYgo', 67326910, 'CN', 'CHN')
# (53, 'Escha', 'OCE', 'AUS', [''])
# ['Escha', '']
# ('Escha', 44772983, 'OCE', 'AUS')
# (111, 'Lab 004 Rain', 'NA', 'USA', ['Rainplosion', 'Lab004Rain'])
# ['Lab 004 Rain', 'Rainplosion', 'Lab004Rain']
# ('Lab 004 Rain', 43069266, 'NA', 'USA')
# ('Rainplosion', 43069266, 'NA', 'USA')
# ('Lab004Rain', 43069266, 'NA', 'USA')
# (1515, 'OLV Krovsavetik', 'LA', 'CHL', [])
# ['OLV Krovsavetik']
# ('OLV Krovsavetik', 50255682, 'LA', 'CHL')
# (1519, 'Codecsgg', 'LA', 'CHL', [])
# ['Codecsgg']
# ('Codecsgg', 54723593, 'LA', 'CHL')
# (1455, 'snuu32', 'EMEA', '!RL', [])
# ['snuu32']
# ('snuu32', 61002393, 'EMEA', '!RL')
# (590, 'Angora', 'OCE', 'NZL', [''])
# ['Angora', '']
# ('Angora', 65328297, 'OCE', 'NZL')
# (472, 'LifesBad', 'LA', 'ARG', ['EST LifesBad', 'eXp LifesBad'])
# ['LifesBad', 'EST LifesBad', 'eXp LifesBad']
# ('LifesBad', 69657505, 'LA', 'ARG')
# ('EST LifesBad', 69657505, 'LA', 'ARG')
# ('eXp LifesBad', 69657505, 'LA', 'ARG')
# (562, 'Kbaobao', 'SEA', 'HKG', ['K寶寶生氣了'])
# ['Kbaobao', 'K寶寶生氣了']
# ('Kbaobao', 59557135, 'SEA', 'HKG')
# ('K寶寶生氣了', 59557135, 'SEA', 'HKG')
# (1372, 'Keane', 'OCE', 'KOR', ['TSM enaek'])
# ['Keane', 'TSM enaek']
# ('Keane', 88078430, 'OCE', 'KOR')
# ('TSM enaek', 18771370, 'OCE', 'KOR')
# (1305, 'chunkypapa', 'EMEA', 'GBR', ['chunki916'])
# ['chunkypapa', 'chunki916']
# ('chunkypapa', 65352475, 'EMEA', 'GBR')
# ('chunki916', 65352475, 'EMEA', 'GBR')
# (29, 'Lion', 'LA', 'CRI', ['GOAT Lion'])
# ['Lion', 'GOAT Lion']
# ('Lion', 47635693, 'LA', 'CRI')
# ('GOAT Lion', 47635693, 'LA', 'CRI')
# (45, 'ZENIA', 'KR', 'KOR', ['ZENIA TFT'])
# ['ZENIA', 'ZENIA TFT']
# ('ZENIA', 45025219, 'KR', 'KOR')
# ('ZENIA TFT', 45025219, 'KR', 'KOR')
# (383, 'Elvisbeback', 'NA', 'USA', [])
# ['Elvisbeback']
# ('Elvisbeback', 21937750, 'NA', 'USA')
# (592, 'VLCLilliaPlayer', 'OCE', 'AUS', ['VLC'])
# ['VLCLilliaPlayer', 'VLC']
# ('VLCLilliaPlayer', 4947971, 'OCE', 'AUS')
# ('VLC', 4947971, 'OCE', 'AUS')
# (607, 'RiYue', 'CN', 'CHN', ['快手丶无敌日月'])
# ['RiYue', '快手丶无敌日月']
# ('RiYue', 6950755, 'CN', 'CHN')
# ('快手丶无敌日月', 6950755, 'CN', 'CHN')
# (377, 'ParisTilton', 'NA', 'USA', [])
# ['ParisTilton']
# ('ParisTilton', 69455720, 'NA', 'USA')
# (437, 'pausecham', 'NA', 'USA', [])
# ['pausecham']
# ('pausecham', 30248667, 'NA', 'USA')
# (83, 'guubums', 'NA', 'CAN', [])
# ['guubums']
# ('guubums', 85383621, 'NA', 'CAN')
# (1817, 'Xian', 'CN', 'CHN', [])
# ['Xian']
# ('Xian', 5677439, 'CN', 'CHN')
# (44, 'nukomaru', 'JP', 'JPN', ['ぬこ丸'])
# ['nukomaru', 'ぬこ丸']
# ('nukomaru', 8461955, 'JP', 'JPN')
# ('ぬこ丸', 8461955, 'JP', 'JPN')
# (2564, 'xNolskog', 'EMEA', 'POL', ['ImpetuousPanda'])
# ['xNolskog', 'ImpetuousPanda']
# ('xNolskog', 17360260, 'EMEA', 'POL')
# ('ImpetuousPanda', 17360260, 'EMEA', 'POL')
# (32, 'BC Socks', 'NA', 'USA', ['Mismatched Socks', 'MismatchedSocks'])
# ['BC Socks', 'Mismatched Socks', 'MismatchedSocks']
# ('BC Socks', 78570778, 'NA', 'USA')
# ('Mismatched Socks', 27993639, 'NA', 'USA')
# ('MismatchedSocks', 27993639, 'NA', 'USA')
# (443, 'ddann', 'NA', 'USA', [])
# ['ddann']
# ('ddann', 92405326, 'NA', 'USA')
# (452, 'marinethan', 'NA', 'USA', [])
# ['marinethan']
# ('marinethan', 18188460, 'NA', 'USA')
# (605, 'Chuqi', 'CN', 'CHN', ['初七'])
# ['Chuqi', '初七']
# ('Chuqi', 24983779, 'CN', 'CHN')
# ('初七', 24983779, 'CN', 'CHN')
# (626, 'Balmyeong', 'KR', 'KOR', ['발 명'])
# ['Balmyeong', '발 명']
# ('Balmyeong', 39534188, 'KR', 'KOR')
# ('발 명', 39534188, 'KR', 'KOR')
# (475, 'YGQF', 'CN', 'CHN', [])
# ['YGQF']
# ('YGQF', 75523770, 'CN', 'CHN')
# (99, 'Alphago', 'CN', 'CHN', [])
# ['Alphago']
# ('Alphago', 93400693, 'CN', 'CHN')
# (604, 'Shendu', 'CN', 'CHN', [])
# ['Shendu']
# ('Shendu', 66275291, 'CN', 'CHN')
# (105, 'Calcifer', 'LA', 'COL', [])
# ['Calcifer']
# ('Calcifer', 95370463, 'LA', 'COL')
# (90, 'Voltariux', 'EMEA', 'FRA', ['SLY Voltariux'])
# ['Voltariux', 'SLY Voltariux']
# ('Voltariux', 26414012, 'EMEA', 'FRA')
# ('SLY Voltariux', 26414012, 'EMEA', 'FRA')
# (609, '60second', 'CN', 'CHN', [])
# ['60second']
# ('60second', 99201566, 'CN', 'CHN')
# (489, 'jeddimindtricks', 'NA', 'USA', [])
# ['jeddimindtricks']
# ('jeddimindtricks', 5145663, 'NA', 'USA')
# (563, 'Kratos', 'SEA', 'VNM', [])
# ['Kratos']
# ('Kratos', 89539850, 'SEA', 'VNM')
# (565, '16 Minari', 'SEA', 'VNM', [])
# ['16 Minari']
# ('16 Minari', 61539086, 'SEA', 'VNM')
# (567, 'SBTC Kit', 'SEA', 'VNM', [])
# ['SBTC Kit']
# ('SBTC Kit', 84527314, 'SEA', 'VNM')
# (569, 'SVM DVQ', 'SEA', 'VNM', [])
# ['SVM DVQ']
# ('SVM DVQ', 21904283, 'SEA', 'VNM')
# (572, 'steppy', 'SEA', 'SGP', [])
# ['steppy']
# ('steppy', 88293032, 'SEA', 'SGP')
# (570, 'GD Dau Dau', 'SEA', 'VNM', [])
# ['GD Dau Dau']
# ('GD Dau Dau', 78021587, 'SEA', 'VNM')
# (574, 'VN VuEriksen', 'SEA', 'VNM', [])
# ['VN VuEriksen']
# ('VN VuEriksen', 99363799, 'SEA', 'VNM')
# (575, 'Vermillion', 'SEA', 'VNM', [])
# ['Vermillion']
# ('Vermillion', 83477314, 'SEA', 'VNM')
# (830, 'papercheeze', 'NA', 'USA', [])
# ['papercheeze']
# ('papercheeze', 39896118, 'NA', 'USA')
# (833, 'DrownedGod', 'NA', 'USA', [])
# ['DrownedGod']
# ('DrownedGod', 76076161, 'NA', 'USA')
# (836, 'ItsChandlerGG', 'NA', 'USA', [])
# ['ItsChandlerGG']
# ('ItsChandlerGG', 15955270, 'NA', 'USA')
# (838, 'Highrule', 'NA', 'USA', [])
# ['Highrule']
# ('Highrule', 59437333, 'NA', 'USA')
# (79, 'Title', 'JP', 'JPN', [])
# ['Title']
# ('Title', 3177587, 'JP', 'JPN')
# (856, 'Craz', 'NA', 'USA', [])
# ['Craz']
# ('Craz', 64174137, 'NA', 'USA')
# (381, 'Maki Roll', 'NA', 'USA', [])
# ['Maki Roll']
# ('Maki Roll', 59903627, 'NA', 'USA')
# (692, 'ShanHe', 'CN', 'CHN', [])
# ['ShanHe']
# ('ShanHe', 34038905, 'CN', 'CHN')
# (87, 'apa09Neo', 'JP', 'JPN', [])
# ['apa09Neo']
# ('apa09Neo', 38869260, 'JP', 'JPN')
# (559, 'OzinX', 'SEA', 'VNM', ['VN OzinX'])
# ['OzinX', 'VN OzinX']
# ('OzinX', 57552105, 'SEA', 'VNM')
# ('VN OzinX', 57552105, 'SEA', 'VNM')
# (589, 'Huge Hinge Hunk', 'OCE', 'AUS', [])
# ['Huge Hinge Hunk']
# ('Huge Hinge Hunk', 10376585, 'OCE', 'AUS')
# (28, 'PieHat', 'LA', 'PER', [])
# ['PieHat']
# ('PieHat', 23550821, 'LA', 'PER')
# (591, 'Kahdei', 'OCE', 'AUS', [])
# ['Kahdei']
# ('Kahdei', 36140255, 'OCE', 'AUS')
# (593, 'DayumSayum', 'OCE', 'AUS', [])
# ['DayumSayum']
# ('DayumSayum', 26583406, 'OCE', 'AUS')
# (594, 'Skillfullism', 'OCE', 'AUS', [])
# ['Skillfullism']
# ('Skillfullism', 18248891, 'OCE', 'AUS')
# (595, 'Reuniclus', 'OCE', 'AUS', [])
# ['Reuniclus']
# ('Reuniclus', 3883423, 'OCE', 'AUS')
# (597, 'Maxibon bloke', 'OCE', 'AUS', [])
# ['Maxibon bloke']
# ('Maxibon bloke', 54563905, 'OCE', 'AUS')
# (588, 'Perfect Slumbers', 'OCE', 'AUS', [])
# ['Perfect Slumbers']
# ('Perfect Slumbers', 57642314, 'OCE', 'AUS')
# (598, 'ch33sychan', 'OCE', 'AUS', [])
# ['ch33sychan']
# ('ch33sychan', 51769961, 'OCE', 'AUS')
# (599, 'calze6', 'OCE', 'AUS', [])
# ['calze6']
# ('calze6', 55432741, 'OCE', 'AUS')
# (601, 'RONSWANSON', 'OCE', 'AUS', [])
# ['RONSWANSON']
# ('RONSWANSON', 98037918, 'OCE', 'AUS')
# (26, '8lJaywalking', 'KR', 'KOR', [])
# ['8lJaywalking']
# ('8lJaywalking', 4756319, 'KR', 'KOR')
# (34, 'Razza', 'OCE', 'AUS', [])
# ['Razza']
# ('Razza', 90925938, 'OCE', 'AUS')
# (27, 'Thunder', 'KR', 'KOR', [])
# ['Thunder']
# ('Thunder', 85889338, 'KR', 'KOR')
# (88, 'Knpngrz', 'OCE', 'AUS', [])
# ['Knpngrz']
# ('Knpngrz', 43173974, 'OCE', 'AUS')
# (96, 'TXE', 'OCE', 'AUS', [])
# ['TXE']
# ('TXE', 91757845, 'OCE', 'AUS')
# (46, 'Woozzul', 'KR', 'KOR', [])
# ['Woozzul']
# ('Woozzul', 777189, 'KR', 'KOR')
# (109, 'Adastra', 'EMEA', 'TUR', [])
# ['Adastra']
# ('Adastra', 6181837, 'EMEA', 'TUR')
# (67, 'bullbo', 'KR', 'KOR', [])
# ['bullbo']
# ('bullbo', 5929915, 'KR', 'KOR')
# (71, 'agotaboy', 'KR', 'KOR', [])
# ['agotaboy']
# ('agotaboy', 10841190, 'KR', 'KOR')
# (202, 'Garchompro', 'NA', 'USA', [])
# ['Garchompro']
# ('Garchompro', 81700863, 'NA', 'USA')
# (603, 'ZhanWenYu', 'CN', 'CHN', [])
# ['ZhanWenYu']
# ('ZhanWenYu', 43306242, 'CN', 'CHN')
# (608, 'Flancy', 'CN', 'CHN', [])
# ['Flancy']
# ('Flancy', 90827234, 'CN', 'CHN')
# (610, 'ShiziAK', 'CN', 'CHN', [])
# ['ShiziAK']
# ('ShiziAK', 29678006, 'CN', 'CHN')
# (611, 'XiaoY', 'CN', 'CHN', [])
# ['XiaoY']
# ('XiaoY', 61507660, 'CN', 'CHN')
# (602, 'FLY', 'CN', 'CHN', [])
# ['FLY']
# ('FLY', 32432933, 'CN', 'CHN')
# (613, 'Sea', 'CN', 'CHN', [])
# ['Sea']
# ('Sea', 85718905, 'CN', 'CHN')
# (614, 'SNU Challenger', 'KR', 'KOR', [])
# ['SNU Challenger']
# ('SNU Challenger', 76849869, 'KR', 'KOR')
# (624, '공훈', 'KR', 'KOR', [])
# ['공훈']
# ('공훈', 56409893, 'KR', 'KOR')
# (625, '재라', 'KR', 'KOR', [])
# ['재라']
# ('재라', 77004398, 'KR', 'KOR')
# (627, 'Kanata', 'KR', 'KOR', [])
# ['Kanata']
# ('Kanata', 46697798, 'KR', 'KOR')
# (2246, 'Oli', 'LA', 'MEX', [])
# ['Oli']
# ('Oli', 9714447, 'LA', 'MEX')
# (159, 'Clear', 'NA', 'CAN', [])
# ['Clear']
# ('Clear', 6752099, 'NA', 'CAN')
# (467, 'Xnieamo', 'NA', 'USA', [])
# ['Xnieamo']
# ('Xnieamo', 63345361, 'NA', 'USA')
# (31, 'Liquid Kurumx', 'NA', 'USA', ['Kurumx'])
# ['Liquid Kurumx', 'Kurumx']
# ('Liquid Kurumx', 50305755, 'NA', 'USA')
# ('Kurumx', 53265302, 'NA', 'USA')
# (468, 'TheXienator', 'NA', 'USA', [])
# ['TheXienator']
# ('TheXienator', 19851033, 'NA', 'USA')
# (117, 'Ramblinnn', 'NA', 'USA', [])
# ['Ramblinnn']
# ('Ramblinnn', 86116047, 'NA', 'USA')
# (469, 'VOIDS1N', 'NA', 'USA', [])
# ['VOIDS1N']
# ('VOIDS1N', 38376523, 'NA', 'USA')
# (36, 'eusouolucas', 'BR', 'BRA', ['Eusouolucas'])
# ['eusouolucas', 'Eusouolucas']
# ('eusouolucas', 31449829, 'BR', 'BRA')
# ('Eusouolucas', 31449829, 'BR', 'BRA')
# (423, 'aer0', 'NA', 'USA', [])
# ['aer0']
# ('aer0', 38890108, 'NA', 'USA')
# (695, 'Shiquz', 'CN', 'CHN', ['斗鱼逝去z'])
# ['Shiquz', '斗鱼逝去z']
# ('Shiquz', 47914772, 'CN', 'CHN')
# ('斗鱼逝去z', 47914772, 'CN', 'CHN')
# (389, 'Esportslaw', 'NA', 'USA', ['esport slaw'])
# ['Esportslaw', 'esport slaw']
# ('Esportslaw', 52364630, 'NA', 'USA')
# ('esport slaw', 52364630, 'NA', 'USA')
# (49, 'El Tomo', 'LA', 'ARG', ['GpB El Tomo'])
# ['El Tomo', 'GpB El Tomo']
# ('El Tomo', 48745257, 'LA', 'ARG')
# ('GpB El Tomo', 48745257, 'LA', 'ARG')
# (255, 'Thrae', 'EMEA', 'CZE', ['G2 Thrae'])
# ['Thrae', 'G2 Thrae']
# ('Thrae', 17648154, 'EMEA', 'CZE')
# ('G2 Thrae', 17648154, 'EMEA', 'CZE')
# (3341, 'Xendra', 'OCE', 'AUS', [])
# ['Xendra']
# ('Xendra', 44132481, 'OCE', 'AUS')
# (3343, 'rikuu', 'OCE', 'AUS', [])
# ['rikuu']
# ('rikuu', 28956099, 'OCE', 'AUS')
# (615, 'Incheonfist', 'KR', 'KOR', ['존잘인천피스트'])
# ['Incheonfist', '존잘인천피스트']
# ('Incheonfist', 61088643, 'KR', 'KOR')
# ('존잘인천피스트', 61088643, 'KR', 'KOR')
# (691, 'BaiLong', 'CN', 'CHN', ['WhiteDragon'])
# ['BaiLong', 'WhiteDragon']
# ('BaiLong', 60764299, 'CN', 'CHN')
# ('WhiteDragon', 28482981, 'CN', 'CHN')
# (4373, 'ilo ilo', 'NA', 'USA', [])
# ['ilo ilo']
# ('ilo ilo', 90877559, 'NA', 'USA')
# (4382, 'GameBoy CoIor', 'NA', 'USA', [])
# ['GameBoy CoIor']
# ('GameBoy CoIor', 92653231, 'NA', 'USA')
# (4392, 'Tonality', 'NA', 'USA', [])
# ['Tonality']
# ('Tonality', 15840549, 'NA', 'USA')
# (4407, 'kaÏ', 'NA', 'USA', [])
# ['kaÏ']
# ('kaÏ', 98713004, 'NA', 'USA')
# (4416, 'DANQSTA', 'NA', 'USA', [])
# ['DANQSTA']
# ('DANQSTA', 66221134, 'NA', 'USA')
# (3619, 'ajoe1231', 'SEA', '!EA', ['ajoe1232'])
# ['ajoe1231', 'ajoe1232']
# ('ajoe1231', 50372812, 'SEA', '!EA')
# ('ajoe1232', 50372812, 'SEA', '!EA')
# (4790, 'White Arie', 'EMEA', 'FRA', ['WhiteArie'])
# ['White Arie', 'WhiteArie']
# ('White Arie', 72546139, 'EMEA', 'FRA')
# ('WhiteArie', 72546139, 'EMEA', 'FRA')
# (3554, 'oh95', 'LA', 'ARG', [])
# ['oh95']
# ('oh95', 87275550, 'LA', 'ARG')
# (3555, 'RedMay', 'LA', 'ARG', [])
# ['RedMay']
# ('RedMay', 42956847, 'LA', 'ARG')
# (3556, 'AGK Floricienta', 'LA', 'ARG', [])
# ['AGK Floricienta']
# ('AGK Floricienta', 99327426, 'LA', 'ARG')
# (3557, 'Milanesoideh', 'LA', 'ARG', [])
# ['Milanesoideh']
# ('Milanesoideh', 48584250, 'LA', 'ARG')
# (3559, 'Fifiii', 'LA', 'PER', [])
# ['Fifiii']
# ('Fifiii', 5184886, 'LA', 'PER')
# (3560, 'SENTAO ÐE PANA', 'LA', 'CHL', [])
# ['SENTAO ÐE PANA']
# ('SENTAO ÐE PANA', 18998209, 'LA', 'CHL')
# (3561, 'Pop Star Pachonc', 'LA', 'ARG', [])
# ['Pop Star Pachonc']
# ('Pop Star Pachonc', 90850466, 'LA', 'ARG')
# (78, 'Megumim', 'LA', 'PER', ['GLG Megu', 'Pphshy', 'SímpDeMegumin'])
# ['Megumim', 'GLG Megu', 'Pphshy', 'SímpDeMegumin']
# ('Megumim', 22965606, 'LA', 'PER')
# ('GLG Megu', 22965606, 'LA', 'PER')
# ('Pphshy', 22965606, 'LA', 'PER')
# ('SímpDeMegumin', 22965606, 'LA', 'PER')
# (3367, 'Yummy Chidon', 'KR', 'KOR', ['양치돈 맛있다'])
# ['Yummy Chidon', '양치돈 맛있다']
# ('Yummy Chidon', 54305881, 'KR', 'KOR')
# ('양치돈 맛있다', 54305881, 'KR', 'KOR')
# (3587, 'Shirazu', 'BR', 'BRA', [''])
# ['Shirazu', '']
# ('Shirazu', 45267557, 'BR', 'BRA')
# (3306, 'Bean Stalking', 'OCE', 'AUS', ['BeanStalking'])
# ['Bean Stalking', 'BeanStalking']
# ('Bean Stalking', 31602247, 'OCE', 'AUS')
# ('BeanStalking', 71880193, 'OCE', 'AUS')
# (3588, 'bru the king', 'BR', 'BRA', [''])
# ['bru the king', '']
# ('bru the king', 18563377, 'BR', 'BRA')
# (858, 'GNG Black Ese', 'LA', 'ARG', ['Black Ese'])
# ['GNG Black Ese', 'Black Ese']
# ('GNG Black Ese', 73873129, 'LA', 'ARG')
# ('Black Ese', 73873129, 'LA', 'ARG')
# (5773, 'NG Negan2k6', 'SEA', 'VNM', [])
# ['NG Negan2k6']
# ('NG Negan2k6', 97627237, 'SEA', 'VNM')
# (3744, '远去万里山河', 'CN', 'CHN', ['山河远去万里'])
# ['远去万里山河', '山河远去万里']
# ('远去万里山河', 63757341, 'CN', 'CHN')
# ('山河远去万里', 63757341, 'CN', 'CHN')
# (3753, '虎牙丶小摆子z', 'CN', 'CHN', ['小摆子z', '虎牙丶小摆子z'])
# ['虎牙丶小摆子z', '小摆子z', '虎牙丶小摆子z']
# ('虎牙丶小摆子z', 6882645, 'CN', 'CHN')
# ('小摆子z', 6882645, 'CN', 'CHN')
# ('虎牙丶小摆子z', 6882645, 'CN', 'CHN')
# (3608, 'Calcifer A60', 'LA', 'MEX', ['GLG Calci A60', 'GLG Calcifer A60'])
# ['Calcifer A60', 'GLG Calci A60', 'GLG Calcifer A60']
# ('Calcifer A60', 63759390, 'LA', 'MEX')
# ('GLG Calci A60', 63759390, 'LA', 'MEX')
# ('GLG Calcifer A60', 63759390, 'LA', 'MEX')
# (3601, 'Venomancer', 'LA', 'ECU', [])
# ['Venomancer']
# ('Venomancer', 64893936, 'LA', 'ECU')
# (3602, 'Kemok', 'LA', 'COL', [])
# ['Kemok']
# ('Kemok', 29555472, 'LA', 'COL')
# (3604, 'Ziw', 'LA', 'MEX', [])
# ['Ziw']
# ('Ziw', 47767738, 'LA', 'MEX')
# (3605, 'RSK Zacman', 'LA', 'MEX', [])
# ['RSK Zacman']
# ('RSK Zacman', 76581318, 'LA', 'MEX')
# (3606, 'MisterSkills', 'LA', 'MEX', [])
# ['MisterSkills']
# ('MisterSkills', 32061277, 'LA', 'MEX')
# (3607, 'Corundum', 'LA', 'NIC', [])
# ['Corundum']
# ('Corundum', 98541576, 'LA', 'NIC')
# (3625, '小娜啊', 'SEA', '!EA', [])
# ['小娜啊']
# ('小娜啊', 6100222, 'SEA', '!EA')
# (3636, '大型貓咪', 'SEA', '!EA', [])
# ['大型貓咪']
# ('大型貓咪', 72010126, 'SEA', '!EA')
# (3610, '當我拔出兩盞路燈', 'SEA', '!EA', [])
# ['當我拔出兩盞路燈']
# ('當我拔出兩盞路燈', 38082660, 'SEA', '!EA')
# (3616, '鈴木愛理可愛desu', 'SEA', '!EA', [])
# ['鈴木愛理可愛desu']
# ('鈴木愛理可愛desu', 9354568, 'SEA', '!EA')
# (3734, 'bipolarOrderCAO', 'CN', 'CHN', [])
# ['bipolarOrderCAO']
# ('bipolarOrderCAO', 55150533, 'CN', 'CHN')
# (3736, '灬惟一灬', 'CN', 'CHN', [])
# ['灬惟一灬']
# ('灬惟一灬', 81496166, 'CN', 'CHN')
# (3737, '对不对', 'CN', 'CHN', [])
# ['对不对']
# ('对不对', 98007666, 'CN', 'CHN')
# (3738, '好多宝', 'CN', 'CHN', [])
# ['好多宝']
# ('好多宝', 35621081, 'CN', 'CHN')
# (3739, '千文kwords', 'CN', 'CHN', [])
# ['千文kwords']
# ('千文kwords', 61936893, 'CN', 'CHN')
# (3740, 'winstonhu', 'CN', 'CHN', [])
# ['winstonhu']
# ('winstonhu', 3993844, 'CN', 'CHN')
# (3741, '静水监狱犯人9527', 'CN', 'CHN', [])
# ['静水监狱犯人9527']
# ('静水监狱犯人9527', 45801103, 'CN', 'CHN')
# (3743, '淘气美希', 'CN', 'CHN', [])
# ['淘气美希']
# ('淘气美希', 91803478, 'CN', 'CHN')
# (3745, '66岁老头在线', 'CN', 'CHN', [])
# ['66岁老头在线']
# ('66岁老头在线', 51489417, 'CN', 'CHN')
# (3747, '我寄世间雪满头', 'CN', 'CHN', [])
# ['我寄世间雪满头']
# ('我寄世间雪满头', 3007777, 'CN', 'CHN')
# (3748, '旺旺集团总经理', 'CN', 'CHN', [])
# ['旺旺集团总经理']
# ('旺旺集团总经理', 81262323, 'CN', 'CHN')
# (3749, '多包容少摆烂', 'CN', 'CHN', [])
# ['多包容少摆烂']
# ('多包容少摆烂', 16845673, 'CN', 'CHN')
# (3750, 'unkillable7', 'CN', 'CHN', [])
# ['unkillable7']
# ('unkillable7', 74477171, 'CN', 'CHN')
# (3751, 'YYD', 'CN', 'CHN', [])
# ['YYD']
# ('YYD', 50666132, 'CN', 'CHN')
# (3752, '风中的灵感', 'CN', 'CHN', [])
# ['风中的灵感']
# ('风中的灵感', 45696066, 'CN', 'CHN')
# (3754, '榆桑非晚丶', 'CN', 'CHN', [])
# ['榆桑非晚丶']
# ('榆桑非晚丶', 46649443, 'CN', 'CHN')
# (3756, '血龙43', 'CN', 'CHN', [])
# ['血龙43']
# ('血龙43', 29894592, 'CN', 'CHN')
# (3757, 'XiaoGangPao', 'CN', 'CHN', [])
# ['XiaoGangPao']
# ('XiaoGangPao', 5464523, 'CN', 'CHN')
# (3755, '派大星单杀章鱼哥', 'CN', 'CHN', [])
# ['派大星单杀章鱼哥']
# ('派大星单杀章鱼哥', 79448320, 'CN', 'CHN')
# (3758, '江流之主塔姆', 'CN', 'CHN', [])
# ['江流之主塔姆']
# ('江流之主塔姆', 85660335, 'CN', 'CHN')
# (3759, 'XiguaSweet', 'CN', 'CHN', [])
# ['XiguaSweet']
# ('XiguaSweet', 22762649, 'CN', 'CHN')
# (3760, '虎牙AG丶林非鹿', 'CN', 'CHN', [])
# ['虎牙AG丶林非鹿']
# ('虎牙AG丶林非鹿', 12580935, 'CN', 'CHN')
# (3762, 'Kizooo', 'CN', 'CHN', [])
# ['Kizooo']
# ('Kizooo', 48857618, 'CN', 'CHN')
# (3763, 'Archae', 'CN', 'CHN', [])
# ['Archae']
# ('Archae', 42819892, 'CN', 'CHN')
# (3764, '爱下棋、小屁桃', 'CN', 'CHN', [])
# ['爱下棋、小屁桃']
# ('爱下棋、小屁桃', 80769222, 'CN', 'CHN')
# (3766, 'LOVE、rainydays', 'CN', 'CHN', [])
# ['LOVE、rainydays']
# ('LOVE、rainydays', 48766138, 'CN', 'CHN')
# (3767, '无色灬夜', 'CN', 'CHN', [])
# ['无色灬夜']
# ('无色灬夜', 82735472, 'CN', 'CHN')
# (3761, '无名之辈三寻', 'CN', 'CHN', [])
# ['无名之辈三寻']
# ('无名之辈三寻', 56517656, 'CN', 'CHN')
# (3765, 'Healer、宇', 'CN', 'CHN', [])
# ['Healer、宇']
# ('Healer、宇', 83166423, 'CN', 'CHN')
# (3768, '武汉科技大学棋圣', 'CN', 'CHN', [])
# ['武汉科技大学棋圣']
# ('武汉科技大学棋圣', 84016058, 'CN', 'CHN')
# (3769, '虎牙、关小海', 'CN', 'CHN', [])
# ['虎牙、关小海']
# ('虎牙、关小海', 65005061, 'CN', 'CHN')
# (3811, 'Yoonjung Goooooo', 'SEA', 'VNM', [])
# ['Yoonjung Goooooo']
# ('Yoonjung Goooooo', 61532017, 'SEA', 'VNM')
# (2722, 'nice ok we lost', 'EMEA', 'GBR', [])
# ['nice ok we lost']
# ('nice ok we lost', 5536959, 'EMEA', 'GBR')
# (2772, 'NBA Nebra', 'EMEA', 'BEL', [])
# ['NBA Nebra']
# ('NBA Nebra', 23451726, 'EMEA', 'BEL')
# (2781, 'Aexoq', 'EMEA', 'DEU', [])
# ['Aexoq']
# ('Aexoq', 51442128, 'EMEA', 'DEU')
# (2845, 'mysiacik', 'EMEA', 'SVK', [])
# ['mysiacik']
# ('mysiacik', 17144523, 'EMEA', 'SVK')
# (2868, 'Hi im Tal', 'EMEA', 'LTU', [])
# ['Hi im Tal']
# ('Hi im Tal', 41534132, 'EMEA', 'LTU')
# (2883, 'wsh frr', 'EMEA', 'FRA', [])
# ['wsh frr']
# ('wsh frr', 28973840, 'EMEA', 'FRA')
# (2933, 'TatoWins', 'BR', 'BRA', [])
# ['TatoWins']
# ('TatoWins', 25144008, 'BR', 'BRA')
# (2942, 'Mantega x', 'BR', 'BRA', [])
# ['Mantega x']
# ('Mantega x', 13546158, 'BR', 'BRA')
# (2947, 'Billyn Nelson', 'BR', 'BRA', [])
# ['Billyn Nelson']
# ('Billyn Nelson', 62924137, 'BR', 'BRA')
# (2957, 'frey', 'BR', 'BRA', [])
# ['frey']
# ('frey', 80384547, 'BR', 'BRA')
# (3011, 'Grokuu', 'NA', 'USA', [])
# ['Grokuu']
# ('Grokuu', 98998634, 'NA', 'USA')
# (3013, 'Billy', 'NA', 'USA', [])
# ['Billy']
# ('Billy', 52414646, 'NA', 'USA')
# (3054, 'Weezlebub', 'OCE', 'AUS', [])
# ['Weezlebub']
# ('Weezlebub', 85023780, 'OCE', 'AUS')
# (3160, 'Söarer', 'OCE', 'AUS', [])
# ['Söarer']
# ('Söarer', 77098102, 'OCE', 'AUS')
# (3207, 'CucksRyou', 'OCE', 'AUS', [])
# ['CucksRyou']
# ('CucksRyou', 63803725, 'OCE', 'AUS')
# (3289, 'SvG Olbap', 'OCE', 'AUS', [])
# ['SvG Olbap']
# ('SvG Olbap', 87870294, 'OCE', 'AUS')
# (3312, 'bablyonberlin', 'OCE', 'AUS', [])
# ['bablyonberlin']
# ('bablyonberlin', 94335516, 'OCE', 'AUS')
# (3329, 'Renatus', 'OCE', 'AUS', [])
# ['Renatus']
# ('Renatus', 98900005, 'OCE', 'AUS')
# (3332, 'Kuuu', 'OCE', 'AUS', [])
# ['Kuuu']
# ('Kuuu', 30850839, 'OCE', 'AUS')
# (4374, 'Roundfaced', 'NA', 'USA', [])
# ['Roundfaced']
# ('Roundfaced', 87670187, 'NA', 'USA')
# (4383, 'DarthMandalore', 'NA', 'USA', [])
# ['DarthMandalore']
# ('DarthMandalore', 37685383, 'NA', 'USA')
# (4393, 'yoman5', 'NA', 'USA', [])
# ['yoman5']
# ('yoman5', 31020447, 'NA', 'USA')
# (4405, 'LivesInBox', 'NA', 'USA', [])
# ['LivesInBox']
# ('LivesInBox', 15283896, 'NA', 'USA')
# (4417, 'ValorantSova', 'NA', 'USA', [])
# ['ValorantSova']
# ('ValorantSova', 7264168, 'NA', 'USA')
# (1370, 'Scarra', 'NA', 'USA', ['DSG scarra'])
# ['Scarra', 'DSG scarra']
# ('Scarra', 51757506, 'NA', 'USA')
# ('DSG scarra', 51757506, 'NA', 'USA')
# (3368, 'Cassigod', 'KR', 'KOR', ['카시갓'])
# ['Cassigod', '카시갓']
# ('Cassigod', 16785518, 'KR', 'KOR')
# ('카시갓', 16785518, 'KR', 'KOR')
# (5227, 'TwoZeroNine', 'LA', 'ARG', [''])
# ['TwoZeroNine', '']
# ('TwoZeroNine', 17788436, 'LA', 'ARG')
# (3512, '응애 나 애기보리', 'KR', 'KOR', ['보리픔픔'])
# ['응애 나 애기보리', '보리픔픔']
# ('응애 나 애기보리', 22733115, 'KR', 'KOR')
# ('보리픔픔', 22733115, 'KR', 'KOR')
# (668, 'K6 Seasons', 'LA', 'JAM', ['INP Seasøns', 'K6 Seasøns', 'Seasøns'])
# ['K6 Seasons', 'INP Seasøns', 'K6 Seasøns', 'Seasøns']
# ('K6 Seasons', 60468711, 'LA', 'JAM')
# ('INP Seasøns', 60468711, 'LA', 'JAM')
# ('K6 Seasøns', 60468711, 'LA', 'JAM')
# ('Seasøns', 60468711, 'LA', 'JAM')
# (4791, 'ACE San Gofab', 'EMEA', 'FRA', ['SanGofab', 'NES San Gofab'])
# ['ACE San Gofab', 'SanGofab', 'NES San Gofab']
# ('ACE San Gofab', 61505582, 'EMEA', 'FRA')
# ('SanGofab', 61505582, 'EMEA', 'FRA')
# ('NES San Gofab', 61505582, 'EMEA', 'FRA')
# (3532, 'KoreaHealthClub', 'KR', 'KOR', ['고려헬스클럽'])
# ['KoreaHealthClub', '고려헬스클럽']
# ('KoreaHealthClub', 23734082, 'KR', 'KOR')
# ('고려헬스클럽', 23734082, 'KR', 'KOR')
# (3484, '블랙펭수', 'KR', 'KOR', ['블랙펭수1'])
# ['블랙펭수', '블랙펭수1']
# ('블랙펭수', 80980038, 'KR', 'KOR')
# ('블랙펭수1', 80980038, 'KR', 'KOR')
# (3534, 'AFTV 빈그레', 'KR', 'KOR', ['머리가 텅 빈그레'])
# ['AFTV 빈그레', '머리가 텅 빈그레']
# ('AFTV 빈그레', 33579572, 'KR', 'KOR')
# ('머리가 텅 빈그레', 33579572, 'KR', 'KOR')
# (568, 'HNZ Midfeed', 'SEA', 'VNM', ['HNZ MIDFEED', 'HNZ MIDFEEDD', 'MidFeed'])
# ['HNZ Midfeed', 'HNZ MIDFEED', 'HNZ MIDFEEDD', 'MidFeed']
# ('HNZ Midfeed', 11475937, 'SEA', 'VNM')
# ('HNZ MIDFEED', 11475937, 'SEA', 'VNM')
# ('HNZ MIDFEEDD', 11475937, 'SEA', 'VNM')
# ('MidFeed', 11475937, 'SEA', 'VNM')
# (702, 'techzz', 'BR', 'BRA', ['FOUR Techzz', 'zzhcet', 'zzhcet lnz', 'zzhcet fy'])
# ['techzz', 'FOUR Techzz', 'zzhcet', 'zzhcet lnz', 'zzhcet fy']
# ('techzz', 82287402, 'BR', 'BRA')
# ('FOUR Techzz', 82287402, 'BR', 'BRA')
# ('zzhcet', 29049226, 'BR', 'BRA')
# ('zzhcet lnz', 29049226, 'BR', 'BRA')
# ('zzhcet fy', 29049226, 'BR', 'BRA')
# (3304, 'poutyrin', 'OCE', 'AUS', ['rin'])
# ['poutyrin', 'rin']
# ('poutyrin', 48559008, 'OCE', 'AUS')
# ('rin', 11314262, 'OCE', 'AUS')
# (3483, '덕소나몽이', 'KR', 'KOR', [])
# ['덕소나몽이']
# ('덕소나몽이', 71709528, 'KR', 'KOR')
# (3486, 'hansfam', 'KR', 'KOR', [])
# ['hansfam']
# ('hansfam', 75592558, 'KR', 'KOR')
# (3488, '안지지', 'KR', 'KOR', [])
# ['안지지']
# ('안지지', 83315880, 'KR', 'KOR')
# (3491, 'JapanTFTpro', 'KR', 'KOR', [])
# ['JapanTFTpro']
# ('JapanTFTpro', 10261103, 'KR', 'KOR')
# (3487, 'A블랙', 'KR', 'KOR', [])
# ['A블랙']
# ('A블랙', 55796440, 'KR', 'KOR')
# (3492, '강지비30', 'KR', 'KOR', [])
# ['강지비30']
# ('강지비30', 71983681, 'KR', 'KOR')
# (3494, '인생유일', 'KR', 'KOR', [])
# ['인생유일']
# ('인생유일', 41308752, 'KR', 'KOR')
# (3495, 'AFTV승진스나', 'KR', 'KOR', [])
# ['AFTV승진스나']
# ('AFTV승진스나', 80476964, 'KR', 'KOR')
# (3493, 'TFTTV', 'KR', 'KOR', [])
# ['TFTTV']
# ('TFTTV', 66928762, 'KR', 'KOR')
# (3497, '환준몬', 'KR', 'KOR', [])
# ['환준몬']
# ('환준몬', 78185576, 'KR', 'KOR')
# (3498, '유즈리하 유에나', 'KR', 'KOR', [])
# ['유즈리하 유에나']
# ('유즈리하 유에나', 11543276, 'KR', 'KOR')
# (3499, 'dh cnj우쭐리우중', 'KR', 'KOR', [])
# ['dh cnj우쭐리우중']
# ('dh cnj우쭐리우중', 46326218, 'KR', 'KOR')
# (3500, '영원0원하자', 'KR', 'KOR', [])
# ['영원0원하자']
# ('영원0원하자', 53332753, 'KR', 'KOR')
# (3501, '깜동깜동깜동', 'KR', 'KOR', [])
# ['깜동깜동깜동']
# ('깜동깜동깜동', 61465845, 'KR', 'KOR')
# (3502, '따끈2', 'KR', 'KOR', [])
# ['따끈2']
# ('따끈2', 4426092, 'KR', 'KOR')
# (3503, 'EDG chichi', 'KR', 'KOR', [])
# ['EDG chichi']
# ('EDG chichi', 76703490, 'KR', 'KOR')
# (3504, '채수채수밭', 'KR', 'KOR', [])
# ['채수채수밭']
# ('채수채수밭', 15724474, 'KR', 'KOR')
# (3505, 'AFTV밍둘레', 'KR', 'KOR', [])
# ['AFTV밍둘레']
# ('AFTV밍둘레', 85168234, 'KR', 'KOR')
# (3506, '빼꼼0I', 'KR', 'KOR', [])
# ['빼꼼0I']
# ('빼꼼0I', 94442152, 'KR', 'KOR')
# (3508, 'afreeca재의', 'KR', 'KOR', [])
# ['afreeca재의']
# ('afreeca재의', 96587494, 'KR', 'KOR')
# (3509, '원라쿠', 'KR', 'KOR', [])
# ['원라쿠']
# ('원라쿠', 4591166, 'KR', 'KOR')
# (3510, '대깨라프', 'KR', 'KOR', [])
# ['대깨라프']
# ('대깨라프', 5598719, 'KR', 'KOR')
# (3511, 'MOSO', 'KR', 'KOR', [])
# ['MOSO']
# ('MOSO', 7567775, 'KR', 'KOR')
# (3507, 'duni', 'KR', 'KOR', [])
# ['duni']
# ('duni', 19445915, 'KR', 'KOR')
# (3513, 'flancy', 'KR', 'KOR', [])
# ['flancy']
# ('flancy', 40279154, 'KR', 'KOR')
# (3514, '뽀뇨뽀뇨', 'KR', 'KOR', [])
# ['뽀뇨뽀뇨']
# ('뽀뇨뽀뇨', 52693830, 'KR', 'KOR')
# (3515, 'Afreecatv 900607', 'KR', 'KOR', [])
# ['Afreecatv 900607']
# ('Afreecatv 900607', 54881627, 'KR', 'KOR')
# (3516, '채소연TV', 'KR', 'KOR', [])
# ['채소연TV']
# ('채소연TV', 89263189, 'KR', 'KOR')
# (3517, '울보거스', 'KR', 'KOR', [])
# ['울보거스']
# ('울보거스', 68806370, 'KR', 'KOR')
# (3519, '장봄준 fan', 'KR', 'KOR', [])
# ['장봄준 fan']
# ('장봄준 fan', 68403191, 'KR', 'KOR')
# (3520, '유튜브백기사구독', 'KR', 'KOR', [])
# ['유튜브백기사구독']
# ('유튜브백기사구독', 92310164, 'KR', 'KOR')
# (3521, '엠성구', 'KR', 'KOR', [])
# ['엠성구']
# ('엠성구', 63691657, 'KR', 'KOR')
# (3523, '순득쨩', 'KR', 'KOR', [])
# ['순득쨩']
# ('순득쨩', 5425731, 'KR', 'KOR')
# (3524, 'AFTV매형깐부', 'KR', 'KOR', [])
# ['AFTV매형깐부']
# ('AFTV매형깐부', 13338438, 'KR', 'KOR')
# (3525, '꼬맹아 나 안잘래', 'KR', 'KOR', [])
# ['꼬맹아 나 안잘래']
# ('꼬맹아 나 안잘래', 33579012, 'KR', 'KOR')
# (3527, '락득구', 'KR', 'KOR', [])
# ['락득구']
# ('락득구', 67192325, 'KR', 'KOR')
# (3528, '동 동 2020', 'KR', 'KOR', [])
# ['동 동 2020']
# ('동 동 2020', 62734089, 'KR', 'KOR')
# (3529, '넌 미대 오지마라', 'KR', 'KOR', [])
# ['넌 미대 오지마라']
# ('넌 미대 오지마라', 91023716, 'KR', 'KOR')
# (3531, '한림면 시라소니', 'KR', 'KOR', [])
# ['한림면 시라소니']
# ('한림면 시라소니', 83637466, 'KR', 'KOR')
# (3530, '딱 데', 'KR', 'KOR', [])
# ['딱 데']
# ('딱 데', 227805, 'KR', 'KOR')
# (3535, '조 득', 'KR', 'KOR', [])
# ['조 득']
# ('조 득', 15391859, 'KR', 'KOR')
# (3536, '로이디에츠', 'KR', 'KOR', [])
# ['로이디에츠']
# ('로이디에츠', 78659862, 'KR', 'KOR')
# (3533, '최훈이', 'KR', 'KOR', [])
# ['최훈이']
# ('최훈이', 89576023, 'KR', 'KOR')
# (3537, '난글렀어', 'KR', 'KOR', [])
# ['난글렀어']
# ('난글렀어', 27192277, 'KR', 'KOR')
# (3482, '원 툴', 'KR', 'KOR', ['지하닝'])
# ['원 툴', '지하닝']
# ('원 툴', 24865149, 'KR', 'KOR')
# ('지하닝', 65168426, 'KR', 'KOR')
# (3580, 'Mtreasure#LAN', 'LA', 'COL', [''])
# ['Mtreasure#LAN', '']
# ('Mtreasure#LAN', 99727204, 'LA', 'COL')
# (3582, 'maneug03', 'LA', 'MEX', [''])
# ['maneug03', '']
# ('maneug03', 61602912, 'LA', 'MEX')
# (3584, 'HG Poc', 'LA', 'MEX', [''])
# ['HG Poc', '']
# ('HG Poc', 77997422, 'LA', 'MEX')
# (3585, 'Sun Ârt', 'LA', 'COL', [''])
# ['Sun Ârt', '']
# ('Sun Ârt', 54233669, 'LA', 'COL')
# (3581, 'StLuis21', 'LA', 'MEX', [''])
# ['StLuis21', '']
# ('StLuis21', 24915962, 'LA', 'MEX')
# (3589, 'burrival junior', 'BR', 'BRA', [''])
# ['burrival junior', '']
# ('burrival junior', 21072184, 'BR', 'BRA')
# (894, 'Shenanigantz', 'LA', 'CHL', ['MKS Shenanigantz'])
# ['Shenanigantz', 'MKS Shenanigantz']
# ('Shenanigantz', 11669310, 'LA', 'CHL')
# ('MKS Shenanigantz', 11669310, 'LA', 'CHL')
# (2183, 'XKT Distanz', 'LA', 'CHL', ['Distanz'])
# ['XKT Distanz', 'Distanz']
# ('XKT Distanz', 99160754, 'LA', 'CHL')
# ('Distanz', 99160754, 'LA', 'CHL')
# (4377, 'Ène', 'NA', 'USA', [])
# ['Ène']
# ('Ène', 78811832, 'NA', 'USA')
# (4385, 'Nazrat NA', 'NA', 'USA', [])
# ['Nazrat NA']
# ('Nazrat NA', 52608335, 'NA', 'USA')
# (4395, 'mrotdog', 'NA', 'USA', [])
# ['mrotdog']
# ('mrotdog', 46338625, 'NA', 'USA')
# (4406, 'CLG HotshotGG', 'NA', 'USA', [])
# ['CLG HotshotGG']
# ('CLG HotshotGG', 51148870, 'NA', 'USA')
# (4420, 'Bxh7', 'NA', 'USA', [])
# ['Bxh7']
# ('Bxh7', 73559413, 'NA', 'USA')
# (1166, 'Itachi', 'BR', 'BRA', ['BES itachi', 'Sdds riven dusk', 'ItachiTFT'])
# ['Itachi', 'BES itachi', 'Sdds riven dusk', 'ItachiTFT']
# ('Itachi', 60566694, 'BR', 'BRA')
# ('BES itachi', 60566694, 'BR', 'BRA')
# ('Sdds riven dusk', 47541912, 'BR', 'BRA')
# ('ItachiTFT', 60566694, 'BR', 'BRA')
# (5228, 'Darevitt', 'LA', 'PER', ['MrDarevitt'])
# ['Darevitt', 'MrDarevitt']
# ('Darevitt', 23892210, 'LA', 'PER')
# ('MrDarevitt', 23892210, 'LA', 'PER')
# (3830, '1st Remizdabezt', 'SEA', 'VNM', [])
# ['1st Remizdabezt']
# ('1st Remizdabezt', 93219258, 'SEA', 'VNM')
# (3832, 'TFA 1', 'SEA', 'VNM', [])
# ['TFA 1']
# ('TFA 1', 4915009, 'SEA', 'VNM')
# (3833, 'severthaidinh', 'SEA', 'VNM', [])
# ['severthaidinh']
# ('severthaidinh', 32120109, 'SEA', 'VNM')
# (3842, 'pyuupnpay', 'SEA', 'VNM', [])
# ['pyuupnpay']
# ('pyuupnpay', 14413585, 'SEA', 'VNM')
# (3844, 'khí vận', 'SEA', 'VNM', [])
# ['khí vận']
# ('khí vận', 34979384, 'SEA', 'VNM')
# (3846, 'Trưởng Lão FBG', 'SEA', 'VNM', [])
# ['Trưởng Lão FBG']
# ('Trưởng Lão FBG', 58407162, 'SEA', 'VNM')
# (3849, 'SnowB1', 'SEA', 'VNM', [])
# ['SnowB1']
# ('SnowB1', 11532321, 'SEA', 'VNM')
# (3850, 'Hoptft', 'SEA', 'VNM', [])
# ['Hoptft']
# ('Hoptft', 85103001, 'SEA', 'VNM')
# (3845, 'Yt Top 1 Gaming', 'SEA', 'VNM', [])
# ['Yt Top 1 Gaming']
# ('Yt Top 1 Gaming', 55408209, 'SEA', 'VNM')
# (3848, 'antxnio', 'SEA', 'VNM', [])
# ['antxnio']
# ('antxnio', 34771218, 'SEA', 'VNM')
# (3843, '1 day no sun', 'SEA', 'VNM', [])
# ['1 day no sun']
# ('1 day no sun', 95274196, 'SEA', 'VNM')
# (3852, 'Cứ thế th0i', 'SEA', 'VNM', [])
# ['Cứ thế th0i']
# ('Cứ thế th0i', 58411928, 'SEA', 'VNM')
# (3853, 'setsuko dog', 'SEA', 'VNM', [])
# ['setsuko dog']
# ('setsuko dog', 85000179, 'SEA', 'VNM')
# (3858, 'Hehexdd', 'SEA', 'VNM', [])
# ['Hehexdd']
# ('Hehexdd', 20804549, 'SEA', 'VNM')
# (3859, 'Jeff Justin', 'SEA', 'VNM', [])
# ['Jeff Justin']
# ('Jeff Justin', 14684352, 'SEA', 'VNM')
# (3860, 'RigaMagiciannn', 'SEA', 'VNM', [])
# ['RigaMagiciannn']
# ('RigaMagiciannn', 37328267, 'SEA', 'VNM')
# (3861, 'Kỳ thủ Đông Lào', 'SEA', 'VNM', [])
# ['Kỳ thủ Đông Lào']
# ('Kỳ thủ Đông Lào', 98997575, 'SEA', 'VNM')
# (3857, 'SBTC KẻThứcThời', 'SEA', 'VNM', [])
# ['SBTC KẻThứcThời']
# ('SBTC KẻThứcThời', 52883380, 'SEA', 'VNM')
# (3856, 'FS Kenzou', 'SEA', 'VNM', [])
# ['FS Kenzou']
# ('FS Kenzou', 31846270, 'SEA', 'VNM')
# (3855, 'FS Roll 7', 'SEA', 'VNM', [])
# ['FS Roll 7']
# ('FS Roll 7', 17278693, 'SEA', 'VNM')
# (3862, 'U N M E l', 'SEA', 'VNM', [])
# ['U N M E l']
# ('U N M E l', 49181549, 'SEA', 'VNM')
# (3863, 'TF Baam', 'SEA', 'VNM', [])
# ['TF Baam']
# ('TF Baam', 72662802, 'SEA', 'VNM')
# (3865, 'quanganhvippro', 'SEA', 'VNM', [])
# ['quanganhvippro']
# ('quanganhvippro', 67356433, 'SEA', 'VNM')
# (3866, 'NTHTxNVD', 'SEA', 'VNM', [])
# ['NTHTxNVD']
# ('NTHTxNVD', 84132490, 'SEA', 'VNM')
# (3867, 'Lasan Hill', 'SEA', 'VNM', [])
# ['Lasan Hill']
# ('Lasan Hill', 42310001, 'SEA', 'VNM')
# (3868, 'SOS Somybaby', 'SEA', 'VNM', [])
# ['SOS Somybaby']
# ('SOS Somybaby', 31187505, 'SEA', 'VNM')
# (3869, 'vidTFT', 'SEA', 'VNM', [])
# ['vidTFT']
# ('vidTFT', 17782539, 'SEA', 'VNM')
# (3870, 'SKTT1DươngQuân', 'SEA', 'VNM', [])
# ['SKTT1DươngQuân']
# ('SKTT1DươngQuân', 93335383, 'SEA', 'VNM')
# (3871, 'KND Lemon8', 'SEA', 'VNM', [])
# ['KND Lemon8']
# ('KND Lemon8', 15689468, 'SEA', 'VNM')
# (3864, 'C5 Blueee', 'SEA', 'VNM', [])
# ['C5 Blueee']
# ('C5 Blueee', 54088403, 'SEA', 'VNM')
# (3872, 'phucpui', 'SEA', 'VNM', [])
# ['phucpui']
# ('phucpui', 29921777, 'SEA', 'VNM')
# (3873, 'DB HighRoii', 'SEA', 'VNM', [])
# ['DB HighRoii']
# ('DB HighRoii', 94222416, 'SEA', 'VNM')
# (3874, 'Cườngggg782', 'SEA', 'VNM', [])
# ['Cườngggg782']
# ('Cườngggg782', 23447003, 'SEA', 'VNM')
# (3875, 'TFT SnowAce', 'SEA', 'VNM', [])
# ['TFT SnowAce']
# ('TFT SnowAce', 52057529, 'SEA', 'VNM')
# (3876, 'KazeSeven', 'SEA', 'VNM', [])
# ['KazeSeven']
# ('KazeSeven', 49908298, 'SEA', 'VNM')
# (3877, 'Mi Sói 666', 'SEA', 'VNM', [])
# ['Mi Sói 666']
# ('Mi Sói 666', 6747290, 'SEA', 'VNM')
# (3878, 'TSCMKNRNSH', 'SEA', 'VNM', [])
# ['TSCMKNRNSH']
# ('TSCMKNRNSH', 22602469, 'SEA', 'VNM')
# (3879, 'bladeking', 'SEA', 'VNM', [])
# ['bladeking']
# ('bladeking', 80489438, 'SEA', 'VNM')
# (3880, 'VN Tuyết Linh', 'SEA', 'VNM', [])
# ['VN Tuyết Linh']
# ('VN Tuyết Linh', 8451758, 'SEA', 'VNM')
# (3881, 'ElIlSEN', 'SEA', 'VNM', [])
# ['ElIlSEN']
# ('ElIlSEN', 62360765, 'SEA', 'VNM')
# (3882, 'HLG Kim Thu', 'SEA', 'VNM', [])
# ['HLG Kim Thu']
# ('HLG Kim Thu', 95728472, 'SEA', 'VNM')
# (3883, 'Bobbie2802', 'SEA', 'VNM', [])
# ['Bobbie2802']
# ('Bobbie2802', 54086029, 'SEA', 'VNM')
# (3884, 'Mr Suky', 'SEA', 'VNM', [])
# ['Mr Suky']
# ('Mr Suky', 21455246, 'SEA', 'VNM')
# (3886, 'MeoU TFT', 'SEA', 'VNM', [])
# ['MeoU TFT']
# ('MeoU TFT', 55010728, 'SEA', 'VNM')
# (3888, 'HnZ Đình Hảii', 'SEA', 'VNM', [])
# ['HnZ Đình Hảii']
# ('HnZ Đình Hảii', 14695704, 'SEA', 'VNM')
# (3889, 'y Tiger1', 'SEA', 'VNM', [])
# ['y Tiger1']
# ('y Tiger1', 14331522, 'SEA', 'VNM')
# (3890, 'Lợi Nguyễnn', 'SEA', 'VNM', [])
# ['Lợi Nguyễnn']
# ('Lợi Nguyễnn', 35598006, 'SEA', 'VNM')
# (3892, 'T 21092002', 'SEA', 'VNM', [])
# ['T 21092002']
# ('T 21092002', 19697191, 'SEA', 'VNM')
# (3891, 'ChGKuuhakuTFF', 'SEA', 'VNM', [])
# ['ChGKuuhakuTFF']
# ('ChGKuuhakuTFF', 41577041, 'SEA', 'VNM')
# (3894, 'TSTShin', 'SEA', 'VNM', [])
# ['TSTShin']
# ('TSTShin', 75467348, 'SEA', 'VNM')
# (3895, 'D U K I H A N 1', 'SEA', 'VNM', [])
# ['D U K I H A N 1']
# ('D U K I H A N 1', 92526373, 'SEA', 'VNM')
# (3896, 'Atreus VII', 'SEA', 'VNM', [])
# ['Atreus VII']
# ('Atreus VII', 27095409, 'SEA', 'VNM')
# (3897, 'Manhhe', 'SEA', 'VNM', [])
# ['Manhhe']
# ('Manhhe', 56461290, 'SEA', 'VNM')
# (3899, 'Đầm Văn Cua', 'SEA', 'VNM', [])
# ['Đầm Văn Cua']
# ('Đầm Văn Cua', 59330076, 'SEA', 'VNM')
# (3900, 'HP AnhTu', 'SEA', 'VNM', [])
# ['HP AnhTu']
# ('HP AnhTu', 10934777, 'SEA', 'VNM')
# (3902, 'SP Mạnh Chim Ưng', 'SEA', 'VNM', [])
# ['SP Mạnh Chim Ưng']
# ('SP Mạnh Chim Ưng', 38395697, 'SEA', 'VNM')
# (3901, 'G1ữa Ngân Hà', 'SEA', 'VNM', [])
# ['G1ữa Ngân Hà']
# ('G1ữa Ngân Hà', 31601296, 'SEA', 'VNM')
# (3903, 'MT Colnat', 'SEA', 'VNM', [])
# ['MT Colnat']
# ('MT Colnat', 98054437, 'SEA', 'VNM')
# (3904, 'Cánh Cụt Hụt Hơi', 'SEA', 'VNM', [])
# ['Cánh Cụt Hụt Hơi']
# ('Cánh Cụt Hụt Hơi', 54317962, 'SEA', 'VNM')
# (3905, '12342106', 'SEA', 'VNM', [])
# ['12342106']
# ('12342106', 41966343, 'SEA', 'VNM')
# (3906, 'Em Luận Ngợp Quá', 'SEA', 'VNM', [])
# ['Em Luận Ngợp Quá']
# ('Em Luận Ngợp Quá', 45731779, 'SEA', 'VNM')
# (3907, 'Joung Process', 'SEA', 'VNM', [])
# ['Joung Process']
# ('Joung Process', 62154496, 'SEA', 'VNM')
# (3908, 'Shinöbu Neesan', 'SEA', 'VNM', [])
# ['Shinöbu Neesan']
# ('Shinöbu Neesan', 49286238, 'SEA', 'VNM')
# (3909, 'SP Stev3', 'SEA', 'VNM', [])
# ['SP Stev3']
# ('SP Stev3', 27519326, 'SEA', 'VNM')
# (3910, 'SVM CườngTĐ', 'SEA', 'VNM', [])
# ['SVM CườngTĐ']
# ('SVM CườngTĐ', 44832499, 'SEA', 'VNM')
# (3911, 'Łevel5JudgeŁight', 'SEA', 'VNM', [])
# ['Łevel5JudgeŁight']
# ('Łevel5JudgeŁight', 27816081, 'SEA', 'VNM')
# (3912, 'tidien', 'SEA', 'VNM', [])
# ['tidien']
# ('tidien', 2940698, 'SEA', 'VNM')
# (3913, 'KND Hanni Bius', 'SEA', 'VNM', [])
# ['KND Hanni Bius']
# ('KND Hanni Bius', 31129669, 'SEA', 'VNM')
# (3914, 'Windkyy', 'SEA', 'VNM', [])
# ['Windkyy']
# ('Windkyy', 58620487, 'SEA', 'VNM')
# (3916, 'Vi Mêu', 'SEA', 'VNM', [])
# ['Vi Mêu']
# ('Vi Mêu', 70151312, 'SEA', 'VNM')
# (3917, 'IT is Shi', 'SEA', 'VNM', [])
# ['IT is Shi']
# ('IT is Shi', 1364091, 'SEA', 'VNM')
# (3918, 'hnay cau on chu', 'SEA', 'VNM', [])
# ['hnay cau on chu']
# ('hnay cau on chu', 35664082, 'SEA', 'VNM')
# (3915, '748 Ốc Mốc', 'SEA', 'VNM', [])
# ['748 Ốc Mốc']
# ('748 Ốc Mốc', 85935963, 'SEA', 'VNM')
# (3919, 'FBG enQien', 'SEA', 'VNM', [])
# ['FBG enQien']
# ('FBG enQien', 74658545, 'SEA', 'VNM')
# (3920, 'SDE', 'SEA', 'VNM', [])
# ['SDE']
# ('SDE', 91865291, 'SEA', 'VNM')
# (3921, 'Voronoi', 'SEA', 'VNM', [])
# ['Voronoi']
# ('Voronoi', 95043377, 'SEA', 'VNM')
# (3922, 'I Love Quao 3000', 'SEA', 'VNM', [])
# ['I Love Quao 3000']
# ('I Love Quao 3000', 65654804, 'SEA', 'VNM')
# (3923, 'SuIIyoon', 'SEA', 'VNM', [])
# ['SuIIyoon']
# ('SuIIyoon', 36075093, 'SEA', 'VNM')
# (3924, 'ng gã dùng', 'SEA', 'VNM', [])
# ['ng gã dùng']
# ('ng gã dùng', 53970762, 'SEA', 'VNM')
# (3925, 'thach dauu', 'SEA', 'VNM', [])
# ['thach dauu']
# ('thach dauu', 13312828, 'SEA', 'VNM')
# (3927, 'Mot Cay Cung', 'SEA', 'VNM', [])
# ['Mot Cay Cung']
# ('Mot Cay Cung', 55943914, 'SEA', 'VNM')
# (4378, 'd0g3s', 'NA', 'USA', [])
# ['d0g3s']
# ('d0g3s', 30089302, 'NA', 'USA')
# (4384, 'cat ponder', 'NA', 'USA', [])
# ['cat ponder']
# ('cat ponder', 90274946, 'NA', 'USA')
# (4394, 'Silby', 'NA', 'USA', [])
# ['Silby']
# ('Silby', 92143326, 'NA', 'USA')
# (4403, 'dannydonuts45', 'NA', 'USA', [])
# ['dannydonuts45']
# ('dannydonuts45', 35121102, 'NA', 'USA')
# (4414, 'Jia ke se', 'NA', 'USA', [])
# ['Jia ke se']
# ('Jia ke se', 47478330, 'NA', 'USA')
# (4792, 'Billie Jimmy', 'EMEA', 'FRA', ['BillieJimmy'])
# ['Billie Jimmy', 'BillieJimmy']
# ('Billie Jimmy', 98901857, 'EMEA', 'FRA')
# ('BillieJimmy', 98901857, 'EMEA', 'FRA')
# (6391, 'ddddddddddwaaaaa', 'CN', 'CHN', [])
# ['ddddddddddwaaaaa']
# ('ddddddddddwaaaaa', 62835325, 'CN', 'CHN')
# (5229, 'Kahi', 'LA', 'CHL', [''])
# ['Kahi', '']
# ('Kahi', 67044462, 'LA', 'CHL')
# (6400, '我真是个懒b', 'CN', 'CHN', [])
# ['我真是个懒b']
# ('我真是个懒b', 52895325, 'CN', 'CHN')
# (3979, 'KND Minhbeso', 'SEA', 'VNM', ['dj Minhbesone'])
# ['KND Minhbeso', 'dj Minhbesone']
# ('KND Minhbeso', 71221402, 'SEA', 'VNM')
# ('dj Minhbesone', 71221402, 'SEA', 'VNM')
# (5451, 'sir muro', 'LA', 'CHL', [])
# ['sir muro']
# ('sir muro', 23683089, 'LA', 'CHL')
# (4874, 'PaulusTFT', 'EMEA', 'DEU', [])
# ['PaulusTFT']
# ('PaulusTFT', 51198032, 'EMEA', 'DEU')
# (4876, 'Dadasa1', 'EMEA', 'POL', [])
# ['Dadasa1']
# ('Dadasa1', 19165605, 'EMEA', 'POL')
# (4877, 'elias xdd', 'EMEA', 'DEU', [])
# ['elias xdd']
# ('elias xdd', 25953015, 'EMEA', 'DEU')
# (4878, 'shibbytavu', 'EMEA', 'FRA', [])
# ['shibbytavu']
# ('shibbytavu', 45639801, 'EMEA', 'FRA')
# (4879, 'Lord Bollis', 'EMEA', 'SWE', [])
# ['Lord Bollis']
# ('Lord Bollis', 43893018, 'EMEA', 'SWE')
# (3828, 'ö Blade ö', 'SEA', 'VNM', ['Blade'])
# ['ö Blade ö', 'Blade']
# ('ö Blade ö', 98367810, 'SEA', 'VNM')
# ('Blade', 98367810, 'SEA', 'VNM')
# (3946, 'sutinhlang1', 'SEA', 'VNM', ['Sự Tĩnh Lặng'])
# ['sutinhlang1', 'Sự Tĩnh Lặng']
# ('sutinhlang1', 78131044, 'SEA', 'VNM')
# ('Sự Tĩnh Lặng', 78131044, 'SEA', 'VNM')
# (3820, 'Demo TFT', 'SEA', 'VNM', [])
# ['Demo TFT']
# ('Demo TFT', 47678360, 'SEA', 'VNM')
# (3821, 'Hải Anh is me', 'SEA', 'VNM', [])
# ['Hải Anh is me']
# ('Hải Anh is me', 4405011, 'SEA', 'VNM')
# (3825, 'P2W HaoreddogxC', 'SEA', 'VNM', [])
# ['P2W HaoreddogxC']
# ('P2W HaoreddogxC', 45520502, 'SEA', 'VNM')
# (3826, 'NG VINJIN', 'SEA', 'VNM', [])
# ['NG VINJIN']
# ('NG VINJIN', 95079674, 'SEA', 'VNM')
# (3827, 'ßánh Xu Xê BN', 'SEA', 'VNM', [])
# ['ßánh Xu Xê BN']
# ('ßánh Xu Xê BN', 9000261, 'SEA', 'VNM')
# (3774, 'ZenKun1', 'SEA', 'VNM', [])
# ['ZenKun1']
# ('ZenKun1', 87011821, 'SEA', 'VNM')
# (3931, 'KyouKaz', 'SEA', 'VNM', [])
# ['KyouKaz']
# ('KyouKaz', 5977851, 'SEA', 'VNM')
# (3932, 'PhongThầnSabo', 'SEA', 'VNM', [])
# ['PhongThầnSabo']
# ('PhongThầnSabo', 98954908, 'SEA', 'VNM')
# (3933, 'Dungbanganh1102', 'SEA', 'VNM', [])
# ['Dungbanganh1102']
# ('Dungbanganh1102', 14857130, 'SEA', 'VNM')
# (3938, 'LibraD2910', 'SEA', 'VNM', [])
# ['LibraD2910']
# ('LibraD2910', 20962598, 'SEA', 'VNM')
# (3942, 'HLG Victorious', 'SEA', 'VNM', [])
# ['HLG Victorious']
# ('HLG Victorious', 94142423, 'SEA', 'VNM')
# (3943, 'Huy Rồng', 'SEA', 'VNM', [])
# ['Huy Rồng']
# ('Huy Rồng', 15678681, 'SEA', 'VNM')
# (3944, 'trunglkkkkkkk', 'SEA', 'VNM', [])
# ['trunglkkkkkkk']
# ('trunglkkkkkkk', 22994616, 'SEA', 'VNM')
# (3945, 'Sir Ling', 'SEA', 'VNM', [])
# ['Sir Ling']
# ('Sir Ling', 28236759, 'SEA', 'VNM')
# (3947, 'NNG 1314', 'SEA', 'VNM', [])
# ['NNG 1314']
# ('NNG 1314', 62636693, 'SEA', 'VNM')
# (3950, 'magic25', 'SEA', 'VNM', [])
# ['magic25']
# ('magic25', 68839307, 'SEA', 'VNM')
# (3951, 'Santorinii', 'SEA', 'VNM', [])
# ['Santorinii']
# ('Santorinii', 2594895, 'SEA', 'VNM')
# (3949, 'DJ GiaMinh', 'SEA', 'VNM', [])
# ['DJ GiaMinh']
# ('DJ GiaMinh', 64731830, 'SEA', 'VNM')
# (3952, 'Perfaketo', 'SEA', 'VNM', [])
# ['Perfaketo']
# ('Perfaketo', 95761908, 'SEA', 'VNM')
# (3953, 'Hieu on bush', 'SEA', 'VNM', [])
# ['Hieu on bush']
# ('Hieu on bush', 19225569, 'SEA', 'VNM')
# (3954, 'INF XiaoFeng1', 'SEA', 'VNM', [])
# ['INF XiaoFeng1']
# ('INF XiaoFeng1', 20022399, 'SEA', 'VNM')
# (3955, 'back pain', 'SEA', 'VNM', [])
# ['back pain']
# ('back pain', 45332104, 'SEA', 'VNM')
# (3958, 'LaLaNặcÁSáchLong', 'SEA', 'VNM', [])
# ['LaLaNặcÁSáchLong']
# ('LaLaNặcÁSáchLong', 91426317, 'SEA', 'VNM')
# (3959, 'FANBOYEMCHE', 'SEA', 'VNM', [])
# ['FANBOYEMCHE']
# ('FANBOYEMCHE', 20337907, 'SEA', 'VNM')
# (3960, 'NG InKaa', 'SEA', 'VNM', [])
# ['NG InKaa']
# ('NG InKaa', 11811350, 'SEA', 'VNM')
# (3961, 'Mai ngọc sơnn', 'SEA', 'VNM', [])
# ['Mai ngọc sơnn']
# ('Mai ngọc sơnn', 9239837, 'SEA', 'VNM')
# (3962, 'dungnekk', 'SEA', 'VNM', [])
# ['dungnekk']
# ('dungnekk', 97483236, 'SEA', 'VNM')
# (3963, 'daohoa anhh', 'SEA', 'VNM', [])
# ['daohoa anhh']
# ('daohoa anhh', 63858986, 'SEA', 'VNM')
# (3964, 'TL x EnTiKayyyy', 'SEA', 'VNM', [])
# ['TL x EnTiKayyyy']
# ('TL x EnTiKayyyy', 31830133, 'SEA', 'VNM')
# (3966, 'Tuỵ', 'SEA', 'VNM', [])
# ['Tuỵ']
# ('Tuỵ', 12212636, 'SEA', 'VNM')
# (3967, 'NG TVD', 'SEA', 'VNM', [])
# ['NG TVD']
# ('NG TVD', 26192993, 'SEA', 'VNM')
# (3968, 'NG Ji Tiên', 'SEA', 'VNM', [])
# ['NG Ji Tiên']
# ('NG Ji Tiên', 47744302, 'SEA', 'VNM')
# (3969, 'ACE NVQ', 'SEA', 'VNM', [])
# ['ACE NVQ']
# ('ACE NVQ', 5803897, 'SEA', 'VNM')
# (3970, 'Ottooo', 'SEA', 'VNM', [])
# ['Ottooo']
# ('Ottooo', 11225529, 'SEA', 'VNM')
# (3971, 'VN SVM DVQ', 'SEA', 'VNM', [])
# ['VN SVM DVQ']
# ('VN SVM DVQ', 7951590, 'SEA', 'VNM')
# (3965, 'Hiiiii Im Negan', 'SEA', 'VNM', [])
# ['Hiiiii Im Negan']
# ('Hiiiii Im Negan', 20396356, 'SEA', 'VNM')
# (3973, 'TFA Love1Side', 'SEA', 'VNM', [])
# ['TFA Love1Side']
# ('TFA Love1Side', 4854998, 'SEA', 'VNM')
# (3975, 'INF VV', 'SEA', 'VNM', [])
# ['INF VV']
# ('INF VV', 98673346, 'SEA', 'VNM')
# (3976, 'NTL NuocMamToiOt', 'SEA', 'VNM', [])
# ['NTL NuocMamToiOt']
# ('NTL NuocMamToiOt', 66763535, 'SEA', 'VNM')
# (3977, 'BLN Kính Tâm Ma', 'SEA', 'VNM', [])
# ['BLN Kính Tâm Ma']
# ('BLN Kính Tâm Ma', 73086558, 'SEA', 'VNM')
# (3978, 'xuxu bu bong', 'SEA', 'VNM', [])
# ['xuxu bu bong']
# ('xuxu bu bong', 28302964, 'SEA', 'VNM')
# (3980, 'D2F Iris', 'SEA', 'VNM', [])
# ['D2F Iris']
# ('D2F Iris', 59046972, 'SEA', 'VNM')
# (3974, 'HNZ boi tháng 8', 'SEA', 'VNM', [])
# ['HNZ boi tháng 8']
# ('HNZ boi tháng 8', 67396830, 'SEA', 'VNM')
# (3981, 'WASPAOB', 'SEA', 'VNM', [])
# ['WASPAOB']
# ('WASPAOB', 70713164, 'SEA', 'VNM')
# (3983, 'Pháp Sư Đôńg Lào', 'SEA', 'VNM', [])
# ['Pháp Sư Đôńg Lào']
# ('Pháp Sư Đôńg Lào', 57420693, 'SEA', 'VNM')
# (3984, 'sonsinger0444', 'SEA', 'VNM', [])
# ['sonsinger0444']
# ('sonsinger0444', 12634681, 'SEA', 'VNM')
# (3985, 'dung lua em1', 'SEA', 'VNM', [])
# ['dung lua em1']
# ('dung lua em1', 27454037, 'SEA', 'VNM')
# (3986, 'Em Đức Lạc Lối', 'SEA', 'VNM', [])
# ['Em Đức Lạc Lối']
# ('Em Đức Lạc Lối', 55965295, 'SEA', 'VNM')
# (3987, 'Potm TFT', 'SEA', 'VNM', [])
# ['Potm TFT']
# ('Potm TFT', 24920963, 'SEA', 'VNM')
# (3988, 'ĐTrai HHoa PNhã', 'SEA', 'VNM', [])
# ['ĐTrai HHoa PNhã']
# ('ĐTrai HHoa PNhã', 17165564, 'SEA', 'VNM')
# (3989, 'SOS Sữa', 'SEA', 'VNM', [])
# ['SOS Sữa']
# ('SOS Sữa', 81507289, 'SEA', 'VNM')
# (3991, 'T 16 04 04', 'SEA', 'VNM', [])
# ['T 16 04 04']
# ('T 16 04 04', 69911632, 'SEA', 'VNM')
# (3992, 'Tôi Dại Dột 111', 'SEA', 'VNM', [])
# ['Tôi Dại Dột 111']
# ('Tôi Dại Dột 111', 59786702, 'SEA', 'VNM')
# (3993, 'INF ND', 'SEA', 'VNM', [])
# ['INF ND']
# ('INF ND', 79869721, 'SEA', 'VNM')
# (3996, 'Khó cho Vũ quáa', 'SEA', 'VNM', [])
# ['Khó cho Vũ quáa']
# ('Khó cho Vũ quáa', 15193471, 'SEA', 'VNM')
# (3997, 'ggwen272003', 'SEA', 'VNM', [])
# ['ggwen272003']
# ('ggwen272003', 75557412, 'SEA', 'VNM')
# (3998, 'Gà Đăng Đoàn', 'SEA', 'VNM', [])
# ['Gà Đăng Đoàn']
# ('Gà Đăng Đoàn', 58500180, 'SEA', 'VNM')
# (3999, 'ÔngHøàngKïểmSøát', 'SEA', 'VNM', [])
# ['ÔngHøàngKïểmSøát']
# ('ÔngHøàngKïểmSøát', 80929115, 'SEA', 'VNM')
# (4000, 'SVM LâmLouis', 'SEA', 'VNM', [])
# ['SVM LâmLouis']
# ('SVM LâmLouis', 61107226, 'SEA', 'VNM')
# (4001, 'TRIEN DAI HIEP', 'SEA', 'VNM', [])
# ['TRIEN DAI HIEP']
# ('TRIEN DAI HIEP', 73378066, 'SEA', 'VNM')
# (4003, 'TA nuôi bạo chúa', 'SEA', 'VNM', [])
# ['TA nuôi bạo chúa']
# ('TA nuôi bạo chúa', 24970903, 'SEA', 'VNM')
# (4009, 'Y3uem38', 'SEA', 'VNM', [])
# ['Y3uem38']
# ('Y3uem38', 49504245, 'SEA', 'VNM')
# (4007, 'Nhà Báo Tên Kiên', 'SEA', 'VNM', [])
# ['Nhà Báo Tên Kiên']
# ('Nhà Báo Tên Kiên', 14578776, 'SEA', 'VNM')
# (4010, 'toi ngu quaaaaa', 'SEA', 'VNM', [])
# ['toi ngu quaaaaa']
# ('toi ngu quaaaaa', 90072767, 'SEA', 'VNM')
# (4011, 'LuckyOla', 'SEA', 'VNM', [])
# ['LuckyOla']
# ('LuckyOla', 546335, 'SEA', 'VNM')
# (4012, 'Zhou Jieqiong', 'SEA', 'VNM', [])
# ['Zhou Jieqiong']
# ('Zhou Jieqiong', 87245176, 'SEA', 'VNM')
# (4015, 'nghiavipprono1', 'SEA', 'VNM', [])
# ['nghiavipprono1']
# ('nghiavipprono1', 32776764, 'SEA', 'VNM')
# (4016, 'kebatbaiso1', 'SEA', 'VNM', [])
# ['kebatbaiso1']
# ('kebatbaiso1', 45750607, 'SEA', 'VNM')
# (4014, 'Deannn', 'SEA', 'VNM', [])
# ['Deannn']
# ('Deannn', 71269504, 'SEA', 'VNM')
# (4013, 'VN Hồ cảm xúc', 'SEA', 'VNM', [])
# ['VN Hồ cảm xúc']
# ('VN Hồ cảm xúc', 2176193, 'SEA', 'VNM')
# (3823, 'oilchesterunited', 'SEA', 'VNM', [])
# ['oilchesterunited']
# ('oilchesterunited', 18289720, 'SEA', 'VNM')
# (3814, '72 Sunshine', 'SEA', 'VNM', [])
# ['72 Sunshine']
# ('72 Sunshine', 88742034, 'SEA', 'VNM')
# (3840, 'FS Đau Đầu', 'SEA', 'VNM', [])
# ['FS Đau Đầu']
# ('FS Đau Đầu', 10975867, 'SEA', 'VNM')
# (3841, 'DJ TOM', 'SEA', 'VNM', [])
# ['DJ TOM']
# ('DJ TOM', 42253363, 'SEA', 'VNM')
# (3930, 'KhanhxDuy', 'SEA', 'VNM', [])
# ['KhanhxDuy']
# ('KhanhxDuy', 51562966, 'SEA', 'VNM')
# (3936, 'HK dungeon', 'SEA', 'VNM', [])
# ['HK dungeon']
# ('HK dungeon', 41143837, 'SEA', 'VNM')
# (3941, 'SVM Maybe1', 'SEA', 'VNM', [])
# ['SVM Maybe1']
# ('SVM Maybe1', 14893602, 'SEA', 'VNM')
# (3957, 'TDQ ON TOP', 'SEA', 'VNM', [])
# ['TDQ ON TOP']
# ('TDQ ON TOP', 42517780, 'SEA', 'VNM')
# (4379, 'rjblarmo', 'NA', 'USA', [])
# ['rjblarmo']
# ('rjblarmo', 95920757, 'NA', 'USA')
# (4400, 'ng c bandz', 'NA', 'USA', [])
# ['ng c bandz']
# ('ng c bandz', 4118386, 'NA', 'USA')
# (4410, 'bwby', 'NA', 'USA', [])
# ['bwby']
# ('bwby', 30617122, 'NA', 'USA')
# (1202, 'Vulpix', 'EMEA', 'DNK', ['lvl 1 Vulpix', 'Hellzminion'])
# ['Vulpix', 'lvl 1 Vulpix', 'Hellzminion']
# ('Vulpix', 2924965, 'EMEA', 'DNK')
# ('lvl 1 Vulpix', 2924965, 'EMEA', 'DNK')
# ('Hellzminion', 2924965, 'EMEA', 'DNK')
# (5230, 'RSK CoyoteB', 'LA', 'MEX', [''])
# ['RSK CoyoteB', '']
# ('RSK CoyoteB', 97129564, 'LA', 'MEX')
# (5079, 'Titas', 'EMEA', 'LTU', [])
# ['Titas']
# ('Titas', 67872658, 'EMEA', 'LTU')
# (3822, 'AlbicelesteTFT', 'SEA', 'VNM', ['AlbicelesteTDTU'])
# ['AlbicelesteTFT', 'AlbicelesteTDTU']
# ('AlbicelesteTFT', 14179330, 'SEA', 'VNM')
# ('AlbicelesteTDTU', 14179330, 'SEA', 'VNM')
# (1765, 'cmb9', 'BR', 'BRA', ['wim hof 60 rep', 'cuckmyblade', 'SLORPGLORPIN'])
# ['cmb9', 'wim hof 60 rep', 'cuckmyblade', 'SLORPGLORPIN']
# ('cmb9', 51912279, 'BR', 'BRA')
# ('wim hof 60 rep', 51912279, 'BR', 'BRA')
# ('cuckmyblade', 51912279, 'BR', 'BRA')
# ('SLORPGLORPIN', 85298687, 'BR', 'BRA')
# (6392, '手刃猫咪', 'CN', 'CHN', [])
# ['手刃猫咪']
# ('手刃猫咪', 94732634, 'CN', 'CHN')
# (556, 'GD Royal', 'SEA', 'VNM', ['GD Roya'])
# ['GD Royal', 'GD Roya']
# ('GD Royal', 94321411, 'SEA', 'VNM')
# ('GD Roya', 94321411, 'SEA', 'VNM')
# (4948, 'RST Tacti', 'EMEA', 'FRA', ['Alexbourc'])
# ['RST Tacti', 'Alexbourc']
# ('RST Tacti', 57030089, 'EMEA', 'FRA')
# ('Alexbourc', 57030089, 'EMEA', 'FRA')
# (2470, 'BoxBox', 'NA', 'USA', ['DSG BoxBox', '안돼'])
# ['BoxBox', 'DSG BoxBox', '안돼']
# ('BoxBox', 2501111, 'NA', 'USA')
# ('DSG BoxBox', 2501111, 'NA', 'USA')
# ('안돼', 2501111, 'NA', 'USA')
# (4930, 'Yoge God', 'EMEA', 'NLD', [])
# ['Yoge God']
# ('Yoge God', 4956314, 'EMEA', 'NLD')
# (5786, 'NhuocThiên', 'SEA', 'VNM', [])
# ['NhuocThiên']
# ('NhuocThiên', 64804691, 'SEA', 'VNM')
# (5458, 'FZTFallean', 'LA', 'ARG', [])
# ['FZTFallean']
# ('FZTFallean', 43100604, 'LA', 'ARG')
# (4909, 'MetalManatee', 'EMEA', 'GBR', ['Laser Octopus'])
# ['MetalManatee', 'Laser Octopus']
# ('MetalManatee', 32295962, 'EMEA', 'GBR')
# ('Laser Octopus', 32295962, 'EMEA', 'GBR')
# (4888, 'SaltyCole', 'EMEA', 'FRA', [])
# ['SaltyCole']
# ('SaltyCole', 67382077, 'EMEA', 'FRA')
# (4889, 'Holodista', 'EMEA', 'FIN', [])
# ['Holodista']
# ('Holodista', 27182052, 'EMEA', 'FIN')
# (4890, 'kamilekpi', 'EMEA', 'POL', [])
# ['kamilekpi']
# ('kamilekpi', 23717823, 'EMEA', 'POL')
# (4891, 'trixservus', 'EMEA', 'DEU', [])
# ['trixservus']
# ('trixservus', 99945889, 'EMEA', 'DEU')
# (4893, 'Raconfir', 'EMEA', 'DEU', [])
# ['Raconfir']
# ('Raconfir', 67437891, 'EMEA', 'DEU')
# (4894, 'Salamandrium', 'EMEA', 'FRA', [])
# ['Salamandrium']
# ('Salamandrium', 38179333, 'EMEA', 'FRA')
# (4898, 'gothic kitty', 'EMEA', 'GBR', [])
# ['gothic kitty']
# ('gothic kitty', 68632732, 'EMEA', 'GBR')
# (4899, 'Shadow zone 51', 'EMEA', 'FRA', [])
# ['Shadow zone 51']
# ('Shadow zone 51', 64657912, 'EMEA', 'FRA')
# (4900, 'TFT LØREN', 'EMEA', 'CZE', [])
# ['TFT LØREN']
# ('TFT LØREN', 11306408, 'EMEA', 'CZE')
# (4901, 'HaiEloTFT', 'EMEA', 'DEU', [])
# ['HaiEloTFT']
# ('HaiEloTFT', 4622189, 'EMEA', 'DEU')
# ...
# ['PROYECTO Talon']
# None
# (9961, 'victorcas04', 'LA', '!LA', [])
# ['victorcas04']
# None
# (10016, 'Notgab0火', 'LA', '!LA', [])
# ['Notgab0火']
# None
# (10018, 'Scurraontwich', 'LA', '!LA', [])
# ['Scurraontwich']
# None
# (9926, 'crazy4tits', 'LA', '!LA', [])
# ['crazy4tits']
# None
# (9928, 'cipitio503', 'LA', '!LA', [])
# ['cipitio503']
# None
# (10046, 'Z4ngetsu', 'LA', '!LA', [])
# ['Z4ngetsu']
# None
# (10045, 'Smth Uncle', 'LA', '!LA', [])
# ['Smth Uncle']
# None
# (9929, 'Harujr', 'LA', '!LA', [])
# ['Harujr']
# None
# (10048, 'Fąded', 'LA', '!LA', [])
# ['Fąded']
# None
# (10049, 'ミゲル', 'LA', '!LA', [])
# ['ミゲル']
# None
# (10050, 'Near', 'LA', '!LA', [])
# ['Near']
# None
# (9930, 'GhatO', 'LA', '!LA', [])
# ['GhatO']
# None
# (10051, 'katakkuri', 'LA', '!LA', [])
# ['katakkuri']
# None
# (10052, 'xXJose05Xx', 'LA', '!LA', [])
# ['xXJose05Xx']
# None
# (9934, 'F E N I I X', 'LA', '!LA', [])
# ['F E N I I X']
# None
# (9935, 'Kingambit', 'LA', '!LA', [])
# ['Kingambit']
# None
# (10055, 'RISU', 'LA', '!LA', [])
# ['RISU']
# None
# (10056, 'Palatio', 'LA', '!LA', [])
# ['Palatio']
# None
# (9936, 'Lynz', 'LA', '!LA', [])
# ['Lynz']
# None
# (10025, 'TuercasGamer11', 'LA', '!LA', [])
# ['TuercasGamer11']
# None
# (10032, 'FF The Solitary', 'LA', '!LA', [])
# ['FF The Solitary']
# None
# (10031, 'Princesa Luna', 'LA', '!LA', [])
# ['Princesa Luna']
# None
# (9938, 'Zopilotinho', 'LA', '!LA', [])
# ['Zopilotinho']
# None
# (9939, 'Ragnar Iodbrok', 'LA', '!LA', [])
# ['Ragnar Iodbrok']
# None
# (9937, 'LasNalg4sDeNinaJ', 'LA', '!LA', [])
# ['LasNalg4sDeNinaJ']
# None
# (9940, 'jurado2727', 'LA', '!LA', [])
# ['jurado2727']
# None
# (9946, 'Marc3l', 'LA', '!LA', [])
# ['Marc3l']
# None
# (9948, 'Sundrybaton', 'LA', '!LA', [])
# ['Sundrybaton']
# None
# (9949, 'rest4ever', 'LA', '!LA', [])
# ['rest4ever']
# None
# (9950, 'godacaes', 'LA', '!LA', [])
# ['godacaes']
# None
# (10030, 'HUMI', 'LA', '!LA', [])
# ['HUMI']
# None
# (9951, 'SoyS', 'LA', '!LA', [])
# ['SoyS']
# None
# (10067, 'Coki', 'CN', 'CHN', ['Coki0y0', '周凡', 'Cokiy0y', '斗鱼丶cokiy0y'])
# ['Coki', 'Coki0y0', '周凡', 'Cokiy0y', '斗鱼丶cokiy0y']
# None
# None
# None
# None
# None
# (10068, 'deslayerx', 'CN', 'CHN', ['SlayerX'])
# ['deslayerx', 'SlayerX']
# None
# None
# (10069, 'DQD', 'CN', 'CHN', ['等秋冬'])
# ['DQD', '等秋冬']
# None
# None
# (10070, 'HeiZi', 'CN', 'CHN', ['二流棋手黑子'])
# ['HeiZi', '二流棋手黑子']
# None
# None
# (10071, 'JiangZhe', 'CN', 'CHN', ['姜哲代表'])
# ['JiangZhe', '姜哲代表']
# None
# None
# (10072, 'XiaoZhiZhu', 'CN', 'CHN', ['潇之助', '之助'])
# ['XiaoZhiZhu', '潇之助', '之助']
# ('XiaoZhiZhu', 45096125, None, None)
# None
# None
# (10076, 'bb40014', 'CN', 'CHN', [])
# ['bb40014']
# None
# (10073, '别打电话放门口', 'CN', 'CHN', [])
# ['别打电话放门口']
# None
# (10074, 'CaiMiao', 'CN', 'CHN', ['菜喵qwq'])
# ['CaiMiao', '菜喵qwq']
# None
# None
# (10075, 'JiaSuSu', 'CN', 'CHN', [])
# ['JiaSuSu']
# None
# (10077, '请叫我小丑宗师', 'CN', 'CHN', [])
# ['请叫我小丑宗师']
# None
# (10078, 'DuZai', 'CN', 'CHN', ['独在o'])
# ['DuZai', '独在o']
# None
# None
# (10079, 'NiLiu', 'CN', 'CHN', ['七月逆流'])
# ['NiLiu', '七月逆流']
# ('NiLiu', 18422329, None, None)
# None
# (10080, 'A Bai', 'CN', 'CHN', ['阿柏', '阿柏天天开心', 'ABai'])
# ['A Bai', '阿柏', '阿柏天天开心', 'ABai']
# ('A Bai', 2302620, None, None)
# None
# None
# None
# (10081, 'AhriY', 'CN', 'CHN', ['阿狸Y'])
# ['AhriY', '阿狸Y']
# None
# None
# (10082, 'HaiTang', 'CN', 'CHN', ['梅花海棠'])
# ['HaiTang', '梅花海棠']
# None
# None
# (10083, 'HeFangZhi', 'CN', 'CHN', ['何方知'])
# ['HeFangZhi', '何方知']
# None
# None
# (10084, 'LaoMa', 'CN', 'CHN', ['老马'])
# ['LaoMa', '老马']
# None
# None
# (10085, 'LiangRen', 'CN', 'CHN', ['良人'])
# ['LiangRen', '良人']
# None
# None
# (10086, 'MoYuZai', 'CN', 'CHN', ['墨鱼仔', 'MoYu'])
# ['MoYuZai', '墨鱼仔', 'MoYu']
# ('MoYuZai', 33248301, None, None)
# None
# None
# (10087, 'Pale', 'CN', 'CHN', ['白止'])
# ['Pale', '白止']
# None
# None
# (10088, 'ZhenBai', 'CN', 'CHN', ['小飞'])
# ['ZhenBai', '小飞']
# None
# None
# (10089, 'ZuiSe', 'CN', 'CHN', ['醉色'])
# ['ZuiSe', '醉色']
# None
# None
# (10090, '月圆或缺', 'CN', 'CHN', [])
# ['月圆或缺']
# None
# (10091, 'YU', 'CN', 'CHN', [])
# ['YU']
# None
# (10092, 'BigBolwo', 'CN', 'CHN', ['我太难了wo'])
# ['BigBolwo', '我太难了wo']
# None
# None
# (10093, 'Claphantasia', 'CN', 'CHN', ['呼愁', '呼愁HuChou'])
# ['Claphantasia', '呼愁', '呼愁HuChou']
# None
# None
# None
# (10094, 'QianYuan', 'CN', 'CHN', ['浅渊QAQ'])
# ['QianYuan', '浅渊QAQ']
# None
# None
# (10095, 'RenuHugh', 'CN', 'CHN', ['Renu丶hugh'])
# ['RenuHugh', 'Renu丶hugh']
# None
# None
# (10096, '5641663', 'CN', 'CHN', [])
# ['5641663']
# None
# (10097, 'HuanYing', 'CN', 'CHN', ['追逐幻影'])
# ['HuanYing', '追逐幻影']
# None
# None
# (10098, 'PAC SamLebriz', 'EMEA', 'FRA', [''])
# ['PAC SamLebriz', '']
# None
# (10101, 'smilishman', 'EMEA', 'TUR', [''])
# ['smilishman', '']
# None
# (10107, 'Nagi', 'EMEA', 'FRA', [''])
# ['Nagi', '']
# None
# (10100, 'TMEY', 'EMEA', '!RL', [])
# ['TMEY']
# ('TMEY', 79808575, 'EMEA', 'CHE')
# (10103, 'Mirko3K', 'EMEA', 'ITA', [''])
# ['Mirko3K', '']
# None
# (10099, 'hecatics', 'EMEA', 'PSE', [''])
# ['hecatics', '']
# None
# (10104, 'DragonBlade', 'EMEA', 'TUR', [''])
# ['DragonBlade', '']
# None
# (10106, 'vao', 'EMEA', 'DEU', [''])
# ['vao', '']
# None
# (10102, 'crystarion', 'EMEA', 'RUS', [''])
# ['crystarion', '']
# None
# (10105, 'Ryosuke', 'EMEA', 'FRA', [''])
# ['Ryosuke', '']
# None
# (10110, '指蝶阿', 'CN', 'CHN', [])
# ['指蝶阿']
# None
# (10111, '我看你是不懂O', 'CN', 'CHN', [])
# ['我看你是不懂O']
# None
# (10114, '云顶丶智哥', 'CN', 'CHN', [])
# ['云顶丶智哥']
# None
# (10109, '超级小路10', 'CN', 'CHN', [])
# ['超级小路10']
# None
# (10113, '爱睡觉的猪猪阿', 'CN', 'CHN', [])
# ['爱睡觉的猪猪阿']
# None
# (10108, 'HarrietgLdDfM', 'CN', 'CHN', [])
# ['HarrietgLdDfM']
# None
# (10112, '冷水饮冰', 'CN', 'CHN', [])
# ['冷水饮冰']
# None
# (10115, '3Point5', 'CN', 'CHN', ['是骑着笨猪撞地球'])
# ['3Point5', '是骑着笨猪撞地球']
# None
# None
# (10124, '风起同行', 'CN', 'CHN', [])
# ['风起同行']
# None
# (10117, 'RenHongX', 'CN', 'CHN', [])
# ['RenHongX']
# None
# (10121, '卧龙凤雏da聪明', 'CN', 'CHN', [])
# ['卧龙凤雏da聪明']
# None
# (10116, '孤帆OuO', 'CN', 'CHN', [])
# ['孤帆OuO']
# None
# (10122, 'tUSPantheon', 'CN', 'CHN', [])
# ['tUSPantheon']
# None
# (10123, '云顶张同学', 'CN', 'CHN', [])
# ['云顶张同学']
# None
# (10118, 'dimiri', 'CN', 'CHN', [])
# ['dimiri']
# None
# (10119, '我会隐身呀qaq', 'CN', 'CHN', [])
# ['我会隐身呀qaq']
# None
# (10120, '小小沐偶', 'CN', 'CHN', [])
# ['小小沐偶']
# None
# (10129, 'subtitle', 'SEA', 'SGP', ['súbtítlé'])
# ['subtitle', 'súbtítlé']
# None
# None
# (10125, 'TTVBebe1112', 'SEA', 'THA', [])
# ['TTVBebe1112']
# None
# (10127, 'Kuy', 'SEA', 'THA', [])
# ['Kuy']
# None
# (10126, 'SheeepStick', 'SEA', 'SGP', [])
# ['SheeepStick']
# None
# (10130, 'Tay', 'SEA', 'THA', [])
# ['Tay']
# None
# (10131, 'Eggy', 'SEA', 'SGP', [])
# ['Eggy']
# None
# (10128, 'RizuDiff', 'SEA', 'SGP', [])
# ['RizuDiff']
# None
# (10139, '3성 문다은', 'KR', 'KOR', [])
# ['3성 문다은']
# None
# (10134, '화내면 모지리', 'KR', 'KOR', [])
# ['화내면 모지리']
# None
# (10135, '짱먹으러왔어', 'KR', 'KOR', [])
# ['짱먹으러왔어']
# None
# (10136, '최정환01', 'KR', 'KOR', [])
# ['최정환01']
# None
# (10137, '슈퍼개미 홍홍홍', 'KR', 'KOR', [])
# ['슈퍼개미 홍홍홍']
# None
# (10138, '끌벵이봉달이', 'KR', 'KOR', [])
# ['끌벵이봉달이']
# None
# (10132, 'prometheus', 'KR', 'KOR', [])
# ['prometheus']
# None
# (10133, '체스왕', 'KR', 'KOR', [])
# ['체스왕']
# None
# (10140, 'NZ White', 'CN', 'CHN', ['NZ白'])
# ['NZ White', 'NZ白']
# None
# None
# (10141, '14U1 Kulwizard', 'SEA', 'VNM', [''])
# ['14U1 Kulwizard', '']
# None
# (10142, 'Wmeng', 'CN', 'CHN', ['我梦悠长'])
# ['Wmeng', '我梦悠长']
# ('Wmeng', 88760567, None, None)
# None
# (10143, 'DZZ', 'CN', 'CHN', [''])
# ['DZZ', '']
# None
# (10144, 'LittleGiant', 'CN', 'CHN', [''])
# ['LittleGiant', '']
# None
# (10212, 'GatL1n', 'CN', 'CHN', [])
# ['GatL1n']
# None
# (10156, '这波我先吃了', 'CN', 'CHN', [])
# ['这波我先吃了']
# None
# (10159, '气赛江南', 'CN', 'CHN', ['气寒江南'])
# ['气赛江南', '气寒江南']
# None
# None
# (10165, '炮芙老公ZUNDUMA', 'CN', 'CHN', [])
# ['炮芙老公ZUNDUMA']
# None
# (10146, '二的卟三不四', 'CN', 'CHN', [])
# ['二的卟三不四']
# None
# (10189, 'Yumu丶羽目', 'CN', 'CHN', [])
# ['Yumu丶羽目']
# None
# (10188, '风掠幽蓝J', 'CN', 'CHN', [])
# ['风掠幽蓝J']
# None
# (10199, 'Wananovo', 'CN', 'CHN', ['虎牙丶晚安n', '晚安n', '晚安未闻花名', 'Wananvo', '虎牙丶晚安'])
# ['Wananovo', '虎牙丶晚安n', '晚安n', '晚安未闻花名', 'Wananvo', '虎牙丶晚安']
# None
# None
# None
# None
# ('Wananvo', 75769982, 'CN', 'CHN')
# None
# (10225, '石头人我翘里妈', 'CN', 'CHN', [])
# ['石头人我翘里妈']
# None
# (10224, '挽风如梦', 'CN', 'CHN', [])
# ['挽风如梦']
# None
# (10222, 'wild丨浪', 'CN', 'CHN', [])
# ['wild丨浪']
# None
# (10223, '憨厚的猩猩', 'CN', 'CHN', [])
# ['憨厚的猩猩']
# None
# (10221, 'zzzzombie', 'CN', 'CHN', [])
# ['zzzzombie']
# None
# (10220, 'Haruak1', 'CN', 'CHN', [])
# ['Haruak1']
# None
# (10219, 'bilibili丶夜莺s9', 'CN', 'CHN', [])
# ['bilibili丶夜莺s9']
# None
# (10218, 'ZBHRuaRua', 'CN', 'CHN', [])
# ['ZBHRuaRua']
# None
# (10217, '南工程小棋神', 'CN', 'CHN', [])
# ['南工程小棋神']
# None
# (10216, '垮不掉', 'CN', 'CHN', [])
# ['垮不掉']
# None
# (10215, '小河灵百毒不侵', 'CN', 'CHN', [])
# ['小河灵百毒不侵']
# None
# (10214, '万千鲸落', 'CN', 'CHN', [])
# ['万千鲸落']
# None
# (10150, '宁雪灬寒冬', 'CN', 'CHN', [])
# ['宁雪灬寒冬']
# None
# (10213, '尾大不掉', 'CN', 'CHN', [])
# ['尾大不掉']
# None
# (10155, 'mymisstulip', 'CN', 'CHN', [])
# ['mymisstulip']
# None
# (10181, '曾是高手', 'CN', 'CHN', [])
# ['曾是高手']
# None
# (10180, '软软超级大魔王', 'CN', 'CHN', [])
# ['软软超级大魔王']
# None
# (10179, '蕊蕊想喝AD钙', 'CN', 'CHN', [])
# ['蕊蕊想喝AD钙']
# None
# (10178, '叶知秋的大魔王', 'CN', 'CHN', [])
# ['叶知秋的大魔王']
# None
# (10177, '先脱贫后脱单', 'CN', 'CHN', [])
# ['先脱贫后脱单']
# None
# (10175, '你可以不要问吗', 'CN', 'CHN', [])
# ['你可以不要问吗']
# None
# (10174, '就酸就酸', 'CN', 'CHN', [])
# ['就酸就酸']
# None
# (10147, 'NMG丶Tongbao', 'CN', 'CHN', [])
# ['NMG丶Tongbao']
# None
# (10173, '小2丿上妞', 'CN', 'CHN', [])
# ['小2丿上妞']
# None
# (10172, '做条有海的鱼', 'CN', 'CHN', [])
# ['做条有海的鱼']
# None
# (10171, 'AI丶星辰灬', 'CN', 'CHN', [])
# ['AI丶星辰灬']
# None
# (10170, '虎牙、罗纳尔润', 'CN', 'CHN', [])
# ['虎牙、罗纳尔润']
# None
# (10169, '绝迹时代', 'CN', 'CHN', [])
# ['绝迹时代']
# None
# (10158, '约赏联动', 'CN', 'CHN', [])
# ['约赏联动']
# None
# (10166, 'vanishingact', 'CN', 'CHN', [])
# ['vanishingact']
# None
# (10211, '只想要风铃', 'CN', 'CHN', [])
# ['只想要风铃']
# None
# (10198, '5tan', 'CN', 'CHN', [])
# ['5tan']
# None
# (10210, 'VpqziB', 'CN', 'CHN', [])
# ['VpqziB']
# None
# (10157, '里蜀山妖界少主', 'CN', 'CHN', [])
# ['里蜀山妖界少主']
# None
# (10209, 'Linzhy', 'CN', 'CHN', [])
# ['Linzhy']
# None
# (10208, '南方阿戴', 'CN', 'CHN', [])
# ['南方阿戴']
# None
# (10207, '夜长丿梦还多', 'CN', 'CHN', [])
# ['夜长丿梦还多']
# None
# (10206, '雾绪z', 'CN', 'CHN', [])
# ['雾绪z']
# None
# (10200, '秦shi其鹿丶', 'CN', 'CHN', [])
# ['秦shi其鹿丶']
# None
# (10205, '对抗路勋哥', 'CN', 'CHN', [])
# ['对抗路勋哥']
# None
# (10204, '崔觉秋', 'CN', 'CHN', [])
# ['崔觉秋']
# None
# (10182, '硬糖少女303赵粤', 'CN', 'CHN', [])
# ['硬糖少女303赵粤']
# None
# (10201, '与风约', 'CN', 'CHN', [])
# ['与风约']
# None
# (10176, 'FX怠惰丶赐死剑魂', 'CN', 'CHN', [''])
# ['FX怠惰丶赐死剑魂', '']
# None
# (10190, '小心肝儿呀', 'CN', 'CHN', [])
# ['小心肝儿呀']
# None
# (10151, 'Desmos', 'CN', 'CHN', [])
# ['Desmos']
# None
# (10160, '只剩怀念kk', 'CN', 'CHN', [])
# ['只剩怀念kk']
# None
# (10153, 'Neeoss', 'CN', 'CHN', [])
# ['Neeoss']
# None
# (10148, '安静Falling丶', 'CN', 'CHN', [])
# ['安静Falling丶']
# None
# (10162, 'V5总冠军', 'CN', 'CHN', [])
# ['V5总冠军']
# None
# (10203, '轰long轰long', 'CN', 'CHN', [])
# ['轰long轰long']
# None
# (10202, '一只小卓z', 'CN', 'CHN', [])
# ['一只小卓z']
# None
# (10154, '风流剑魔英雄', 'CN', 'CHN', [])
# ['风流剑魔英雄']
# None
# (10163, '沉稳丶sea', 'CN', 'CHN', [])
# ['沉稳丶sea']
# None
# (10152, '四川godlike', 'CN', 'CHN', [])
# ['四川godlike']
# None
# (10164, '复心不负心丶', 'CN', 'CHN', [])
# ['复心不负心丶']
# None
# (10197, '小PandaOvO', 'CN', 'CHN', [])
# ['小PandaOvO']
# None
# (10161, '优殇丶心心', 'CN', 'CHN', [])
# ['优殇丶心心']
# None
# (10145, 'Siji', 'CN', 'CHN', [])
# ['Siji']
# None
# (10167, 'Promise丶烛火', 'CN', 'CHN', [])
# ['Promise丶烛火']
# None
# (10193, 'ooo琢玉ooo', 'CN', 'CHN', ['o琢玉o'])
# ['ooo琢玉ooo', 'o琢玉o']
# None
# None
# (10187, '犯罪级可爱呀丶', 'CN', 'CHN', [])
# ['犯罪级可爱呀丶']
# None
# (10191, '云遮月‖雾隐花', 'CN', 'CHN', [])
# ['云遮月‖雾隐花']
# None
# (10168, '心雨之痕', 'CN', 'CHN', [])
# ['心雨之痕']
# None
# (10192, '不机制JokerTu', 'CN', 'CHN', [])
# ['不机制JokerTu']
# None
# (10195, 'MarinanPv', 'CN', 'CHN', [])
# ['MarinanPv']
# None
# (10194, '我听见山音', 'CN', 'CHN', [])
# ['我听见山音']
# None
# (10196, '秋雨如挽歌z', 'CN', 'CHN', [])
# ['秋雨如挽歌z']
# None
# (10183, '陆子梦', 'CN', 'CHN', [])
# ['陆子梦']
# None
# (10149, 'KillerKot', 'CN', 'CHN', [])
# ['KillerKot']
# None
# (10186, '成都宋义进', 'CN', 'CHN', [])
# ['成都宋义进']
# None
# (10185, '露出坤角', 'CN', 'CHN', [])
# ['露出坤角']
# None
# (10184, 'silxsss', 'CN', 'CHN', [])
# ['silxsss']
# None
# (10241, '灭火器TuT', 'CN', 'CHN', [])
# ['灭火器TuT']
# None
# (10303, '爱吃素的贾素素', 'CN', 'CHN', [])
# ['爱吃素的贾素素']
# None
# (10302, '刘天沛你真帅', 'CN', 'CHN', [])
# ['刘天沛你真帅']
# None
# (10301, '唯胜棋手YYD', 'CN', 'CHN', [])
# ['唯胜棋手YYD']
# None
# (10289, '皮卡丘灬狗运', 'CN', 'CHN', [])
# ['皮卡丘灬狗运']
# None
# (10290, '志勋一米五', 'CN', 'CHN', [])
# ['志勋一米五']
# None
# (10265, 'krisiiiii', 'CN', 'CHN', [])
# ['krisiiiii']
# None
# (10274, 'Wantlevelto9', 'CN', 'CHN', [])
# ['Wantlevelto9']
# None
# (10273, 'Animaヽ尘', 'CN', 'CHN', [])
# ['Animaヽ尘']
# None
# (10279, 'Min4kam1Yuki', 'CN', 'CHN', [])
# ['Min4kam1Yuki']
# None
# (10259, '我可是懒大王5', 'CN', 'CHN', [])
# ['我可是懒大王5']
# None
# (10292, '春秋蝉鸣', 'CN', 'CHN', [])
# ['春秋蝉鸣']
# None
# (10300, '凡凡不烦烦烦', 'CN', 'CHN', [])
# ['凡凡不烦烦烦']
# None
# (10271, 'Huya丶三天', 'CN', 'CHN', [])
# ['Huya丶三天']
# None
# (10270, '洛小靖', 'CN', 'CHN', [])
# ['洛小靖']
# None
# (10293, '沉寂在喧嚣中', 'CN', 'CHN', [])
# ['沉寂在喧嚣中']
# None
# (10228, 'HidamariOVO', 'CN', 'CHN', [])
# ['HidamariOVO']
# None
# (10242, '误入你的甜蜜', 'CN', 'CHN', [])
# ['误入你的甜蜜']
# None
# (10254, 'Suryxin11', 'CN', 'CHN', [])
# ['Suryxin11']
# None
# (10232, 'mugi酱', 'CN', 'CHN', [])
# ['mugi酱']
# None
# (10298, '槐中诗', 'CN', 'CHN', [])
# ['槐中诗']
# None
# (10237, '林夕名秋', 'CN', 'CHN', [])
# ['林夕名秋']
# None
# (10250, '我是大井盖', 'CN', 'CHN', [])
# ['我是大井盖']
# None
# (10238, '球球你们别死了', 'CN', 'CHN', [])
# ['球球你们别死了']
# None
# (10239, 'saisai丶', 'CN', 'CHN', [])
# ['saisai丶']
# None
# (10294, 'douyu小光诺', 'CN', 'CHN', [])
# ['douyu小光诺']
# None
# (10246, '冷知冬', 'CN', 'CHN', [])
# ['冷知冬']
# None
# (10245, 'WanXing', 'CN', 'CHN', [])
# ['WanXing']
# None
# (10249, '派蒙人i', 'CN', 'CHN', [])
# ['派蒙人i']
# None
# (10226, '我为无崖子上王者', 'CN', 'CHN', [])
# ['我为无崖子上王者']
# None
# (10248, 'FYGlory丶SCXT', 'CN', 'CHN', [])
# ['FYGlory丶SCXT']
# None
# (10288, '留常鱼', 'CN', 'CHN', [])
# ['留常鱼']
# None
# (10291, '江户888', 'CN', 'CHN', [])
# ['江户888']
# None
# (10269, 'czy下棋专用号', 'CN', 'CHN', [])
# ['czy下棋专用号']
# None
# (10264, 'B站丶云顶红绿', 'CN', 'CHN', [])
# ['B站丶云顶红绿']
# None
# (10263, '对面小dai打不过', 'CN', 'CHN', [])
# ['对面小dai打不过']
# None
# (10262, '偶然ORan', 'CN', 'CHN', [])
# ['偶然ORan']
# None
# (10287, 'B站丶冲击波', 'CN', 'CHN', [])
# ['B站丶冲击波']
# None
# (10280, 'QingChen', 'CN', 'CHN', ['jayxmf丶轻尘'])
# ['QingChen', 'jayxmf丶轻尘']
# None
# None
# (10285, '虎牙丶TheONE', 'CN', 'CHN', [])
# ['虎牙丶TheONE']
# None
# (10286, '排到我都是倒霉蛋', 'CN', 'CHN', [])
# ['排到我都是倒霉蛋']
# None
# (10275, '丁世光本光', 'CN', 'CHN', [])
# ['丁世光本光']
# None
# (10276, '鸭鸭的带bang护卫', 'CN', 'CHN', [])
# ['鸭鸭的带bang护卫']
# None
# (10278, '喜鹊zZ', 'CN', 'CHN', [])
# ['喜鹊zZ']
# None
# (10282, '拉闷了', 'CN', 'CHN', [])
# ['拉闷了']
# None
# (10277, '棋布语', 'CN', 'CHN', [])
# ['棋布语']
# None
# (10240, 'Dawn、wu', 'CN', 'CHN', [])
# ['Dawn、wu']
# None
# (10272, 'Cokiy0y', 'CN', 'CHN', ['斗鱼丶cokiy0y'])
# ['Cokiy0y', '斗鱼丶cokiy0y']
# ('Cokiy0y', 12147943, 'CN', 'CHN')
# ('斗鱼丶cokiy0y', 12147943, 'CN', 'CHN')
# (10284, 'TracyJre', 'CN', 'CHN', [])
# ['TracyJre']
# None
# (10256, 'B站丶小寒喵', 'CN', 'CHN', [])
# ['B站丶小寒喵']
# None
# (10235, 'xvkdvnsw', 'CN', 'CHN', [])
# ['xvkdvnsw']
# None
# (10258, '嘉殃未央', 'CN', 'CHN', [])
# ['嘉殃未央']
# None
# (10268, '我们唯一的关系', 'CN', 'CHN', [])
# ['我们唯一的关系']
# None
# (10247, '虎牙歌神丶弃徒x', 'CN', 'CHN', [])
# ['虎牙歌神丶弃徒x']
# None
# (10257, '你Y的126', 'CN', 'CHN', [])
# ['你Y的126']
# None
# (10229, '郭小白', 'CN', 'CHN', [])
# ['郭小白']
# None
# (10297, 'NT、Sjlife', 'CN', 'CHN', [])
# ['NT、Sjlife']
# None
# (10255, 'YD狂浪生', 'CN', 'CHN', [])
# ['YD狂浪生']
# None
# (10231, '赏金猎人团', 'CN', 'CHN', [])
# ['赏金猎人团']
# None
# (10283, '我不认识你们哦', 'CN', 'CHN', [])
# ['我不认识你们哦']
# None
# (10261, 'Yebaiy', 'CN', 'CHN', [])
# ['Yebaiy']
# None
# (10267, '古月不会上', 'CN', 'CHN', [])
# ['古月不会上']
# None
# (10299, 'McGee99', 'CN', 'CHN', ['斗鱼丶麦基99'])
# ['McGee99', '斗鱼丶麦基99']
# ('McGee99', 64261875, 'CN', 'CHN')
# ('斗鱼丶麦基99', 64261875, 'CN', 'CHN')
# (10230, '消费', 'CN', 'CHN', ['9471398特训员飞'])
# ['消费', '9471398特训员飞']
# ('消费', 78811838, 'CN', 'CHN')
# ('9471398特训员飞', 37509155, 'CN', 'CHN')
# (10307, '微风C', 'CN', 'CHN', [])
# ['微风C']
# None
# (10296, '1214丶以父之名', 'CN', 'CHN', [])
# ['1214丶以父之名']
# None
# (10306, '空心', 'CN', 'CHN', [])
# ['空心']
# None
# (10305, '我带月宝上王者', 'CN', 'CHN', [])
# ['我带月宝上王者']
# None
# (10253, 'KCIST', 'CN', 'CHN', [])
# ['KCIST']
# None
# (10243, '无敌电闪暴风龙王', 'CN', 'CHN', [])
# ['无敌电闪暴风龙王']
# None
# (10281, 'ScratchYouNipple', 'CN', 'CHN', [])
# ['ScratchYouNipple']
# None
# (10233, 'WonThree', 'CN', 'CHN', [])
# ['WonThree']
# None
# (10252, 'zswwwsz', 'CN', 'CHN', [])
# ['zswwwsz']
# None
# (10295, '悲伤小海豹', 'CN', 'CHN', [])
# ['悲伤小海豹']
# None
# (10260, '再也不怨一次', 'CN', 'CHN', [])
# ['再也不怨一次']
# ('再也不怨一次', 58989993, 'CN', 'CHN')
# (10244, '我很虾头', 'CN', 'CHN', [])
# ['我很虾头']
# None
# (10266, 'MilkMe', 'CN', 'CHN', [])
# ['MilkMe']
# ('MilkMe', 59335813, 'CN', 'CHN')
# (10234, '阿灿', 'CN', 'CHN', ['斗鱼冲分大赛阿灿'])
# ['阿灿', '斗鱼冲分大赛阿灿']
# None
# None
# (10227, '超级小路', 'CN', 'CHN', [])
# ['超级小路']
# None
# (10251, 'Jiaheng想上大学', 'CN', 'CHN', [])
# ['Jiaheng想上大学']
# None
# (10304, '斗鱼冲分大赛销灭', 'CN', 'CHN', [])
# ['斗鱼冲分大赛销灭']
# None
# (10236, '不听不问不念不想', 'CN', 'CHN', [])
# ['不听不问不念不想']
# None

# %%
# puts all the region/countries down for ids that exist
from sqlalchemy import create_engine, text
import os

# Setup database connection
db_name = os.getenv("DB_NAME")
db_user = os.getenv("DB_USER")
db_password = os.getenv("DB_PASSWORD")
db_host = os.getenv("DB_HOST")

# Create engine for the database
engine_db_host = create_engine(
    f"postgresql+psycopg2://{db_user}:{db_password}@{db_host}/{db_name}"
)

# Query for rows with NULL region or country
with engine_db_host.begin() as connection_db_host:
    # Step 1: Fetch rows with NULL region or country
    query_nulls = text("""
        SELECT player_name, player_id, region, country
        FROM tbl_player_aliases
        WHERE region IS NULL OR country IS NULL
    """)
    null_results = connection_db_host.execute(query_nulls).fetchall()

    # Process each row with nulls
    for row in null_results:
        player_name, player_id, region, country = row
        print(f"Processing: player_id={player_id}, player_name={player_name}, region={region}, country={country}")

        # Step 2: Look for rows with the same player_id that have non-null region and country
        query_non_nulls = text("""
            SELECT region, country
            FROM tbl_player_aliases
            WHERE player_id = :player_id
            AND region IS NOT NULL AND country IS NOT NULL
        """)
        non_null_result = connection_db_host.execute(query_non_nulls, {"player_id": player_id}).fetchone()

        # Step 3: If a row with the same player_id and non-null region/country exists, update the current row
        if non_null_result:
            non_null_region, non_null_country = non_null_result
            print(f"Found non-null values for player_id={player_id}: region={non_null_region}, country={non_null_country}")

            # Step 4: Update the row with the non-null region/country
            query_update = text("""
                UPDATE tbl_player_aliases
                SET region = :region, country = :country
                WHERE player_id = :player_id AND (region IS NULL OR country IS NULL)
            """)
            connection_db_host.execute(query_update, {
                "region": non_null_region,
                "country": non_null_country,
                "player_id": player_id
            })
            print(f"Updated: player_id={player_id} with region={non_null_region}, country={non_null_country}")
        else:
            print(f"No non-null region/country found for player_id={player_id}")
# Out:
# Processing: player_id=45665142, player_name=Riverx, region=None, country=None
# No non-null region/country found for player_id=45665142
# Processing: player_id=13945082, player_name=mogumoguyummy, region=None, country=None
# No non-null region/country found for player_id=13945082
# Processing: player_id=62741729, player_name=Carelessd, region=None, country=None
# No non-null region/country found for player_id=62741729
# Processing: player_id=63079728, player_name=SealkunMbappe, region=None, country=None
# Found non-null values for player_id=63079728: region=LA, country=COL
# Updated: player_id=63079728 with region=LA, country=COL
# Processing: player_id=63079728, player_name=SealKun Mbappe, region=None, country=None
# Found non-null values for player_id=63079728: region=LA, country=COL
# Updated: player_id=63079728 with region=LA, country=COL
# Processing: player_id=27993639, player_name=socks, region=None, country=None
# Found non-null values for player_id=27993639: region=NA, country=USA
# Updated: player_id=27993639 with region=NA, country=USA
# Processing: player_id=78502757, player_name=Lab 02 Dinodan, region=None, country=None
# No non-null region/country found for player_id=78502757
# Processing: player_id=49277320, player_name=Ala, region=None, country=None
# No non-null region/country found for player_id=49277320
# Processing: player_id=91380292, player_name=MoGG, region=None, country=None
# No non-null region/country found for player_id=91380292
# Processing: player_id=75409583, player_name=Rakki Ryu, region=None, country=None
# No non-null region/country found for player_id=75409583
# Processing: player_id=94913771, player_name=NiihiI, region=None, country=None
# No non-null region/country found for player_id=94913771
# Processing: player_id=36140255, player_name=JNO Kahdei, region=None, country=None
# Found non-null values for player_id=36140255: region=OCE, country=AUS
# Updated: player_id=36140255 with region=OCE, country=AUS
# Processing: player_id=34485932, player_name=phura, region=None, country=None
# No non-null region/country found for player_id=34485932
# Processing: player_id=61422875, player_name=MecLove, region=None, country=None
# No non-null region/country found for player_id=61422875
# Processing: player_id=61422875, player_name=Meclove, region=None, country=None
# No non-null region/country found for player_id=61422875
# Processing: player_id=15482264, player_name=Slayingshot, region=None, country=None
# No non-null region/country found for player_id=15482264
# Processing: player_id=52821891, player_name=MILK, region=None, country=None
# Found non-null values for player_id=52821891: region=NA, country=USA
# Updated: player_id=52821891 with region=NA, country=USA
# Processing: player_id=95747627, player_name=Ripple, region=None, country=None
# No non-null region/country found for player_id=95747627
# Processing: player_id=69439183, player_name=KiBi, region=None, country=None
# No non-null region/country found for player_id=69439183
# Processing: player_id=33585192, player_name=TOR MAIKEL, region=None, country=None
# No non-null region/country found for player_id=33585192
# Processing: player_id=60482545, player_name=TOR Relic, region=None, country=None
# Found non-null values for player_id=60482545: region=LA, country=VEN
# Updated: player_id=60482545 with region=LA, country=VEN
# Processing: player_id=44404838, player_name=RFG JasonLin24, region=None, country=None
# No non-null region/country found for player_id=44404838
# Processing: player_id=68742490, player_name=junglebook1, region=None, country=None
# No non-null region/country found for player_id=68742490
# Processing: player_id=89676046, player_name=Tx Venomancer, region=None, country=None
# No non-null region/country found for player_id=89676046
# Processing: player_id=26426339, player_name=iseo3, region=None, country=None
# No non-null region/country found for player_id=26426339
# Processing: player_id=12893237, player_name=FORA Onlyteemo, region=None, country=None
# No non-null region/country found for player_id=12893237
# Processing: player_id=97650888, player_name=ZETA title, region=None, country=None
# No non-null region/country found for player_id=97650888
# Processing: player_id=12596280, player_name=myrostik, region=None, country=None
# No non-null region/country found for player_id=12596280
# Processing: player_id=79038099, player_name=GK vclf, region=None, country=None
# Found non-null values for player_id=79038099: region=BR, country=BRA
# Updated: player_id=79038099 with region=BR, country=BRA
# Processing: player_id=80845808, player_name=Kulwizard, region=None, country=None
# No non-null region/country found for player_id=80845808
# Processing: player_id=60380675, player_name=SOJU setsuko, region=None, country=None
# Found non-null values for player_id=60380675: region=NA, country=USA
# Updated: player_id=60380675 with region=NA, country=USA
# Processing: player_id=80326192, player_name=SALAD, region=None, country=None
# No non-null region/country found for player_id=80326192
# Processing: player_id=21911552, player_name=Anx TFT, region=None, country=None
# No non-null region/country found for player_id=21911552
# Processing: player_id=88090548, player_name=Chengo TFT, region=None, country=None
# No non-null region/country found for player_id=88090548
# Processing: player_id=99432668, player_name=INF HR Rudyck, region=None, country=None
# Found non-null values for player_id=99432668: region=LA, country=MEX
# Updated: player_id=99432668 with region=LA, country=MEX
# Processing: player_id=38944922, player_name=Sully TFT, region=None, country=None
# Found non-null values for player_id=38944922: region=NA, country=USA
# Updated: player_id=38944922 with region=NA, country=USA
# Processing: player_id=47121441, player_name=MarcelP, region=None, country=None
# Found non-null values for player_id=47121441: region=NA, country=USA
# Updated: player_id=47121441 with region=NA, country=USA
# Processing: player_id=47121441, player_name=Marcel P1, region=None, country=None
# Found non-null values for player_id=47121441: region=NA, country=USA
# Updated: player_id=47121441 with region=NA, country=USA
# Processing: player_id=47393839, player_name=TOR Rereplay, region=None, country=None
# Found non-null values for player_id=47393839: region=NA, country=USA
# Updated: player_id=47393839 with region=NA, country=USA
# Processing: player_id=47393839, player_name=TL Rereplay, region=None, country=None
# Found non-null values for player_id=47393839: region=NA, country=USA
# Updated: player_id=47393839 with region=NA, country=USA
# Processing: player_id=4760750, player_name=INF HR Laplace, region=None, country=None
# No non-null region/country found for player_id=4760750
# Processing: player_id=35014403, player_name=VSPO LiShao, region=None, country=None
# Found non-null values for player_id=35014403: region=CN, country=CHN
# Updated: player_id=35014403 with region=CN, country=CHN
# Processing: player_id=78647039, player_name=Darth Nub, region=None, country=None
# No non-null region/country found for player_id=78647039
# Processing: player_id=99439453, player_name=DavidAs, region=None, country=None
# Found non-null values for player_id=99439453: region=LA, country=MEX
# Updated: player_id=99439453 with region=LA, country=MEX
# Processing: player_id=89887027, player_name=Lazuli, region=None, country=None
# No non-null region/country found for player_id=89887027
# Processing: player_id=31593866, player_name=INF HR Pino, region=None, country=None
# Found non-null values for player_id=31593866: region=LA, country=MEX
# Updated: player_id=31593866 with region=LA, country=MEX
# Processing: player_id=31593866, player_name=INF HR SuperPino, region=None, country=None
# Found non-null values for player_id=31593866: region=LA, country=MEX
# Updated: player_id=31593866 with region=LA, country=MEX
# Processing: player_id=42025048, player_name=leofloresdiscor, region=None, country=None
# No non-null region/country found for player_id=42025048
# Processing: player_id=76659502, player_name=TBD LiTuChuan, region=None, country=None
# Found non-null values for player_id=76659502: region=CN, country=CHN
# Updated: player_id=76659502 with region=CN, country=CHN
# Processing: player_id=75619160, player_name=roffs, region=None, country=None
# No non-null region/country found for player_id=75619160
# Processing: player_id=56932882, player_name=Tacca TFT, region=None, country=None
# Found non-null values for player_id=56932882: region=LA, country=COL
# Updated: player_id=56932882 with region=LA, country=COL
# Processing: player_id=9231308, player_name=Lab003 Broseph, region=None, country=None
# Found non-null values for player_id=9231308: region=NA, country=CAN
# Updated: player_id=9231308 with region=NA, country=CAN
# Processing: player_id=91277084, player_name=EINS Sologesang, region=None, country=None
# Found non-null values for player_id=91277084: region=EMEA, country=DEU
# Updated: player_id=91277084 with region=EMEA, country=DEU
# Processing: player_id=60428842, player_name=bublz, region=None, country=None
# No non-null region/country found for player_id=60428842
# Processing: player_id=49412699, player_name=plumbum, region=None, country=None
# No non-null region/country found for player_id=49412699
# Processing: player_id=87380072, player_name=GK Bapzera, region=None, country=None
# Found non-null values for player_id=87380072: region=BR, country=BRA
# Updated: player_id=87380072 with region=BR, country=BRA
# Processing: player_id=87380072, player_name=Bapzera, region=None, country=None
# Found non-null values for player_id=87380072: region=BR, country=BRA
# Updated: player_id=87380072 with region=BR, country=BRA
# Processing: player_id=82491627, player_name=salty, region=None, country=None
# No non-null region/country found for player_id=82491627
# Processing: player_id=98348651, player_name=TL grea, region=None, country=None
# Found non-null values for player_id=98348651: region=NA, country=USA
# Updated: player_id=98348651 with region=NA, country=USA
# Processing: player_id=87501644, player_name=phimas, region=None, country=None
# No non-null region/country found for player_id=87501644
# Processing: player_id=34156606, player_name=chirrrrrrrup, region=None, country=None
# No non-null region/country found for player_id=34156606
# Processing: player_id=99201566, player_name=TM 60second, region=None, country=None
# Found non-null values for player_id=99201566: region=CN, country=CHN
# Updated: player_id=99201566 with region=CN, country=CHN
# Processing: player_id=27050154, player_name=Pizza TFT, region=None, country=None
# No non-null region/country found for player_id=27050154
# Processing: player_id=82693489, player_name=KC Wet Jungler, region=None, country=None
# No non-null region/country found for player_id=82693489
# Processing: player_id=56188609, player_name=Ladyluck, region=None, country=None
# No non-null region/country found for player_id=56188609
# Processing: player_id=24524712, player_name=T1 Binteum, region=None, country=None
# Found non-null values for player_id=24524712: region=KR, country=KOR
# Updated: player_id=24524712 with region=KR, country=KOR
# Processing: player_id=54530476, player_name=INF HR Hyper, region=None, country=None
# No non-null region/country found for player_id=54530476
# Processing: player_id=65134436, player_name=DLGODOFDEATH, region=None, country=None
# No non-null region/country found for player_id=65134436
# Processing: player_id=65134436, player_name=DLGOD0FDEATH, region=None, country=None
# No non-null region/country found for player_id=65134436
# Processing: player_id=96212203, player_name=bandit, region=None, country=None
# No non-null region/country found for player_id=96212203
# Processing: player_id=19677080, player_name=kpk618, region=None, country=None
# No non-null region/country found for player_id=19677080
# Processing: player_id=25440898, player_name=DUSKiagoraJose, region=None, country=None
# No non-null region/country found for player_id=25440898
# Processing: player_id=74726477, player_name=Mistborn, region=None, country=None
# No non-null region/country found for player_id=74726477
# Processing: player_id=68476926, player_name=Ganga, region=None, country=None
# No non-null region/country found for player_id=68476926
# Processing: player_id=71475153, player_name=TFT Yoni, region=None, country=None
# No non-null region/country found for player_id=71475153
# Processing: player_id=15819722, player_name=yosoymainjo, region=None, country=None
# No non-null region/country found for player_id=15819722
# Processing: player_id=54274152, player_name=Tanjo, region=None, country=None
# No non-null region/country found for player_id=54274152
# Processing: player_id=92055192, player_name=MEYOU, region=None, country=None
# No non-null region/country found for player_id=92055192
# Processing: player_id=82354990, player_name=tbone, region=None, country=None
# No non-null region/country found for player_id=82354990
# Processing: player_id=86779357, player_name=Proto TFT, region=None, country=None
# No non-null region/country found for player_id=86779357
# Processing: player_id=32155263, player_name=CST arzoo, region=None, country=None
# Found non-null values for player_id=32155263: region=EMEA, country=TUN
# Updated: player_id=32155263 with region=EMEA, country=TUN
# Processing: player_id=35585319, player_name=3p1c, region=None, country=None
# No non-null region/country found for player_id=35585319
# Processing: player_id=15300237, player_name=VIT prestivent, region=None, country=None
# Found non-null values for player_id=15300237: region=NA, country=USA
# Updated: player_id=15300237 with region=NA, country=USA
# Processing: player_id=56499595, player_name=Jasonhu234, region=None, country=None
# No non-null region/country found for player_id=56499595
# Processing: player_id=38614600, player_name=XtheFarmerX, region=None, country=None
# No non-null region/country found for player_id=38614600
# Processing: player_id=25168320, player_name=Altenahue TFT, region=None, country=None
# Found non-null values for player_id=25168320: region=LA, country=ARG
# Updated: player_id=25168320 with region=LA, country=ARG
# Processing: player_id=26350985, player_name=Liquid ego, region=None, country=None
# No non-null region/country found for player_id=26350985
# Processing: player_id=42992093, player_name=53414D TFT, region=None, country=None
# No non-null region/country found for player_id=42992093
# Processing: player_id=32865388, player_name=a1t1k, region=None, country=None
# No non-null region/country found for player_id=32865388
# Processing: player_id=19892013, player_name=tintt, region=None, country=None
# No non-null region/country found for player_id=19892013
# Processing: player_id=56319592, player_name=Tarmyshane, region=None, country=None
# No non-null region/country found for player_id=56319592
# Processing: player_id=44883905, player_name=ohmy90, region=None, country=None
# No non-null region/country found for player_id=44883905
# Processing: player_id=34109504, player_name=VenomWM, region=None, country=None
# No non-null region/country found for player_id=34109504
# Processing: player_id=94154485, player_name=dudu, region=None, country=None
# Found non-null values for player_id=94154485: region=BR, country=BRA
# Updated: player_id=94154485 with region=BR, country=BRA
# Processing: player_id=1453309, player_name=Cheney, region=None, country=None
# No non-null region/country found for player_id=1453309
# Processing: player_id=99645825, player_name=TORONTOTOKYO, region=None, country=None
# No non-null region/country found for player_id=99645825
# Processing: player_id=99645825, player_name=TORONTO TOKYO, region=None, country=None
# No non-null region/country found for player_id=99645825
# Processing: player_id=99645825, player_name=TORONTOTOKYOTFT, region=None, country=None
# No non-null region/country found for player_id=99645825
# Processing: player_id=39442765, player_name=caoMei, region=None, country=None
# Found non-null values for player_id=39442765: region=BR, country=BRA
# Updated: player_id=39442765 with region=BR, country=BRA
# Processing: player_id=59668233, player_name=JDG A Hao ei, region=None, country=None
# No non-null region/country found for player_id=59668233
# Processing: player_id=71131590, player_name=Dominus, region=None, country=None
# No non-null region/country found for player_id=71131590
# Processing: player_id=94220234, player_name=TBD Ningli, region=None, country=None
# Found non-null values for player_id=94220234: region=CN, country=CHN
# Updated: player_id=94220234 with region=CN, country=CHN
# Processing: player_id=6233667, player_name=cn werid TFT, region=None, country=None
# No non-null region/country found for player_id=6233667
# Processing: player_id=19998701, player_name=thybeaster, region=None, country=None
# No non-null region/country found for player_id=19998701
# Processing: player_id=18542480, player_name=GGuthix, region=None, country=None
# Found non-null values for player_id=18542480: region=LA, country=CRI
# Updated: player_id=18542480 with region=LA, country=CRI
# Processing: player_id=38364604, player_name=FNC Kiyoon, region=None, country=None
# Found non-null values for player_id=38364604: region=NA, country=CAN
# Updated: player_id=38364604 with region=NA, country=CAN
# Processing: player_id=50336755, player_name=nxte, region=None, country=None
# No non-null region/country found for player_id=50336755
# Processing: player_id=23493906, player_name=TheMagykal, region=None, country=None
# No non-null region/country found for player_id=23493906
# Processing: player_id=85019126, player_name=TFT Xbm0ts, region=None, country=None
# No non-null region/country found for player_id=85019126
# Processing: player_id=44385241, player_name=Dayang, region=None, country=None
# No non-null region/country found for player_id=44385241
# Processing: player_id=94817577, player_name=Darvinism, region=None, country=None
# No non-null region/country found for player_id=94817577
# Processing: player_id=34971509, player_name=Lab039erinkuma, region=None, country=None
# Found non-null values for player_id=34971509: region=NA, country=USA
# Updated: player_id=34971509 with region=NA, country=USA
# Processing: player_id=89259668, player_name=ms gwen, region=None, country=None
# No non-null region/country found for player_id=89259668
# Processing: player_id=94871721, player_name=Bossoskills, region=None, country=None
# Found non-null values for player_id=94871721: region=NA, country=USA
# Updated: player_id=94871721 with region=NA, country=USA
# Processing: player_id=86007903, player_name=syz, region=None, country=None
# No non-null region/country found for player_id=86007903
# Processing: player_id=55860249, player_name=hsk, region=None, country=None
# No non-null region/country found for player_id=55860249
# Processing: player_id=53505410, player_name=gravyboop, region=None, country=None
# No non-null region/country found for player_id=53505410
# Processing: player_id=36601605, player_name=invectiv, region=None, country=None
# No non-null region/country found for player_id=36601605
# Processing: player_id=59697033, player_name=bruhbruhbruh, region=None, country=None
# No non-null region/country found for player_id=59697033
# Processing: player_id=28902686, player_name=TL PockyGom, region=None, country=None
# Found non-null values for player_id=28902686: region=NA, country=USA
# Updated: player_id=28902686 with region=NA, country=USA
# Processing: player_id=71256556, player_name=Tobsss, region=None, country=None
# No non-null region/country found for player_id=71256556
# Processing: player_id=13096248, player_name=PestControl, region=None, country=None
# No non-null region/country found for player_id=13096248
# Processing: player_id=98047871, player_name=Labl3r, region=None, country=None
# No non-null region/country found for player_id=98047871
# Processing: player_id=60611981, player_name=flamez, region=None, country=None
# No non-null region/country found for player_id=60611981
# Processing: player_id=17713785, player_name=Qiyuan, region=None, country=None
# No non-null region/country found for player_id=17713785
# Processing: player_id=4562381, player_name=INF HR MrMugui, region=None, country=None
# No non-null region/country found for player_id=4562381
# Processing: player_id=35879175, player_name=Proto31, region=None, country=None
# No non-null region/country found for player_id=35879175
# Processing: player_id=42130112, player_name=ocean TFT, region=None, country=None
# No non-null region/country found for player_id=42130112
# Processing: player_id=5527728, player_name=FNC wasian, region=None, country=None
# Found non-null values for player_id=5527728: region=NA, country=CAN
# Updated: player_id=5527728 with region=NA, country=CAN
# Processing: player_id=23127047, player_name=Goku, region=None, country=None
# No non-null region/country found for player_id=23127047
# Processing: player_id=92037715, player_name=bobotft, region=None, country=None
# No non-null region/country found for player_id=92037715
# Processing: player_id=13798329, player_name=Zurk, region=None, country=None
# No non-null region/country found for player_id=13798329
# Processing: player_id=90827234, player_name=JDG Flancy, region=None, country=None
# Found non-null values for player_id=90827234: region=CN, country=CHN
# Updated: player_id=90827234 with region=CN, country=CHN
# Processing: player_id=25853876, player_name=Detetive Aline, region=None, country=None
# Found non-null values for player_id=25853876: region=BR, country=BRA
# Updated: player_id=25853876 with region=BR, country=BRA
# Processing: player_id=69218414, player_name=Zeal Mint Cat, region=None, country=None
# No non-null region/country found for player_id=69218414
# Processing: player_id=53573257, player_name=pannyandrew, region=None, country=None
# No non-null region/country found for player_id=53573257
# Processing: player_id=90456838, player_name=pitzy, region=None, country=None
# Found non-null values for player_id=90456838: region=NA, country=CAN
# Updated: player_id=90456838 with region=NA, country=CAN
# Processing: player_id=89127326, player_name=Lab 010 Barney, region=None, country=None
# No non-null region/country found for player_id=89127326
# Processing: player_id=78198335, player_name=FSK kubixon, region=None, country=None
# No non-null region/country found for player_id=78198335
# Processing: player_id=29255297, player_name=pit, region=None, country=None
# No non-null region/country found for player_id=29255297
# Processing: player_id=22051257, player_name=Ayy Rick, region=None, country=None
# No non-null region/country found for player_id=22051257
# Processing: player_id=77403499, player_name=Kennethhh, region=None, country=None
# No non-null region/country found for player_id=77403499
# Processing: player_id=60380675, player_name=setsuko1#eprod, region=None, country=None
# Found non-null values for player_id=60380675: region=NA, country=USA
# Updated: player_id=60380675 with region=NA, country=USA
# Processing: player_id=38781691, player_name=k0nda1#eprod, region=None, country=None
# Found non-null values for player_id=38781691: region=BR, country=BRA
# Updated: player_id=38781691 with region=BR, country=BRA
# Processing: player_id=46592495, player_name=RYT Shaco#eprod, region=None, country=None
# Found non-null values for player_id=46592495: region=BR, country=BRA
# Updated: player_id=46592495 with region=BR, country=BRA
# Processing: player_id=46592495, player_name=Shaco, region=None, country=None
# Found non-null values for player_id=46592495: region=BR, country=BRA
# Updated: player_id=46592495 with region=BR, country=BRA
# Processing: player_id=28002550, player_name=Syrian#eprod, region=None, country=None
# Found non-null values for player_id=28002550: region=NA, country=CAN
# Updated: player_id=28002550 with region=NA, country=CAN
# Processing: player_id=94798160, player_name=Autenticos#eprod, region=None, country=None
# Found non-null values for player_id=94798160: region=LA, country=ARG
# Updated: player_id=94798160 with region=LA, country=ARG
# Processing: player_id=77458704, player_name=Neuro, region=None, country=None
# Found non-null values for player_id=77458704: region=BR, country=BRA
# Updated: player_id=77458704 with region=BR, country=BRA
# Processing: player_id=99645825, player_name=TORONTOTOKYO#eprod, region=None, country=None
# No non-null region/country found for player_id=99645825
# Processing: player_id=99645825, player_name=TORONTO TOKYO#eprod, region=None, country=None
# No non-null region/country found for player_id=99645825
# Processing: player_id=15300237, player_name=prestivent#eprod, region=None, country=None
# Found non-null values for player_id=15300237: region=NA, country=USA
# Updated: player_id=15300237 with region=NA, country=USA
# Processing: player_id=15300237, player_name=Prestivent, region=None, country=None
# Found non-null values for player_id=15300237: region=NA, country=USA
# Updated: player_id=15300237 with region=NA, country=USA
# Processing: player_id=5527728, player_name=wasianiverson#eprod, region=None, country=None
# Found non-null values for player_id=5527728: region=NA, country=CAN
# Updated: player_id=5527728 with region=NA, country=CAN
# Processing: player_id=74726477, player_name=Mistborn#eprod, region=None, country=None
# No non-null region/country found for player_id=74726477
# Processing: player_id=27811515, player_name=Copico#eprod, region=None, country=None
# Found non-null values for player_id=27811515: region=BR, country=BRA
# Updated: player_id=27811515 with region=BR, country=BRA
# Processing: player_id=80566850, player_name=Cupiditas#eprod, region=None, country=None
# Found non-null values for player_id=80566850: region=LA, country=ARG
# Updated: player_id=80566850 with region=LA, country=ARG
# Processing: player_id=48321885, player_name=vakio, region=None, country=None
# Found non-null values for player_id=48321885: region=BR, country=BRA
# Updated: player_id=48321885 with region=BR, country=BRA
# Processing: player_id=48321885, player_name=FOUR vakio#eprod, region=None, country=None
# Found non-null values for player_id=48321885: region=BR, country=BRA
# Updated: player_id=48321885 with region=BR, country=BRA
# Processing: player_id=26472673, player_name=campislife20#eprod, region=None, country=None
# Found non-null values for player_id=26472673: region=NA, country=USA
# Updated: player_id=26472673 with region=NA, country=USA
# Processing: player_id=95265227, player_name=Slooper#eprod, region=None, country=None
# Found non-null values for player_id=95265227: region=BR, country=BRA
# Updated: player_id=95265227 with region=BR, country=BRA
# Processing: player_id=53531043, player_name=TG Upsetmax#eprod, region=None, country=None
# Found non-null values for player_id=53531043: region=NA, country=CAN
# Updated: player_id=53531043 with region=NA, country=CAN
# Processing: player_id=47393839, player_name=Liquid Rereplay#eprod, region=None, country=None
# Found non-null values for player_id=47393839: region=NA, country=USA
# Updated: player_id=47393839 with region=NA, country=USA
# Processing: player_id=47393839, player_name=Rereplay, region=None, country=None
# Found non-null values for player_id=47393839: region=NA, country=USA
# Updated: player_id=47393839 with region=NA, country=USA
# Processing: player_id=2059392, player_name=INF HR SrCerdo#eprod, region=None, country=None
# Found non-null values for player_id=2059392: region=LA, country=MEX
# Updated: player_id=2059392 with region=LA, country=MEX
# Processing: player_id=2059392, player_name=SrCerdo, region=None, country=None
# Found non-null values for player_id=2059392: region=LA, country=MEX
# Updated: player_id=2059392 with region=LA, country=MEX
# Processing: player_id=65477339, player_name=INF HR Poison#eprod, region=None, country=None
# Found non-null values for player_id=65477339: region=LA, country=PER
# Updated: player_id=65477339 with region=LA, country=PER
# Processing: player_id=19677080, player_name=kpk618#eprod, region=None, country=None
# No non-null region/country found for player_id=19677080
# Processing: player_id=78647039, player_name=Darth Nub#eprod, region=None, country=None
# No non-null region/country found for player_id=78647039
# Processing: player_id=63079728, player_name=SealKun Mbappe#eprod, region=None, country=None
# Found non-null values for player_id=63079728: region=LA, country=COL
# Updated: player_id=63079728 with region=LA, country=COL
# Processing: player_id=3930687, player_name=Roontonzorg#eprod, region=None, country=None
# Found non-null values for player_id=3930687: region=NA, country=USA
# Updated: player_id=3930687 with region=NA, country=USA
# Processing: player_id=66216700, player_name=jdzielinski22#eprod, region=None, country=None
# Found non-null values for player_id=66216700: region=NA, country=USA
# Updated: player_id=66216700 with region=NA, country=USA
# Processing: player_id=18018707, player_name=hsk the onlyone#eprod, region=None, country=None
# Found non-null values for player_id=18018707: region=BR, country=BRA
# Updated: player_id=18018707 with region=BR, country=BRA
# Processing: player_id=16556367, player_name=Brucelolll#eprod, region=None, country=None
# Found non-null values for player_id=16556367: region=NA, country=CAN
# Updated: player_id=16556367 with region=NA, country=CAN
# Processing: player_id=88294036, player_name=yoohn, region=None, country=None
# Found non-null values for player_id=88294036: region=NA, country=USA
# Updated: player_id=88294036 with region=NA, country=USA
# Processing: player_id=88294036, player_name=yoohnTFT#eprod, region=None, country=None
# Found non-null values for player_id=88294036: region=NA, country=USA
# Updated: player_id=88294036 with region=NA, country=USA
# Processing: player_id=25570816, player_name=dink my oiter#eprod, region=None, country=None
# Found non-null values for player_id=25570816: region=NA, country=USA
# Updated: player_id=25570816 with region=NA, country=USA
# Processing: player_id=64059200, player_name=TexSummers#eprod, region=None, country=None
# Found non-null values for player_id=64059200: region=LA, country=ARG
# Updated: player_id=64059200 with region=LA, country=ARG
# Processing: player_id=13409018, player_name=HighPana#eprod, region=None, country=None
# Found non-null values for player_id=13409018: region=LA, country=VEN
# Updated: player_id=13409018 with region=LA, country=VEN
# Processing: player_id=50343287, player_name=MeanMisterKien#eprod, region=None, country=None
# Found non-null values for player_id=50343287: region=NA, country=USA
# Updated: player_id=50343287 with region=NA, country=USA
# Processing: player_id=59697033, player_name=Bruhbruhbruh WHO, region=None, country=None
# No non-null region/country found for player_id=59697033
# Processing: player_id=97924839, player_name=robinsongz#eprod, region=None, country=None
# Found non-null values for player_id=97924839: region=NA, country=USA
# Updated: player_id=97924839 with region=NA, country=USA
# Processing: player_id=93598861, player_name=PoppIn Jung, region=None, country=None
# No non-null region/country found for player_id=93598861
# Processing: player_id=57904488, player_name=TSphere#eprod, region=None, country=None
# Found non-null values for player_id=57904488: region=NA, country=USA
# Updated: player_id=57904488 with region=NA, country=USA
# Processing: player_id=71697138, player_name=JosueDeleted#eprod, region=None, country=None
# Found non-null values for player_id=71697138: region=LA, country=PER
# Updated: player_id=71697138 with region=LA, country=PER
# Processing: player_id=75409583, player_name=Rakki Ryu#eprod, region=None, country=None
# No non-null region/country found for player_id=75409583
# Processing: player_id=60482545, player_name=INF HR Relic#eprod, region=None, country=None
# Found non-null values for player_id=60482545: region=LA, country=VEN
# Updated: player_id=60482545 with region=LA, country=VEN
# Processing: player_id=53265302, player_name=Kurumx#eprod, region=None, country=None
# Found non-null values for player_id=53265302: region=NA, country=USA
# Updated: player_id=53265302 with region=NA, country=USA
# Processing: player_id=6233667, player_name=cn werid TFT#eprod, region=None, country=None
# No non-null region/country found for player_id=6233667
# Processing: player_id=6233667, player_name=werid, region=None, country=None
# No non-null region/country found for player_id=6233667
# Processing: player_id=27993639, player_name=MismatchedSocks#eprod, region=None, country=None
# Found non-null values for player_id=27993639: region=NA, country=USA
# Updated: player_id=27993639 with region=NA, country=USA
# Processing: player_id=13945082, player_name=mogumoguyummy#eprod, region=None, country=None
# No non-null region/country found for player_id=13945082
# Processing: player_id=56812747, player_name=wilf#eprod, region=None, country=None
# Found non-null values for player_id=56812747: region=NA, country=USA
# Updated: player_id=56812747 with region=NA, country=USA
# Processing: player_id=33110443, player_name=Cool Guy Dom#eprod, region=None, country=None
# Found non-null values for player_id=33110443: region=NA, country=USA
# Updated: player_id=33110443 with region=NA, country=USA
# Processing: player_id=52048293, player_name=AI CE TOMA#eprod, region=None, country=None
# Found non-null values for player_id=52048293: region=BR, country=BRA
# Updated: player_id=52048293 with region=BR, country=BRA
# Processing: player_id=94913771, player_name=NiihiI#eprod, region=None, country=None
# No non-null region/country found for player_id=94913771
# Processing: player_id=79038099, player_name=vclf#eprod, region=None, country=None
# Found non-null values for player_id=79038099: region=BR, country=BRA
# Updated: player_id=79038099 with region=BR, country=BRA
# Processing: player_id=82354990, player_name=tbone#eprod, region=None, country=None
# No non-null region/country found for player_id=82354990
# Processing: player_id=86548266, player_name=evil one, region=None, country=None
# Found non-null values for player_id=86548266: region=BR, country=BRA
# Updated: player_id=86548266 with region=BR, country=BRA
# Processing: player_id=54274152, player_name=Tanjo#eprod, region=None, country=None
# No non-null region/country found for player_id=54274152
# Processing: player_id=86337162, player_name=SpencerTFT#eprod, region=None, country=None
# Found non-null values for player_id=86337162: region=NA, country=CAN
# Updated: player_id=86337162 with region=NA, country=CAN
# Processing: player_id=31449829, player_name=eusouolucas#eprod, region=None, country=None
# Found non-null values for player_id=31449829: region=BR, country=BRA
# Updated: player_id=31449829 with region=BR, country=BRA
# Processing: player_id=19549918, player_name=Tarteman, region=None, country=None
# Found non-null values for player_id=19549918: region=EMEA, country=FRA
# Updated: player_id=19549918 with region=EMEA, country=FRA
# Processing: player_id=97517510, player_name=Aerodynamicks#eprod, region=None, country=None
# Found non-null values for player_id=97517510: region=NA, country=USA
# Updated: player_id=97517510 with region=NA, country=USA
# Processing: player_id=57675094, player_name=Cambulee#eprod, region=None, country=None
# Found non-null values for player_id=57675094: region=NA, country=USA
# Updated: player_id=57675094 with region=NA, country=USA
# Processing: player_id=10135535, player_name=ISG MAIKEL#eprod, region=None, country=None
# Found non-null values for player_id=10135535: region=LA, country=CHL
# Updated: player_id=10135535 with region=LA, country=CHL
# Processing: player_id=10135535, player_name=MAIKEL, region=None, country=None
# Found non-null values for player_id=10135535: region=LA, country=CHL
# Updated: player_id=10135535 with region=LA, country=CHL
# Processing: player_id=34175457, player_name=Koala Esbelto#eprod, region=None, country=None
# Found non-null values for player_id=34175457: region=BR, country=BRA
# Updated: player_id=34175457 with region=BR, country=BRA
# Processing: player_id=4185469, player_name=k3soju1#eprod, region=None, country=None
# Found non-null values for player_id=4185469: region=NA, country=USA
# Updated: player_id=4185469 with region=NA, country=USA
# Processing: player_id=94817577, player_name=Darvinism#eprod, region=None, country=None
# No non-null region/country found for player_id=94817577
# Processing: player_id=5326533, player_name=Aesah#eprod, region=None, country=None
# Found non-null values for player_id=5326533: region=NA, country=USA
# Updated: player_id=5326533 with region=NA, country=USA
# Processing: player_id=80917561, player_name=Stellar Minhee#eprod, region=None, country=None
# Found non-null values for player_id=80917561: region=NA, country=CAN
# Updated: player_id=80917561 with region=NA, country=CAN
# Processing: player_id=82753959, player_name=i agr Jose, region=None, country=None
# Found non-null values for player_id=82753959: region=BR, country=BRA
# Updated: player_id=82753959 with region=BR, country=BRA
# Processing: player_id=82753959, player_name=DUSK i agr Jose#eprod, region=None, country=None
# Found non-null values for player_id=82753959: region=BR, country=BRA
# Updated: player_id=82753959 with region=BR, country=BRA
# Processing: player_id=18542480, player_name=GGuthix#eprod, region=None, country=None
# Found non-null values for player_id=18542480: region=LA, country=CRI
# Updated: player_id=18542480 with region=LA, country=CRI
# Processing: player_id=87651887, player_name=Black Sheep#eprod, region=None, country=None
# Found non-null values for player_id=87651887: region=LA, country=URY
# Updated: player_id=87651887 with region=LA, country=URY
# Processing: player_id=94772009, player_name=LadderSlayer#eprod, region=None, country=None
# Found non-null values for player_id=94772009: region=NA, country=USA
# Updated: player_id=94772009 with region=NA, country=USA
# Processing: player_id=92055192, player_name=MEYOU#eprod, region=None, country=None
# No non-null region/country found for player_id=92055192
# Processing: player_id=38944922, player_name=Sully TFT#eprod, region=None, country=None
# Found non-null values for player_id=38944922: region=NA, country=USA
# Updated: player_id=38944922 with region=NA, country=USA
# Processing: player_id=68476926, player_name=Ganga#eprod, region=None, country=None
# No non-null region/country found for player_id=68476926
# Processing: player_id=54530476, player_name=INF HR Hyper#eprod, region=None, country=None
# No non-null region/country found for player_id=54530476
# Processing: player_id=54530476, player_name=Hyper, region=None, country=None
# No non-null region/country found for player_id=54530476
# Processing: player_id=9591235, player_name=Groxie#eprod, region=None, country=None
# Found non-null values for player_id=9591235: region=NA, country=USA
# Updated: player_id=9591235 with region=NA, country=USA
# Processing: player_id=34073133, player_name=DUSK Nareba#eprod, region=None, country=None
# Found non-null values for player_id=34073133: region=BR, country=BRA
# Updated: player_id=34073133 with region=BR, country=BRA
# Processing: player_id=34073133, player_name=Nareba, region=None, country=None
# Found non-null values for player_id=34073133: region=BR, country=BRA
# Updated: player_id=34073133 with region=BR, country=BRA
# Processing: player_id=57092726, player_name=thekrayc, region=None, country=None
# Found non-null values for player_id=57092726: region=NA, country=USA
# Updated: player_id=57092726 with region=NA, country=USA
# Processing: player_id=57092726, player_name=TTV thekrayc#eprod, region=None, country=None
# Found non-null values for player_id=57092726: region=NA, country=USA
# Updated: player_id=57092726 with region=NA, country=USA
# Processing: player_id=32953490, player_name=ViciuuSS#eprod, region=None, country=None
# Found non-null values for player_id=32953490: region=LA, country=ARG
# Updated: player_id=32953490 with region=LA, country=ARG
# Processing: player_id=94843903, player_name=robivankenob#eprod, region=None, country=None
# Found non-null values for player_id=94843903: region=NA, country=CAN
# Updated: player_id=94843903 with region=NA, country=CAN
# Processing: player_id=61422875, player_name=MecLove#eprod, region=None, country=None
# No non-null region/country found for player_id=61422875
# Processing: player_id=60566694, player_name=ItachiTFT#eprod, region=None, country=None
# Found non-null values for player_id=60566694: region=BR, country=BRA
# Updated: player_id=60566694 with region=BR, country=BRA
# Processing: player_id=72404566, player_name=InvadersMD#eprod, region=None, country=None
# Found non-null values for player_id=72404566: region=LA, country=ARG
# Updated: player_id=72404566 with region=LA, country=ARG
# Processing: player_id=31593866, player_name=INF HR SuperPino#eprod, region=None, country=None
# Found non-null values for player_id=31593866: region=LA, country=MEX
# Updated: player_id=31593866 with region=LA, country=MEX
# Processing: player_id=77884674, player_name=Weklet#eprod, region=None, country=None
# Found non-null values for player_id=77884674: region=NA, country=USA
# Updated: player_id=77884674 with region=NA, country=USA
# Processing: player_id=98348651, player_name=grea#eprod, region=None, country=None
# Found non-null values for player_id=98348651: region=NA, country=USA
# Updated: player_id=98348651 with region=NA, country=USA
# Processing: player_id=87380072, player_name=FORA Bapzera#eprod, region=None, country=None
# Found non-null values for player_id=87380072: region=BR, country=BRA
# Updated: player_id=87380072 with region=BR, country=BRA
# Processing: player_id=40909198, player_name=Miguel Arkjow#eprod, region=None, country=None
# Found non-null values for player_id=40909198: region=BR, country=BRA
# Updated: player_id=40909198 with region=BR, country=BRA
# Processing: player_id=99432668, player_name=INF HR Rudyck#eprod, region=None, country=None
# Found non-null values for player_id=99432668: region=LA, country=MEX
# Updated: player_id=99432668 with region=LA, country=MEX
# Processing: player_id=87501644, player_name=phimas#eprod, region=None, country=None
# No non-null region/country found for player_id=87501644
# Processing: player_id=12224297, player_name=ISG Cheche#eprod, region=None, country=None
# Found non-null values for player_id=12224297: region=LA, country=ARG
# Updated: player_id=12224297 with region=LA, country=ARG
# Processing: player_id=89259668, player_name=ms gwen#eprod, region=None, country=None
# No non-null region/country found for player_id=89259668
# Processing: player_id=42025048, player_name=leofloresdiscor#eprod, region=None, country=None
# No non-null region/country found for player_id=42025048
# Processing: player_id=79071072, player_name=Triple8s#eprod, region=None, country=None
# Found non-null values for player_id=79071072: region=NA, country=USA
# Updated: player_id=79071072 with region=NA, country=USA
# Processing: player_id=12893237, player_name=FORA Onlyteemo#eprod, region=None, country=None
# No non-null region/country found for player_id=12893237
# Processing: player_id=12893237, player_name=Onlyteemo, region=None, country=None
# No non-null region/country found for player_id=12893237
# Processing: player_id=93221102, player_name=Kaiweng#eprod, region=None, country=None
# Found non-null values for player_id=93221102: region=NA, country=USA
# Updated: player_id=93221102 with region=NA, country=USA
# Processing: player_id=92384638, player_name=JesusTeemo#eprod, region=None, country=None
# Found non-null values for player_id=92384638: region=NA, country=USA
# Updated: player_id=92384638 with region=NA, country=USA
# Processing: player_id=98047871, player_name=Labl3r#eprod, region=None, country=None
# No non-null region/country found for player_id=98047871
# Processing: player_id=52821891, player_name=Milk Guy#eprod, region=None, country=None
# Found non-null values for player_id=52821891: region=NA, country=USA
# Updated: player_id=52821891 with region=NA, country=USA
# Processing: player_id=62741729, player_name=Carelessd#eprod, region=None, country=None
# No non-null region/country found for player_id=62741729
# Processing: player_id=89378295, player_name=casparwu#eprod, region=None, country=None
# Found non-null values for player_id=89378295: region=NA, country=USA
# Updated: player_id=89378295 with region=NA, country=USA
# Processing: player_id=7452180, player_name=Trebornac#eprod, region=None, country=None
# Found non-null values for player_id=7452180: region=BR, country=BRA
# Updated: player_id=7452180 with region=BR, country=BRA
# Processing: player_id=96212203, player_name=bandit#eprod, region=None, country=None
# No non-null region/country found for player_id=96212203
# Processing: player_id=32916600, player_name=tleyds#eprod, region=None, country=None
# Found non-null values for player_id=32916600: region=NA, country=USA
# Updated: player_id=32916600 with region=NA, country=USA
# Processing: player_id=49412699, player_name=plumbum#eprod, region=None, country=None
# No non-null region/country found for player_id=49412699
# Processing: player_id=55417111, player_name=So bio#eprod, region=None, country=None
# Found non-null values for player_id=55417111: region=BR, country=BRA
# Updated: player_id=55417111 with region=BR, country=BRA
# Processing: player_id=34971509, player_name=Lab039erinkuma#eprod, region=None, country=None
# Found non-null values for player_id=34971509: region=NA, country=USA
# Updated: player_id=34971509 with region=NA, country=USA
# Processing: player_id=34088022, player_name=Phoenixaa#eprod, region=None, country=None
# Found non-null values for player_id=34088022: region=NA, country=USA
# Updated: player_id=34088022 with region=NA, country=USA
# Processing: player_id=8738123, player_name=DobZ#eprod, region=None, country=None
# Found non-null values for player_id=8738123: region=BR, country=BRA
# Updated: player_id=8738123 with region=BR, country=BRA
# Processing: player_id=78198335, player_name=kubixon, region=None, country=None
# No non-null region/country found for player_id=78198335
# Processing: player_id=67222730, player_name=Filup#eprod, region=None, country=None
# Found non-null values for player_id=67222730: region=NA, country=USA
# Updated: player_id=67222730 with region=NA, country=USA
# Processing: player_id=23127047, player_name=Goku#eprod, region=None, country=None
# No non-null region/country found for player_id=23127047
# Processing: player_id=34485932, player_name=phura#eprod, region=None, country=None
# No non-null region/country found for player_id=34485932
# Processing: player_id=50866503, player_name=JukeYou#eprod, region=None, country=None
# Found non-null values for player_id=50866503: region=NA, country=USA
# Updated: player_id=50866503 with region=NA, country=USA
# Processing: player_id=71919866, player_name=MK Fizz#eprod, region=None, country=None
# Found non-null values for player_id=71919866: region=LA, country=PER
# Updated: player_id=71919866 with region=LA, country=PER
# Processing: player_id=43069266, player_name=Lab 004 Rain#eprod, region=None, country=None
# Found non-null values for player_id=43069266: region=NA, country=USA
# Updated: player_id=43069266 with region=NA, country=USA
# Processing: player_id=43069266, player_name=Rain, region=None, country=None
# Found non-null values for player_id=43069266: region=NA, country=USA
# Updated: player_id=43069266 with region=NA, country=USA
# Processing: player_id=32544720, player_name=Liquid SV#eprod, region=None, country=None
# Found non-null values for player_id=32544720: region=NA, country=USA
# Updated: player_id=32544720 with region=NA, country=USA
# Processing: player_id=90456838, player_name=pitzy#eprod, region=None, country=None
# Found non-null values for player_id=90456838: region=NA, country=CAN
# Updated: player_id=90456838 with region=NA, country=CAN
# Processing: player_id=53735694, player_name=Connerisme#eprod, region=None, country=None
# Found non-null values for player_id=53735694: region=NA, country=USA
# Updated: player_id=53735694 with region=NA, country=USA
# Processing: player_id=89827472, player_name=Toddy#eprod, region=None, country=None
# Found non-null values for player_id=89827472: region=BR, country=BRA
# Updated: player_id=89827472 with region=BR, country=BRA
# Processing: player_id=39864278, player_name=xiao dian dian#eprod, region=None, country=None
# Found non-null values for player_id=39864278: region=NA, country=CAN
# Updated: player_id=39864278 with region=NA, country=CAN
# Processing: player_id=94154485, player_name=DDUDU, region=None, country=None
# Found non-null values for player_id=94154485: region=BR, country=BRA
# Updated: player_id=94154485 with region=BR, country=BRA
# Processing: player_id=19117497, player_name=ego illusions#eprod, region=None, country=None
# Found non-null values for player_id=19117497: region=BR, country=BRA
# Updated: player_id=19117497 with region=BR, country=BRA
# ...
# No non-null region/country found for player_id=50316113
# Processing: player_id=68816778, player_name=motive, region=None, country=None
# No non-null region/country found for player_id=68816778
# Processing: player_id=58870505, player_name=夜机, region=None, country=None
# No non-null region/country found for player_id=58870505
# Processing: player_id=53445356, player_name=AlkolikAstronot, region=None, country=None
# No non-null region/country found for player_id=53445356
# Processing: player_id=61902349, player_name=NNES1, region=None, country=None
# No non-null region/country found for player_id=61902349
# Processing: player_id=58215457, player_name=SanGoFab, region=None, country=None
# No non-null region/country found for player_id=58215457
# Processing: player_id=54117256, player_name=Uaiti, region=None, country=None
# No non-null region/country found for player_id=54117256
# Processing: player_id=1527414, player_name=PGarras, region=None, country=None
# No non-null region/country found for player_id=1527414
# Processing: player_id=41848276, player_name=Fahrettingyhg, region=None, country=None
# No non-null region/country found for player_id=41848276
# Processing: player_id=46267218, player_name=kerizbatuhan, region=None, country=None
# No non-null region/country found for player_id=46267218
# Processing: player_id=81362613, player_name=Nep2une, region=None, country=None
# No non-null region/country found for player_id=81362613
# Processing: player_id=6657445, player_name=lupius, region=None, country=None
# No non-null region/country found for player_id=6657445
# Processing: player_id=19446606, player_name=Stoneweaver, region=None, country=None
# No non-null region/country found for player_id=19446606
# Processing: player_id=36428135, player_name=bielzin, region=None, country=None
# No non-null region/country found for player_id=36428135
# Processing: player_id=30217364, player_name=AiKooN, region=None, country=None
# No non-null region/country found for player_id=30217364
# Processing: player_id=42433021, player_name=tycoon, region=None, country=None
# No non-null region/country found for player_id=42433021
# Processing: player_id=38691821, player_name=Natasha2008SPB, region=None, country=None
# No non-null region/country found for player_id=38691821
# Processing: player_id=99388034, player_name=WaterAsChase, region=None, country=None
# No non-null region/country found for player_id=99388034
# Processing: player_id=61570585, player_name=shazamgamer58, region=None, country=None
# No non-null region/country found for player_id=61570585
# Processing: player_id=34906220, player_name=Fiko Baba, region=None, country=None
# No non-null region/country found for player_id=34906220
# Processing: player_id=85695, player_name=Ớt TFT, region=None, country=None
# No non-null region/country found for player_id=85695
# Processing: player_id=62880437, player_name=Faust, region=None, country=None
# No non-null region/country found for player_id=62880437
# Processing: player_id=18884958, player_name=o153580, region=None, country=None
# No non-null region/country found for player_id=18884958
# Processing: player_id=19990558, player_name=LadyWolfya, region=None, country=None
# No non-null region/country found for player_id=19990558
# Processing: player_id=4862945, player_name=carrotman, region=None, country=None
# No non-null region/country found for player_id=4862945
# Processing: player_id=91651412, player_name=Kindrd süt dilim, region=None, country=None
# No non-null region/country found for player_id=91651412
# Processing: player_id=30044164, player_name=Jura, region=None, country=None
# No non-null region/country found for player_id=30044164
# Processing: player_id=40648470, player_name=Eniavar, region=None, country=None
# No non-null region/country found for player_id=40648470
# Processing: player_id=49802113, player_name=QQz#eprod, region=None, country=None
# No non-null region/country found for player_id=49802113
# Processing: player_id=81840454, player_name=Luisito, region=None, country=None
# No non-null region/country found for player_id=81840454
# Processing: player_id=59010943, player_name=ian, region=None, country=None
# No non-null region/country found for player_id=59010943
# Processing: player_id=90038547, player_name=Jota, region=None, country=None
# No non-null region/country found for player_id=90038547
# Processing: player_id=10073970, player_name=traviscwat, region=None, country=None
# No non-null region/country found for player_id=10073970
# Processing: player_id=63667759, player_name=GanDja, region=None, country=None
# No non-null region/country found for player_id=63667759
# Processing: player_id=28093897, player_name=6dot, region=None, country=None
# No non-null region/country found for player_id=28093897
# Processing: player_id=79048320, player_name=Rest of EMEA, region=None, country=None
# No non-null region/country found for player_id=79048320
# Processing: player_id=75593965, player_name=ego, region=None, country=None
# No non-null region/country found for player_id=75593965
# Processing: player_id=85971136, player_name=Bobae, region=None, country=None
# No non-null region/country found for player_id=85971136
# Processing: player_id=39102087, player_name=Twtv kibatft, region=None, country=None
# No non-null region/country found for player_id=39102087
# Processing: player_id=77060157, player_name=koke, region=None, country=None
# No non-null region/country found for player_id=77060157
# Processing: player_id=95322531, player_name=boogiezone, region=None, country=None
# No non-null region/country found for player_id=95322531
# Processing: player_id=82534505, player_name=KingClouddy, region=None, country=None
# No non-null region/country found for player_id=82534505
# Processing: player_id=90617584, player_name=Berend, region=None, country=None
# No non-null region/country found for player_id=90617584
# Processing: player_id=71396410, player_name=elessar, region=None, country=None
# No non-null region/country found for player_id=71396410
# Processing: player_id=55313384, player_name=KiaBalo, region=None, country=None
# No non-null region/country found for player_id=55313384
# Processing: player_id=69920129, player_name=Solmeroth, region=None, country=None
# No non-null region/country found for player_id=69920129
# Processing: player_id=19628542, player_name=Kenedy Tran, region=None, country=None
# No non-null region/country found for player_id=19628542
# Processing: player_id=87135841, player_name=Chandler Bing, region=None, country=None
# No non-null region/country found for player_id=87135841
# Processing: player_id=15108907, player_name=FP0, region=None, country=None
# No non-null region/country found for player_id=15108907
# Processing: player_id=42948049, player_name=lurepy, region=None, country=None
# No non-null region/country found for player_id=42948049
# Processing: player_id=75717380, player_name=prisonbreaker1, region=None, country=None
# No non-null region/country found for player_id=75717380
# Processing: player_id=1281773, player_name=W1g4n3, region=None, country=None
# No non-null region/country found for player_id=1281773
# Processing: player_id=58975306, player_name=Danizinha, region=None, country=None
# No non-null region/country found for player_id=58975306
# Processing: player_id=15116128, player_name=thrae, region=None, country=None
# No non-null region/country found for player_id=15116128
# Processing: player_id=11963992, player_name=Attack, region=None, country=None
# No non-null region/country found for player_id=11963992
# Processing: player_id=56949140, player_name=HanXixng, region=None, country=None
# No non-null region/country found for player_id=56949140
# Processing: player_id=33113281, player_name=Bengur, region=None, country=None
# No non-null region/country found for player_id=33113281
# Processing: player_id=62925264, player_name=西兰花, region=None, country=None
# No non-null region/country found for player_id=62925264
# Processing: player_id=86330769, player_name=Pas de Bol, region=None, country=None
# No non-null region/country found for player_id=86330769
# Processing: player_id=1470834, player_name=WananN, region=None, country=None
# No non-null region/country found for player_id=1470834
# Processing: player_id=5657434, player_name=Lexist, region=None, country=None
# No non-null region/country found for player_id=5657434
# Processing: player_id=51746193, player_name=Tae2n, region=None, country=None
# No non-null region/country found for player_id=51746193
# Processing: player_id=98786245, player_name=Vueenx, region=None, country=None
# No non-null region/country found for player_id=98786245
# Processing: player_id=78876279, player_name=汇源果汁, region=None, country=None
# No non-null region/country found for player_id=78876279
# Processing: player_id=32572759, player_name=DouPi, region=None, country=None
# No non-null region/country found for player_id=32572759
# Processing: player_id=62326113, player_name=Seeking Urf, region=None, country=None
# No non-null region/country found for player_id=62326113
# Processing: player_id=89099906, player_name=OmegaRaul, region=None, country=None
# No non-null region/country found for player_id=89099906
# Processing: player_id=20129364, player_name=theonlytacocat, region=None, country=None
# No non-null region/country found for player_id=20129364
# Processing: player_id=82207347, player_name=hobnob, region=None, country=None
# No non-null region/country found for player_id=82207347
# Processing: player_id=76719749, player_name=MonuVo, region=None, country=None
# No non-null region/country found for player_id=76719749
# Processing: player_id=50320763, player_name=idle, region=None, country=None
# No non-null region/country found for player_id=50320763
# Processing: player_id=64565260, player_name=Madzi, region=None, country=None
# No non-null region/country found for player_id=64565260
# Processing: player_id=88878525, player_name=Loomykev11, region=None, country=None
# No non-null region/country found for player_id=88878525
# Processing: player_id=54482840, player_name=xiellendario, region=None, country=None
# No non-null region/country found for player_id=54482840
# Processing: player_id=95442284, player_name=NotSorryBaby, region=None, country=None
# No non-null region/country found for player_id=95442284
# Processing: player_id=38189302, player_name=Texugö, region=None, country=None
# No non-null region/country found for player_id=38189302
# Processing: player_id=61100725, player_name=Rayditz, region=None, country=None
# No non-null region/country found for player_id=61100725
# Processing: player_id=19932329, player_name=Effen, region=None, country=None
# No non-null region/country found for player_id=19932329
# Processing: player_id=54858463, player_name=Quinho, region=None, country=None
# No non-null region/country found for player_id=54858463
# Processing: player_id=40363396, player_name=chubby, region=None, country=None
# No non-null region/country found for player_id=40363396
# Processing: player_id=72190491, player_name=xplitcit, region=None, country=None
# No non-null region/country found for player_id=72190491
# Processing: player_id=24096532, player_name=Teby, region=None, country=None
# No non-null region/country found for player_id=24096532
# Processing: player_id=49229124, player_name=frayerfayter, region=None, country=None
# No non-null region/country found for player_id=49229124
# Processing: player_id=67724358, player_name=Alaycı Kuş, region=None, country=None
# No non-null region/country found for player_id=67724358
# Processing: player_id=8665788, player_name=Astroboy, region=None, country=None
# No non-null region/country found for player_id=8665788
# Processing: player_id=59175963, player_name=Shener Shên, region=None, country=None
# No non-null region/country found for player_id=59175963
# Processing: player_id=79060165, player_name=SarmeliN, region=None, country=None
# No non-null region/country found for player_id=79060165
# Processing: player_id=96202987, player_name=klein, region=None, country=None
# No non-null region/country found for player_id=96202987
# Processing: player_id=89370199, player_name=Shoshin, region=None, country=None
# No non-null region/country found for player_id=89370199
# Processing: player_id=71603464, player_name=daser20, region=None, country=None
# No non-null region/country found for player_id=71603464
# Processing: player_id=57571222, player_name=Bluffist, region=None, country=None
# No non-null region/country found for player_id=57571222
# Processing: player_id=95558136, player_name=Kimba TWL, region=None, country=None
# No non-null region/country found for player_id=95558136
# Processing: player_id=98346337, player_name=Lytux, region=None, country=None
# No non-null region/country found for player_id=98346337
# Processing: player_id=12249280, player_name=Twíce Jíhyó, region=None, country=None
# No non-null region/country found for player_id=12249280
# Processing: player_id=33644629, player_name=Arthur Fleck, region=None, country=None
# No non-null region/country found for player_id=33644629
# Processing: player_id=8855013, player_name=Pawnup, region=None, country=None
# No non-null region/country found for player_id=8855013
# Processing: player_id=15457751, player_name=zAkeno, region=None, country=None
# No non-null region/country found for player_id=15457751
# Processing: player_id=61988963, player_name=Apoca, region=None, country=None
# No non-null region/country found for player_id=61988963
# Processing: player_id=75807736, player_name=Alperen, region=None, country=None
# No non-null region/country found for player_id=75807736
# Processing: player_id=23722758, player_name=Nyxmera, region=None, country=None
# No non-null region/country found for player_id=23722758
# Processing: player_id=67080923, player_name=Yalço, region=None, country=None
# No non-null region/country found for player_id=67080923
# Processing: player_id=77206007, player_name=Musden, region=None, country=None
# No non-null region/country found for player_id=77206007
# Processing: player_id=7632133, player_name=ssaamm, region=None, country=None
# No non-null region/country found for player_id=7632133
# Processing: player_id=88420498, player_name=Poland, region=None, country=None
# No non-null region/country found for player_id=88420498
# Processing: player_id=55760400, player_name=Kåptån, region=None, country=None
# No non-null region/country found for player_id=55760400
# Processing: player_id=11302845, player_name=Bjergsen, region=None, country=None
# No non-null region/country found for player_id=11302845
# Processing: player_id=78242552, player_name=perfect Slumbers, region=None, country=None
# No non-null region/country found for player_id=78242552
# Processing: player_id=44197350, player_name=szymanskî, region=None, country=None
# No non-null region/country found for player_id=44197350
# Processing: player_id=43798548, player_name=Balandok, region=None, country=None
# No non-null region/country found for player_id=43798548
# Processing: player_id=79255166, player_name=amortikazim12, region=None, country=None
# No non-null region/country found for player_id=79255166
# Processing: player_id=69980986, player_name=Pàla, region=None, country=None
# No non-null region/country found for player_id=69980986
# Processing: player_id=86861028, player_name=The Kinhas, region=None, country=None
# No non-null region/country found for player_id=86861028
# Processing: player_id=57904222, player_name=hellzminion, region=None, country=None
# No non-null region/country found for player_id=57904222
# Processing: player_id=89186435, player_name=GSupporter, region=None, country=None
# No non-null region/country found for player_id=89186435
# Processing: player_id=24934108, player_name=Artifex, region=None, country=None
# No non-null region/country found for player_id=24934108
# Processing: player_id=62035552, player_name=Littletoof, region=None, country=None
# No non-null region/country found for player_id=62035552
# Processing: player_id=57127533, player_name=DelionClub, region=None, country=None
# No non-null region/country found for player_id=57127533
# Processing: player_id=45625583, player_name=sir blackp, region=None, country=None
# No non-null region/country found for player_id=45625583

# %%
from sqlalchemy import create_engine, text
import psycopg2
import os
from hash_tournaments import hash_player_name

db_name = os.getenv("DB_NAME")
db_user = os.getenv("DB_USER")
db_password = os.getenv("DB_PASSWORD")
db_host = os.getenv("DB_HOST")
db_name_2 = "ptft"


engine_ptft = create_engine(
    f"postgresql+psycopg2://{db_user}:{db_password}@{db_host}/{db_name_2}"
)

# Start a session with the ptft database
with engine_ptft.connect() as connection_ptft:
    # Query players from the ptft database ordered by oldest entry first
    query = text('SELECT id, name, region, country, alias FROM player ORDER BY "createdAt" ASC')
    players = connection_ptft.execute(query).fetchall()
