# %%
import requests

# URL of the API endpoint
url = "http://127.0.0.1:8080/tournaments/?id=6893910"

# Parameters to be sent with the request
params = {
    'has_detail': 'TFTourneys'
}

# Making the GET request
response = requests.get(url, params=params)

response.json()
# Out:
# {'tournament_id': 6893910,
#  'tournament_name': 'Inkborn Fables: Americas Golden Spatula',
#  'start_date': '2024-07-05',
#  'end_date': '2024-07-07',
#  'prize_pool': '$50,000',
#  'region': 'Americas',
#  'num_participants': 32,
#  'tier': 'A',
#  'patch': None,
#  'game_mode': None,
#  'event_type': None,
#  'format': None,
#  'liquipedia_link': 'https://liquipedia.net/tft/Inkborn_Fables/Americas/Golden_Spatula',
#  'set': 'Inkborn Fables',
#  'has_detail': True,
#  'live': False,
#  'days': [{'standings': {'TexSummers': 21,
#     'socks': 31,
#     'DavidAs': 23,
#     'Slooper': 25,
#     'GK vclf': 17,
#     'Dishsoap': 33,
#     'TL grea': 32,
#     'wilf': 23,
#     'TOR Relic': 29,
#     'TOR Rereplay': 32,
#     'Aesah': 24,
#     'TOR MAIKEL': 32,
#     'ISG FRITZ': 20,
#     'VIT prestivent': 26,
#     'Ripple': 17,
#     'MILK': 31,
#     'TL PockyGom': 26,
#     'setsuko': 30,
#     'So bio': 34,
#     'Liquid ego': 32,
#     'Brucelolll': 29,
# ...
