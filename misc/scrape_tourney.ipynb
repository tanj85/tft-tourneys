# %%
import pandas as pd

def scrape_tourney(url):
    def getNum(df, r, c):
        # if df.iloc[r, c] == "":
        #     return None
        return int(''.join(filter(str.isdigit, df.iloc[r, c])))

    # url = 'https://docs.google.com/spreadsheets/d/e/2PACX-1vTiQ_4ZOw_C-Be28bVlqOVyxpQQIPd9v9ZHiuHzJf5oH4P_TCXslGPEIGxIs7obxe63vJZNAUWCr_H7/pubhtml#'
    dfs = pd.read_html(url)  # This reads all tables into a list of DataFrame objects

    df = dfs[0]

    player_cols = [i for i, col in enumerate(df.columns) if df[col].astype(str).str.contains("Name").any()]

    # Store game and lobby info as you find it for use with subsequent rows
    current_game = 0  # assuming the games are numbered sequentially in the DataFrame

    print(f"{'Player':<30} {'Score':<5} {'Lobby':<5} {'Game':<5}")

    print(player_cols)

    for col in player_cols:
        current_game += 1
        # print(current_game)
        current_lobby = None
        game_lobby_rows = df[df.iloc[:, col].str.contains("LOBBY", na=False, case=False)].index

        # print(game_lobby_rows)
        # print(df.iloc[:, col])

        for index, row in df.iterrows():
            if index in game_lobby_rows:
                # print(index, col)
                current_lobby = getNum(df, index, col)
            elif current_lobby is not None and pd.notna(df.iloc[index, col]) and pd.notna(df.iloc[index, col+1]):
                print(f"{df.iloc[index, col]:<30} {getNum(df, index, col+1):<5} {current_lobby:<5} {current_game:<5}")

# %%
scrape_tourney("https://docs.google.com/spreadsheets/d/e/2PACX-1vTcH1Dp7vLIYh5DfTdKK9EPmARsHCaF2_kBp_m9exBryOX1rVBqiN8MFiIqlzwpjheEs3vXYLKM_sCC/pubhtml#")
# Out:
# Player                         Score Lobby Game
# [2, 6, 10, 14, 18, 22]
# socks#eprod                    7     1     1
# TOR MAIKEL#eprod               8     1     1
# VIT prestivent#eprod           6     1     1
# Koala Esbelto#eprod            3     1     1
# Slooper#eprod                  2     1     1
# DavidAs#eprod                  1     1     1
# SpencerTFT#eprod               4     1     1
# Ripple#eprod                   5     1     1
# GK Bapzera#eprod               3     2     1
# Altenahue TFT#eprod            6     2     1
# setsuko#eprod                  1     2     1
# Filup#eprod                    8     2     1
# MILK#eprod                     7     2     1
# jdzielinski22#eprod            4     2     1
# Toddy#eprod                    2     2     1
# So bio#eprod                   5     2     1
# Dishsoap#eprod                 2     3     1
# TL PockyGom#eprod              6     3     1
# TOR Rereplay#eprod             8     3     1
# ...

# %%
import pandas as pd


def day_header_scrape(url, day, sheet,tournament_id=0):
    def getNum(df, r, c):
        # if df.iloc[r, c] == "":
        #     return None
        return int(''.join(filter(str.isdigit, df.iloc[r, c])))

    dfs = pd.read_html(url)  # This reads all tables into a list of DataFrame objects

    df = dfs[sheet]

    player_cols = [i for i, col in enumerate(df.columns) if (df[col].astype(str).str.contains("Name").any() and df[col].astype(str).str.contains(f"DAY {day}").any())]

    # Store game and lobby info as you find it for use with subsequent rows
    current_game = 0  # assuming the games are numbered sequentially in the DataFrame

    # print(f"{'Player':<30} {'Score':<5} {'Lobby':<5} {'Game':<5}")

    # print(player_cols)

    for col in player_cols:
        current_game += 1
        # print(current_game)
        current_lobby = None
        game_lobby_rows = df[df.iloc[:, col].str.contains("LOBBY", na=False, case=False)].index

        # print(game_lobby_rows)
        # print(df.iloc[:, col])

        for index, row in df.iterrows():
            if index in game_lobby_rows:
                # print(index, col)
                current_lobby = getNum(df, index, col)
            elif current_lobby is not None and pd.notna(df.iloc[index, col]) and pd.notna(df.iloc[index, col+1]):
                # insert_placement_data(df.iloc[index, col], 9-getNum(df, index, col+1), tournament_id, day, current_lobby, current_game)
                print(f"{df.iloc[index, col]:<30} {9-getNum(df, index, col+1):<5} {current_lobby:<5} {current_game:<5}")
    print(day, url, tournament_id, sheet)

day_header_scrape("https://docs.google.com/spreadsheets/d/e/2PACX-1vTB9zL9Dp3uXXDryaMptggjYP2DZ9otBwDcpuT8keYAHRy4IG5rwZIgwjpAJkStG-cbE8cNi9p4h5m1/pubhtml#", 1, 1)
# Out:
# FSK kubixon#eprod              7     1     1
# T1 Binteum#eprod               3     1     1
# KC Double61#eprod              6     1     1
# VSPO LiShao#eprod              5     1     1
# FNC Dishsoap#eprod             1     1     1
# TOR MAIKEL#eprod               8     1     1
# Asta1#eprod                    4     1     1
# JDG Flancy#eprod               2     1     1
# steppy#eprod                   5     2     1
# Clemou La Hagra#eprod          1     2     1
# JazLatte#eprod                 4     2     1
# TL PockyGom#eprod              6     2     1
# MIH Tarteman#eprod             7     2     1
# Dr OH#eprod                    3     2     1
# FNC wasian#eprod               2     2     1
# Bapzera#eprod                  8     2     1
# TL grea#eprod                  3     3     1
# socks#eprod                    2     3     1
# TianLong#eprod                 5     3     1
# ZETA title#eprod               8     3     1
# TBD Ningli#eprod               1     3     1
# ...

# %%
import pandas as pd
from sqlalchemy import create_engine, text

db_user = 'postgres'
db_password = 'tft!'
db_host = '127.0.0.1'
db_port = '5432'
db_name = 'tftourneys'
table_name = 'tbl_tournament_info'


# Create a connection to the PostgreSQL database
engine = create_engine(f'postgresql+psycopg2://{db_user}:{db_password}@{db_host}:{db_port}/{db_name}')


with engine.connect() as conn:
    conn.execute(
        text("""INSERT INTO tbl_placement_data (player_name, placement, tournament_id, day_num, lobby_id, game_num) 
                VALUES (:p_name, :place, :t_id, :day, :lobby, :game)"""),
        {'p_name':"skull_emoji", 'place': 7, 't_id': 67173566, 'day': 1, 'lobby': 1, 'game': 1}
    )
# Out:
# Running cells with 'Python 3.12.3' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
from sqlalchemy import create_engine, text
import psycopg2
import datetime
import hash_tournaments
import re
import copy



def filter_prize_pool_table_rows(tag):
    return tag.has_attr('class') and 'csstable-widget-row' in tag['class'] and 'prizepooltable-header' not in tag['class'] and 'ppt-toggle-expand' not in tag['class']

# Database connection parameters
dbname = "tftourneys"
user = "postgres"
password = "tft!"
host = "127.0.0.1"
port = '5432'

# Connect to the PostgreSQL database
engine = create_engine(f'postgresql+psycopg2://{user}:{password}@{host}:{port}/{dbname}')


with engine.connect() as conn:
    
    result = conn.execute(
        text("""
    SELECT tournament_id, liquipedia_link, num_participants FROM tbl_liquipedia_tournaments order by random() LIMIT 10;
    """)
    )

urls = []
tournament_ids = []

with engine.connect() as conn:

    for row in result:
        result2 = conn.execute(text(f"SELECT COUNT(tournament_id) from tbl_final_standings WHERE tournament_id={row[0]};"))
        if int(result2.first()[0]) >= int((row[2]if row[2] else 0)/2):
            print(f"skipped tournamnet {row[0]} bc already in")
            continue
        tournament_ids.append(row[0])
        urls.append(row[1])
        print(row[1])

for i in range(len(urls)):

    url = urls[i]
    tournament_id = tournament_ids[i]

    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')

    prize_pool_table = soup.find('div', class_ = 'prizepooltable')

    rows = prize_pool_table.find_all(filter_prize_pool_table_rows)

    player_standings = []

    for row in rows:
        player_stats = {}


        player_stats['id'] = tournament_id

        player_stats['link'] = url

        player_stats['prize'] = '$0'

        possible_div_texts = [x.text.strip() if x.text else "" for x in row.find_all('div', class_ = 'csstable-widget-cell')]

        for txt in possible_div_texts:
            if '$' in txt:
                player_stats['prize'] = txt

        player_stats['place'] = row.find('div', class_ = 'prizepooltable-place').text

        # seems like sometimes can have DQ
        if not any(char.isdigit() for char in player_stats['place']):
            print(player_stats['place'])
            continue

        if '-' in player_stats['place']:
            stats = player_stats['place'].split('-')

            start_place = int(''.join(re.findall(r'\d+', stats[0])))
            end_place = int(''.join(re.findall(r'\d+', stats[1])))

            all_names = row.find_all('span', class_ = 'name')

            for j in range(end_place - start_place + 1):
                player_stats['place'] = start_place + j

                if (j < len(all_names)):
                    player_stats['name'] = all_names[j].text
                    player_stats['name'] = player_stats['name'].strip() if player_stats['name'] else None
                else:
                    player_stats['name'] = ""

                player_standings.append(copy.deepcopy(player_stats))
                # print(player_stats, start_place, end_place, j)

        else:
            player_stats['place'] = int(''.join(re.findall(r'\d+', player_stats['place']))) if player_stats['place'] else None
        
            player_stats['name'] = row.find('span', class_ = 'name').text
            player_stats['name'] = player_stats['name'].strip() if player_stats['name'] else None

            player_standings.append(player_stats)

    sql_query = text(f"""
            INSERT INTO tbl_final_standings (
                tournament_id, player_name, overall_place, prize
            ) VALUES (
                :tournament_id, :player_name, :overall_place, :prize
            )
        """)


    for ps in player_standings:
        parameters = {
            "tournament_id": ps['id'],
            "player_name": ps['name'],
            "overall_place": ps['place'],
            "prize": ps['prize']
        }
        
        with engine.connect() as conn:
            transaction = conn.begin()
            try:
                # Execute the query with parameters
                conn.execute(sql_query, parameters)
                transaction.commit()
            except Exception as e:
                print(f"Failed to add, probably bc duplicate tournament id [{ps['id']}]")
                transaction.rollback()
    print(f"added tourney {ps['id']}")
# Out:
# https://liquipedia.net/tft/Gizmos_%26_Gadgets/North_America/Piltover_Cup
# https://liquipedia.net/tft/Fates/Latin_America/Finals
# https://liquipedia.net/tft/TOC_1/Finals
# https://liquipedia.net/tft/Remix_Rumble/SEA/Vietnam/Community_Tournament/3
# https://liquipedia.net/tft/Inkborn_Fables/Americas/Tacticians_Cup/1
# https://liquipedia.net/tft/Remix_Rumble/Oceania/Qiyana_Open_Qualifier
# https://liquipedia.net/tft/Rising_Legends/Dragonlands/Golden_Spatula_Cup/3
# https://liquipedia.net/tft/Fates/North_America/Challenger_Series/1
# https://liquipedia.net/tft/ProLegends/2024/Stage_1/Open_Qualifier/1
# https://liquipedia.net/tft/Inkborn_Fables/Tacticians_Crown/CN_Qualifier
# added tourney 1023080
# added tourney 77726006
# added tourney 93307187
# added tourney 8872392
# added tourney 95145095
# added tourney 76510635
# added tourney 71183718
# added tourney 8403143
# added tourney 97997514
# added tourney 78431906

# %%
import requests
from bs4 import BeautifulSoup
from sqlalchemy import create_engine, text

dbname = "tftourneys"
user = "postgres"
password = "tft!"
host = "127.0.0.1"
port = '5432'

# Connect to the PostgreSQL database
engine = create_engine(f'postgresql+psycopg2://{user}:{password}@{host}:{port}/{dbname}')

url = "https://docs.google.com/spreadsheets/d/e/2PACX-1vSLAC6-CzsmALuUZ1WZgriDN-xL5zUnbSbAwQ1gEXSZzvYZqeA_QfZUQ5LdqB0Q136rS-kntfHjwZh4/pubhtml#"

response = requests.get(url)
html_content = response.text

soup = BeautifulSoup(html_content, 'html.parser')
tabs = soup.find_all('li', id=lambda value: value and value.startswith('sheet-button'))

# Extract sheet names and IDs
sheets = []
for tab in tabs:
    sheet_name = tab.find('a').text.strip()
    sheets.append(sheet_name)

sheets

result = conn.execute(
            text("SELECT link,day,sheet_index, updated_flag FROM tbl_tournament_info WHERE id = :t_id"),
            {'t_id': tournament_id}
        )

urls = []
days = []
sheet_indices = [] 
updated = []
        
# Iterate through the result set a single time
for row in result:
    urls.append(row[0])       # Access by column name for clarity
    days.append(row[1])
    sheet_indices.append(row[2]) 
    updated.append(row[3])
# Out:
# ['Tactician Trials Day 2 Lobbies',
#  'Tactician Trials Day 2 Standings',
#  'Tactician Trials Day 2 Waitlist',
#  'Tactician Trials Day 1 Lobbies',
#  'Tactician Trials Day 1 Standings',
#  'Event Info']

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
from sqlalchemy import create_engine, text
import psycopg2
import datetime
import hash_tournaments
import re
import copy

url = 'https://docs.google.com/spreadsheets/d/1c05xQh8tiKsup5O9SDB8MdAPShebc3y4EMgEUaX_GMI/pubhtml'

dfs = pd.read_html(url)  # This reads all tables into a list of DataFrame objects

df = dfs[0]

player_cols = [i for i, col in enumerate(df.columns) if df[col].astype(str).str.contains("Name").any()]

game_cols = [i for i, col in enumerate(df.columns) if df[col].astype(str).str.contains("Round").any()]

scraped = 0

current_game = 0
# print(df)
num_player_rows = int(pd.to_numeric(df.iloc[:, 1], errors='coerce').max())
print(num_player_rows)

for col in game_cols:
    current_game += 1
    for i in range(num_player_rows):
        print(df.iloc[i+1, player_cols[0]], "|", df.iloc[i, col])
        scraped += insert_placement_data(df.iloc[i+1, player_cols[0]], 9-int(df.iloc[i, col]), tournament_id, day, current_lobby, current_game)

# for col in player_cols:
#     current_game += 1
#     # print(current_game)
#     current_lobby = None
#     game_lobby_rows = df[df.iloc[:, col].str.contains("LOBBY", na=False, case=False)].index

#     # print(game_lobby_rows)
#     # print(df.iloc[:, col])

#     for index, row in df.iterrows():
#         if index in game_lobby_rows:
#             # print(index, col)
#             current_lobby = getNum(df, index, col)
#         elif current_lobby is not None and pd.notna(df.iloc[index, col]) and pd.notna(df.iloc[index, col+1]):
#             scraped += insert_placement_data(df.iloc[index, col], 9-getNum(df, index, col+1), tournament_id, day, current_lobby, current_game)
#             # print(f"{df.iloc[index, col]:<30} {9-getNum(df, index, col+1):<5} {current_lobby:<5} {current_game:<5}")
# print(f"scraped tourney {tournament_id}, day {day} and updated {scraped} entries")
# Out:
# 168
# ZETA Taro#TFTU | Round 1
# chocotomato#JP1 | 8
# Huey Dewey Louie#OCE | 8
# æ¸éMoGG#TW2 | 7
# ã¬ãä¸¸#JP1 | 7
# Latteåæ¿éµ#Latte | 8
# shimapen#tft | 6
# ãããã¾ã©ã#JP1 | 8
# å¦³å®¶ç¥ç¥ ççµ¦ä½ ä½#TW2 | 4
# éµä¹ç¡¬æ²¼#TW2 | 7
# ZETA kes#TFT | 5
# what can I do#HKJM9 | 6
# k3ketamine#OCE | 5
# riri#3390 | 8
# terrytft#ttv | 7
# å¶ç¾æä½ #5194 | 6
# GrandEscape#0908 | 8
# ãã«è»#JP1 | 7
# ã¨ã¬ãã¼ãªã®æ«#mori | 7
# ZETA title#3331 | 7
# ã¶ãªã¬ãå¤§ä¼#50077 | 8
# ç¹KOOMè²#TW2 | 8
# kuran0827#JP1 | 3
# HeartSeeker#TW2 | 6
# m1zono#5140 | 8
# Kå¯¶å¯¶çæ°£äº#1234 | 8
# Eggy#Woach | 7
# æ´æ´æ´æ´æ´å¾æ#0502 | 8
# æ·çOwoå°ç#æ·çç | 6
# å¤©æ´Haruru#TW2 | 2
# kizichan#65536 | 5
# Boogiezone#OCE | 5
# MagicElephant#SG2 | 2
# Little Timmy#kid | 7
# hinekura#JP1 | 5
# tarakoman#0120 | 6
# YTNye#TW2 | 1
# è±è¼ªä»å¼é»è¼ª#1204 | 3
# DonnieG#4355 | 7
# calze6#OCE | 7
# ZETA KAITO#716 | 6
# ç¶å¸ç¡ç³ç¶ #5084 | 4
# ...
