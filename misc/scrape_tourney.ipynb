# %%
import pandas as pd

def scrape_tourney(url):
    def getNum(df, r, c):
        return int(''.join(filter(str.isdigit, df.iloc[r, c])))

    # url = 'https://docs.google.com/spreadsheets/d/e/2PACX-1vTiQ_4ZOw_C-Be28bVlqOVyxpQQIPd9v9ZHiuHzJf5oH4P_TCXslGPEIGxIs7obxe63vJZNAUWCr_H7/pubhtml#'
    dfs = pd.read_html(url)  # This reads all tables into a list of DataFrame objects

    df = dfs[0]

    player_cols = [i for i, col in enumerate(df.columns) if df[col].astype(str).str.contains("Name").any()]

    # Store game and lobby info as you find it for use with subsequent rows
    current_game = 0  # assuming the games are numbered sequentially in the DataFrame

    print(f"{'Player':<30} {'Score':<5} {'Lobby':<5} {'Game':<5}")

    print(player_cols)

    for col in player_cols:
        current_game += 1
        # print(current_game)
        current_lobby = None
        game_lobby_rows = df[df.iloc[:, col].str.contains("LOBBY", na=False, case=False)].index

        # print(game_lobby_rows)
        # print(df.iloc[:, col])

        for index, row in df.iterrows():
            if index in game_lobby_rows:
                # print(index, col)
                current_lobby = getNum(df, index, col)
            elif current_lobby is not None and pd.notna(df.iloc[index, col]):
                print(f"{df.iloc[index, col]:<30} {getNum(df, index, col+1):<5} {current_lobby:<5} {current_game:<5}")

# %%
scrape_tourney("https://docs.google.com/spreadsheets/d/e/2PACX-1vQjodoBBeSzVtRFp6-nRsQYkShZjJamVwCDrwXDzK8BA1nrOa594V0zRyvP2HDOdST-NyrIsNVbLy1K/pubhtml")
# Out:
# Player                         Score Lobby Game
# [2, 6, 10, 14, 18, 22, 26]
# So bio#eprod                   1     1     1
# prestivent#eprod               8     1     1
# seihunkim#eprod                7     1     1
# ISG FRITZ#eprod                6     1     1
# wilf#eprod                     4     1     1
# Sealkun Mbappe#eprod           2     1     1
# Liquid ego#eprod               5     1     1
# Ayy Rick#eprod                 3     1     1
# thybeaster#eprod               2     2     1
# Cambulee#eprod                 5     2     1
# LilTop#eprod                   3     2     1
# Lab018biribiri#eprod           1     2     1
# Altenahue TFT#eprod            7     2     1
# CookiesOP#eprod                6     2     1
# Ciulla#eprod                   4     2     1
# GK Bapzera#eprod               8     2     1
# Fan The QiQi#eprod             4     3     1
# FNC wasian#eprod               2     3     1
# Brucelolll#eprod               5     3     1
# SALAD#eprod                    1     3     1
# SOJU setsuko#eprod             7     3     1
# ISG MAIKEL#eprod               6     3     1
# Darevitt#eprod                 3     3     1
# socks#eprod                    8     3     1
# Toddy#eprod                    4     4     1
# Ripple#eprod                   3     4     1
# Slooper#eprod                  5     4     1
# TexSummers#eprod               7     4     1
# Stellar Minhee#eprod           6     4     1
# TL Rereplay#eprod              2     4     1
# TSphere#eprod                  8     4     1
# Ramblinnn#eprod                1     4     1
# So bio#eprod                   8     1     2
# prestivent#eprod               7     1     2
# seihunkim#eprod                5     1     2
# ISG FRITZ#eprod                4     1     2
# wilf#eprod                     3     1     2
# Sealkun Mbappe#eprod           1     1     2
# Liquid ego#eprod               2     1     2
# Ayy Rick#eprod                 6     1     2
# thybeaster#eprod               4     2     2
# Cambulee#eprod                 2     2     2
# LilTop#eprod                   1     2     2
# Lab018biribiri#eprod           7     2     2
# Altenahue TFT#eprod            6     2     2
# CookiesOP#eprod                3     2     2
# Ciulla#eprod                   5     2     2
# GK Bapzera#eprod               8     2     2
# Fan The QiQi#eprod             5     3     2
# FNC wasian#eprod               1     3     2
# Brucelolll#eprod               4     3     2
# SALAD#eprod                    2     3     2
# SOJU setsuko#eprod             7     3     2
# ISG MAIKEL#eprod               8     3     2
# Darevitt#eprod                 6     3     2
# socks#eprod                    3     3     2
# Toddy#eprod                    2     4     2
# Ripple#eprod                   4     4     2
# Slooper#eprod                  3     4     2
# TexSummers#eprod               7     4     2
# Stellar Minhee#eprod           5     4     2
# TL Rereplay#eprod              8     4     2
# TSphere#eprod                  6     4     2
# Ramblinnn#eprod                1     4     2
# GK Bapzera#eprod               1     1     3
# seihunkim#eprod                5     1     3
# Stellar Minhee#eprod           8     1     3
# Darevitt#eprod                 4     1     3
# Ayy Rick#eprod                 2     1     3
# wilf#eprod                     6     1     3
# Liquid ego#eprod               7     1     3
# Ramblinnn#eprod                3     1     3
# prestivent#eprod               6     2     3
# Altenahue TFT#eprod            2     2     3
# socks#eprod                    7     2     3
# Brucelolll#eprod               5     2     3
# CookiesOP#eprod                1     2     3
# Cambulee#eprod                 8     2     3
# thybeaster#eprod               3     2     3
# Sealkun Mbappe#eprod           4     2     3
# TexSummers#eprod               7     3     3
# TSphere#eprod                  2     3     3
# TL Rereplay#eprod              1     3     3
# Fan The QiQi#eprod             3     3     3
# Ciulla#eprod                   6     3     3
# Ripple#eprod                   5     3     3
# Toddy#eprod                    8     3     3
# SALAD#eprod                    4     3     3
# ISG MAIKEL#eprod               2     4     3
# SOJU setsuko#eprod             7     4     3
# ISG FRITZ#eprod                4     4     3
# So bio#eprod                   6     4     3
# Lab018biribiri#eprod           5     4     3
# Slooper#eprod                  1     4     3
# LilTop#eprod                   3     4     3
# FNC wasian#eprod               8     4     3
# GK Bapzera#eprod               6     1     4
# seihunkim#eprod                2     1     4
# Stellar Minhee#eprod           1     1     4
# Darevitt#eprod                 3     1     4
# Ayy Rick#eprod                 7     1     4
# wilf#eprod                     5     1     4
# Liquid ego#eprod               4     1     4
# Ramblinnn#eprod                8     1     4
# prestivent#eprod               8     2     4
# Altenahue TFT#eprod            5     2     4
# socks#eprod                    6     2     4
# Brucelolll#eprod               3     2     4
# CookiesOP#eprod                7     2     4
# Cambulee#eprod                 4     2     4
# thybeaster#eprod               2     2     4
# Sealkun Mbappe#eprod           1     2     4
# TexSummers#eprod               4     3     4
# TSphere#eprod                  2     3     4
# TL Rereplay#eprod              5     3     4
# Fan The QiQi#eprod             1     3     4
# Ciulla#eprod                   6     3     4
# Ripple#eprod                   8     3     4
# Toddy#eprod                    3     3     4
# SALAD#eprod                    7     3     4
# ISG MAIKEL#eprod               3     4     4
# SOJU setsuko#eprod             5     4     4
# ISG FRITZ#eprod                1     4     4
# So bio#eprod                   2     4     4
# Lab018biribiri#eprod           4     4     4
# Slooper#eprod                  6     4     4
# LilTop#eprod                   7     4     4
# FNC wasian#eprod               8     4     4
# prestivent#eprod               2     1     5
# Altenahue TFT#eprod            5     1     5
# Stellar Minhee#eprod           1     1     5
# Liquid ego#eprod               6     1     5
# TSphere#eprod                  4     1     5
# Darevitt#eprod                 8     1     5
# ISG FRITZ#eprod                3     1     5
# Sealkun Mbappe#eprod           7     1     5
# SOJU setsuko#eprod             6     2     5
# Ripple#eprod                   4     2     5
# seihunkim#eprod                5     2     5
# Ayy Rick#eprod                 1     2     5
# So bio#eprod                   7     2     5
# TL Rereplay#eprod              8     2     5
# Slooper#eprod                  2     2     5
# thybeaster#eprod               3     2     5
# TexSummers#eprod               4     3     5
# Ciulla#eprod                   3     3     5
# FNC wasian#eprod               7     3     5
# wilf#eprod                     6     3     5
# Toddy#eprod                    2     3     5
# CookiesOP#eprod                5     3     5
# SALAD#eprod                    8     3     5
# Ramblinnn#eprod                1     3     5
# socks#eprod                    6     4     5
# GK Bapzera#eprod               1     4     5
# Cambulee#eprod                 5     4     5
# ISG MAIKEL#eprod               2     4     5
# Lab018biribiri#eprod           3     4     5
# Brucelolll#eprod               7     4     5
# LilTop#eprod                   4     4     5
# Fan The QiQi#eprod             8     4     5
# SOJU setsuko#eprod             2     1     6
# TexSummers#eprod               4     1     6
# FNC wasian#eprod               6     1     6
# Ripple#eprod                   7     1     6
# TL Rereplay#eprod              8     1     6
# wilf#eprod                     5     1     6
# GK Bapzera#eprod               3     1     6
# Liquid ego#eprod               1     1     6
# prestivent#eprod               4     2     6
# socks#eprod                    7     2     6
# Altenahue TFT#eprod            6     2     6
# So bio#eprod                   8     2     6
# seihunkim#eprod                2     2     6
# Cambulee#eprod                 5     2     6
# Brucelolll#eprod               3     2     6
# Darevitt#eprod                 1     2     6
# socks#eprod                    5     1     7
# prestivent#eprod               6     1     7
# SOJU setsuko#eprod             2     1     7
# TexSummers#eprod               4     1     7
# So bio#eprod                   8     1     7
# TL Rereplay#eprod              1     1     7
# FNC wasian#eprod               3     1     7
# Ripple#eprod                   7     1     7

# %%
import pandas as pd
from sqlalchemy import create_engine, text

db_user = 'postgres'
db_password = 'tft!'
db_host = '68.183.150.147'
db_port = '5432'
db_name = 'tftourneys'
table_name = 'tbl_tournament_info'


# Create a connection to the PostgreSQL database
engine = create_engine(f'postgresql+psycopg2://{db_user}:{db_password}@{db_host}:{db_port}/{db_name}')


with engine.connect() as conn:
    conn.execute(
        text("""INSERT INTO tbl_placement_data (player_name, placement, tournament_id, day_num, lobby_id, game_num) 
                VALUES (:p_name, :place, :t_id, :day, :lobby, :game)"""),
        {'p_name':"piss", 'place': 7, 't_id': 67173566, 'day': 1, 'lobby': 1, 'game': 1}
    )
# Out:
# Running cells with 'Python 3.12.3' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/bin/python3 -m pip install ipykernel -U --user --force-reinstall'
