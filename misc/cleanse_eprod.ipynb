# %%
import psycopg2
from sqlalchemy import create_engine, text
import os

# Database connection parameters
dbname = os.getenv("DB_NAME")
user = os.getenv("DB_USER")
password = os.getenv("DB_PASSWORD")
host = os.getenv("DB_HOST")
port = '5432'

# Connect to the PostgreSQL database
engine = create_engine(f'postgresql+psycopg2://{user}:{password}@{host}:{port}/{dbname}')

# Set up the database query to retrieve URLs for the given tournament ID
with engine.connect() as conn:
    
    transaction = conn.begin()
    conn.execute(
        text("""
    UPDATE tbl_placement_data
    SET player_name = SUBSTRING(player_name, 1, LENGTH(player_name) - 6)
    WHERE LOWER(player_name) LIKE '%#eprod';
    """)
    )
    transaction.commit()

# %%
import psycopg2
from sqlalchemy import create_engine, text
from Levenshtein import distance
import hashlib


def hash_player_name(name, seed=0):
    # Create a hash object using MD5, including the seed in the hash input for collision resolution
    hash_input = f"{name}-{seed}".encode()
    hash_object = hashlib.md5(hash_input)

    # Convert the hash to an 8-digit number
    eight_digit_hash = int(hash_object.hexdigest(), 16) % 100000000
    return int(eight_digit_hash)

def similar_names(name1, name2):

    if (len(name1.split(" ")) > len(name2.split(" "))):
        longer_name, other = name1, name2
    else:
        longer_name, other = name2, name1

    longer_name_split = longer_name.split(" ")

    if (len(longer_name_split) > 1):

        # print(longer_name_split, other)

        tag_index = 1

        # in the case where a team tag has a space between them...

        if longer_name_split[1].isupper():
            tag_index = 2

        no_tag = " ".join(longer_name_split[tag_index:len(longer_name_split)])

        # print(no_tag)

        if no_tag.lower() in other.lower() and len(no_tag) > 3:
            return True
    
    if len(name1) > 3 and len(name2) > 3 and (name1.lower() in name2.lower() or name2.lower() in name1.lower()):
        return True

    if distance(name1.lower(), name2.lower()) < 2 and (len(name1) >= 6 or len(name2) >=6):
        return True

    return False

# Database connection parameters
dbname = os.getenv("DB_NAME")
user = os.getenv("DB_USER")
password = os.getenv("DB_PASSWORD")
host = os.getenv("DB_HOST")
port = '5432'

# Connect to the PostgreSQL database
engine = create_engine(f'postgresql+psycopg2://{user}:{password}@{host}:{port}/{dbname}')

names = set()

already_there = set()

# Set up the database query to retrieve URLs for the given tournament ID
with engine.connect() as conn:
    
    result = conn.execute(
        text("""
    SELECT DISTINCT player_name FROM tbl_placement_data;
    """)
    )

# Set up the database query to retrieve URLs for the given tournament ID
with engine.connect() as conn:
    
    result2 = conn.execute(
        text("""
    SELECT DISTINCT player_name FROM tbl_final_standings;
    """)
    )

for row in result:
    names.add(row[0])

for row in result2:
    names.add(row[0])

names = list(names)

groups = {}

with engine.connect() as conn:
    
    result = conn.execute(
        text("""
    SELECT DISTINCT player_name, player_id FROM tbl_player_aliases;
    """)
    )

for row in result:
    already_there.add(row[0])
    p_id = int(row[1])

    if p_id in groups:
        groups[p_id].append(row[0])
    else:
        groups[p_id] = [row[0]]

print(groups)
print(already_there)


for name in names:
    name = name.replace('#eprod', '')
    if name in already_there:
        continue

    found_group = False
    for key, group_names in groups.items():
        if any(similar_names(name, existing_name) for existing_name in group_names):
            groups[key].append(name)
            found_group = True
            break

    if not found_group:
        seed = 0
        hash = hash_player_name(name, seed)
        while hash in groups.keys():
            print(name, groups[hash])
            seed += 1
            hash = hash_player_name(name, seed)
        groups[hash] = [name]

verify = []
        
with engine.connect() as conn:

    transaction = conn.begin()
    for k, v in groups.items():
        num_new_in_bucket = 0
        for name in v:
            if name in already_there:
                continue
            
            num_new_in_bucket += 1 
            query = f"""INSERT INTO tbl_player_aliases (player_name, player_id) 
                        VALUES ('{name}',{k});"""
            conn.execute(
                text(query)
            )
        if num_new_in_bucket > 0 and len(v) > 1:
            verify.append(v)
    transaction.commit()
        

verify
# Out:
# {41081567: ['Viktoker'], 67944654: ['Durkzera'], 31449829: ['Eusouolucas', 'eusouolucas', 'eusouolucas#eprod'], 31399259: ['Dr OH'], 69439183: ['KiBi'], 34175457: ['Koala Esbelto#eprod', 'Koala Esbelto'], 15252658: ['brikstn', 'Briks'], 73030110: ['stopteqh'], 99007395: ['ILikeHoboes'], 54858463: ['Quinho'], 66730554: ['Shawn'], 97832094: ['notrpion'], 66232112: ['LiuLi'], 15300237: ['prestivent', 'Prestivent', 'prestivent#eprod', 'VIT prestivent'], 74726477: ['Mistborn', 'Mistborn#eprod'], 83939924: ['小风很帅'], 41191331: ['MSI PSik'], 18771370: ['TSM enaek'], 64059200: ['TexSummers#eprod', 'TexSummers'], 10135535: ['ISG MAIKEL#eprod', 'ISG Maikel', 'MAIKEL', 'ISG MAIKEL'], 48552254: ['Zanlo'], 1373742: ['milala#eprod', 'FNC milala', 'milala'], 47393839: ['TL Rereplay', 'Rereplay', 'Liquid Rereplay#eprod', 'TOR Rereplay', 'Liquid Rereplay'], 73041350: ['Salamander145'], 91906293: ['bertasaurus'], 19446606: ['Stoneweaver'], 85805531: ['KitingisHard'], 59175963: ['Shener Shên'], 89127326: ['Barney', 'Lab 010 Barney#eprod', 'Lab 010 Barney'], 31593866: ['INF HR SuperPino#eprod', 'INF HR SuperPino', 'INF HR Pino', 'SuperPino'], 13096248: ['PestControl'], 9770944: ['Black Wizard'], 56157966: ['moonify'], 66006079: ['Dữ VN'], 87905577: ['ll ZeuZ ll'], 64704083: ['nhân tâm'], 50886611: ['The Madge Genius'], 20022872: ['Neonify'], 34690713: ['Shinri'], 78647039: ['Darth Nub', 'Darth Nub#eprod'], 3930687: ['Roontonzorg', 'Roontonzorg#eprod'], 76719749: ['MonuVo'], 95536975: ['omurice'], 35014403: ['LiShao', 'VSPO LiShao'], 5072863: ['LilTop'], 49039140: ['vipi'], 29388006: ['RedLotusBR'], 34962837: ['AYSELGİTBAŞIMDAN'], 65227226: ['paj'], 95001319: ['Liptus'], 82491627: ['salty'], 32542287: ['Snoodyboo'], 2716447: ['Hisoka', 'Hisokalol'], 46789141: ['WeiFengC'], 41889077: ['DaanSilvaOFC'], 69490153: ['Dahni'], 11841995: ['Velayy'], 49404578: ['Kezman'], 33644629: ['Arthur Fleck'], 7209712: ['Tropical'], 41818846: ['AsianGamer5'], 37940927: ['Mathze'], 71919866: ['Fizz', 'MK Fizz#eprod', 'MK Fizz'], 67708254: ['Hymn'], 15682541: ['YoungPlum13'], 50343287: ['MeanMisterKien', 'MeanMisterKien#eprod'], 11789340: ['Rubic'], 236436: ['DongGeul'], 45267557: ['Shirazu'], 25903505: ['Shianetto'], 30217364: ['AiKooN'], 79413926: ['Kageros'], 71880193: ['BeanStalking'], 67724358: ['Alaycı Kuş'], 56633656: ['bambi255'], 5531390: ['Icedrop'], 5527728: ['wasianiverson#eprod', 'wasianiverson', 'FNC wasian'], 6657445: ['lupius'], 85718905: ['Sea'], 51460787: ['CheckMate'], 31576167: ['xandeeea'], 71697138: ['JosueDeleted', 'JosueDeleted#eprod'], 75807736: ['Alperen'], 88060598: ['kiri', 'Kiriusaion'], 60482545: ['INF HR Relic', 'INF HR Relic#eprod', 'TOR Relic', 'Relic'], 98937419: ['PasDeBol'], 27993639: ['MismatchedSocks', 'socks', 'Mismatched Socks', 'MismatchedSocks#eprod'], 33331160: ['lallana'], 91651412: ['Kindrd süt dilim'], 52539418: ['madmaddren'], 74349895: ['darkest1903', 'darkest'], 56949140: ['HanXixng'], 18884958: ['o153580'], 97726925: ['mikelololol1'], 81919075: ['iSexyHugoBabyGod'], 72875476: ['zoe only champ'], 56812747: ['wilf', 'wilf#eprod'], 43002724: ['Hugo'], 57794721: ['Dumith'], 51715436: ['Pythrasse'], 54246005: ['TG Shooter'], 27635346: ['Endrick te amo'], 79038099: ['vclf', 'GK vclf', 'vclf#eprod'], 44606299: ['Aletheides'], 5607984: ['Sassi'], 19998701: ['thybeaster'], 94220234: ['Ningli3z', 'TBD Ningli'], 40968768: ['peach'], 86150719: ['Agony1'], 64632510: ['DogS'], 78502757: ['Lab 02 Dinodan'], 42025048: ['leofloresdiscor#eprod', 'leofloresdiscor'], 52537574: ['Highlight Reel', 'Highlight'], 47751860: ['Anads'], 20707702: ['HighPikachu'], 41321881: ['Geolo69'], 77060157: ['koke'], 59854415: ['santa isnt real'], 45025219: ['ZENIA'], 16745454: ['Arrogante', 'Arrogànte'], 73172087: ['Wazapper'], 25168320: ['Altenahue TFT', 'Altenahue'], 61100725: ['Rayditz'], 31712013: ['Enzosexe'], 90617584: ['Berend'], 4185469: ['k3soju1', 'k3soju1#eprod'], 82534505: ['KingClouddy'], 34073133: ['Nareba', 'DUSK Nareba', 'DUSK Nareba#eprod'] ...
# {'Phoenixaa#eprod', 'Rose', 'robivankenob', 'AndreasRiis12', 'Miguel Arkjow', 'creamcrunchop', 'Shekeke', 'Lua Dipa', 'forzer0', 'ruichook', 'ACommonQuail', 'vclf#eprod', 'Lab003 Broseph', 'Cool Guy Dom', 'TianLong', 'INF HR Poison', 'gabymar10', 'momochan', 'MILK', 'NiihiI', 'Marcel P', 'paj', 'RFG JasonLin24', 'daCableguy', 'DaanSilvaOFC', 'omurjack', 'staralfur12', 'TORONTOTOKYO', 'huyg', 'MecLove', 'SOJU setsuko', 'FNC milala', 'OZGURGG', 'illectr0', 'FOUR BieuL', 'Zbrojson', 'Ankalli', 'h4udrauf', 'sERA', 'ItachiTFT#eprod', 'H P', 'MrEloengee', 'Finaldf', 'Makaroni', 'DUSK Nareba#eprod', 'PockyGom', 'Proof111', 'GuAo', 'i agr Jose', 'ARNOLD', 'kpk618', 'Khorge', 'Kranos', 'caoMei VG', 'Avi', 'annieconda', 'Wiru', '53414D TFT', 'EINS Sologesang', 'Dangk', 'JosueDeleted', 'cn werid TFT#eprod', 'ImSoFresh', 'inikoiniko', 'PiratesZ', 'Salamander145', 'iSexyHugoBabyGod', 'Eastern Europe', 'Briks', 'Zetrycanbiz61', 'Kontaksız', 'MoGG', 'aki_', 'Elia', 'Emdony', 'setsuko1', 'MXU', 'havalindahouse', 'Liptus', 'Pun#eprod', 'CFCDuuuuuuuuuuds', 'Sully TFT', 'Tanjo#eprod', 'milala', 'Massive Marsh', 'Glory123', 'Happy', 'lXaldin', 'Tjjuninho', 'PATRON ıs BACK', 'Adraug', 'MoistSierra', 'Black Wizard', 'FuryTank', 'JosueDeleted#eprod', 'TSM enaek', 'guubums', 'chickeneater02', 'STARKOV', 'Dawidowski', 'Fan The QiQi', 'Okabuloz', 'TayDAK', 'Neuro', 'Gabymar10', 'Zellera', 'Tacca TFT', 'ICE', 'phimas', 'Diejoubu', 'AlphaSpirit', 'iCopyKeane', 'JDG Flancy', 'Narkesh', 'Lugh no luck', 'Sm1gl3', 'shouhengg', 'Joshy', 'FORA Neuro', 'Liquid ego', 'DLGODOFDEATH', 'Syrian#eprod', 'CHINESE TRAPPER', 'Turtleoutofwater', 'Saintvicious', 'MoldBunny', 'Roontonzorg', 'İmparator', 'WenRou', 'Domango', 'Unhappy Meal', 'BomberJack007', 'Chorfs', 'DobZ', 'syz', 'Liquid SV', 'eyupsabrituncer', 'TuTuRoo', 'JazLatte', 'uknowSawyer', 'sesisa', 'w0og', 'xandeeea', 'setsuko1#eprod', 'France', 'Lorus', 'Geolo69', 'Allancar', 'thekrayc', 'Learning TFT', 'Uthenera', 'digastop69', 'Wombatz', 'Shirazu', 'Hotplate Black', 'RedLotusBR', 'mattblacktft91', 'kenko1504', 'Corkin de PTA', 'chessmage', 'QiQiuHenChen', 'Jamalzeralol', 'Ikajoh', 'Itachi', 'Tsmmaa', 'KC Double61', 'Goshayy', 'Bränk', 'DisGame2Ez', 'Bradini', 'Viktoker', 'T3MPEL', 'SealKun Mbappe#eprod', 'papercheeze', 'lili', 'Pythrasse', 'peach', 'Beta yc', 'TOR Relic', 'Tanjo', 'Ukko', 'robinsongz#eprod', 'DXN', 'Luqun', 'Wandertrieb', 'ymdn', 'Dr_OH', 'Broseph', 'Tolety', 'INF HR Relic#eprod', 'Twîstz', 'Ashayuni', 'Tomato', 'yuno', 'INF HR Rudyck', 'campislife20#eprod', 'Toddy', 'BeTo', 'Lelio', 'dink my oiter', 'Kalflo', 'Binteum', 'Aletheides', 'jie', 'frey', 'Ripple', 'Black Sheep', 'Kaiweng#eprod', 'angora', 'ISG FRITZ', 'ZETA title', 'MHStana', 'DUSKiagoraJose', 'Carelessd', 'Cat Mentality', 'prestivent#eprod', 'ronniestoppable', 'corville', 'rin', 'bio1uc', 'DeadlyCO2', 'DrDrunkestein', 'Mujjiwaraa', 'Sukesvs', 'Luke', 'Gzaga', 'Tarteman', 'TTV thekrayc', 'JNO Kahdei', 'Kennethhh', 'Prose', 'Inma', 'BeanStalking', 'Aanox', 'campislife20', 'Esinti Cafe', 'Ssang Yeop', 'PasDeBol', 'darkest', 'Pro StreamSniper', 'pannyandrew', 'Tanjiro', 'OutofToon', 'Canbizz', 'ISG MAIKEL#eprod', 'lallana', 'TSphere', 'DobZ#eprod', 'Tacca', 'Nik#eprod', 'WanJu', 'Zwn#eprod', 'gabsreal', 'So bio#eprod', 'm2att', 'Sunnyshore', 'Dishsoap', 'Woozzul', 'Droit', 'azadkrds', 'joaozin', 'apes in the trap', 'Lab039erinkuma', 'Deis1k', 'Goku#eprod', 'Dr OH', 'Dusuncesizlik', 'AceofSpades', 'Arrogante', 'SeekN7eak', '1 1 0 9', 'GEÇER', 'Pitzy', 'Arzoo', 'MismatchedSocks#eprod', 'O Shigueo', 'Souless', 'DRAGAOBAIANO69', 'yev', 'madmaddren', 'Meclove', 'xus0o', 'Ging', 'Kyivix', 'Sebunsheizu', 'imsofetch', 'RedColaBottle', 'ms gwen', 'Sincro', 'Colorful', 'Tarmyshane', 'Sett Calvo', 'flewaay', 'FORA Onlyteemo#eprod', 'BarryBadden', 'Typo Vampire', 'TACOBELL WIFI', 'eusouolucas#eprod', 'DDUDU', 'INF HR Poison#eprod', 'texita2', 'Closeer', 'Altenahue TFT', 'TrybleH', 'SacredNorriss', 'a1t1k', 'AYSELGİTBAŞIMDAN', 'YetişYaEren', 'Kap ...
# []

# %%
[x for x in list(groups.items()) if len(x[1]) > 1]
# Out:
# [(31449829, ['Eusouolucas', 'eusouolucas', 'eusouolucas#eprod']),
#  (34175457, ['Koala Esbelto#eprod', 'Koala Esbelto']),
#  (15252658, ['brikstn', 'Briks']),
#  (15300237,
#   ['prestivent', 'Prestivent', 'prestivent#eprod', 'VIT prestivent']),
#  (74726477, ['Mistborn', 'Mistborn#eprod']),
#  (64059200, ['TexSummers#eprod', 'TexSummers']),
#  (10135535, ['ISG MAIKEL#eprod', 'ISG Maikel', 'MAIKEL', 'ISG MAIKEL']),
#  (1373742, ['milala#eprod', 'FNC milala', 'milala']),
#  (47393839,
#   ['TL Rereplay',
#    'Rereplay',
#    'Liquid Rereplay#eprod',
#    'TOR Rereplay',
#    'Liquid Rereplay']),
#  (89127326, ['Barney', 'Lab 010 Barney#eprod', 'Lab 010 Barney']),
#  (31593866,
#   ['INF HR SuperPino#eprod', 'INF HR SuperPino', 'INF HR Pino', 'SuperPino']),
#  (78647039, ['Darth Nub', 'Darth Nub#eprod']),
#  (3930687, ['Roontonzorg', 'Roontonzorg#eprod']),
#  (35014403, ['LiShao', 'VSPO LiShao']),
#  (2716447, ['Hisoka', 'Hisokalol']),
#  (71919866, ['Fizz', 'MK Fizz#eprod', 'MK Fizz']),
#  (50343287, ['MeanMisterKien', 'MeanMisterKien#eprod']),
#  (5527728, ['wasianiverson#eprod', 'wasianiverson', 'FNC wasian']),
#  (71697138, ['JosueDeleted', 'JosueDeleted#eprod']),
#  (88060598, ['kiri', 'Kiriusaion']),
#  (60482545, ['INF HR Relic', 'INF HR Relic#eprod', 'TOR Relic', 'Relic']),
#  (27993639,
#   ['MismatchedSocks', 'socks', 'Mismatched Socks', 'MismatchedSocks#eprod']),
#  (74349895, ['darkest1903', 'darkest']),
#  (56812747, ['wilf', 'wilf#eprod']),
#  (79038099, ['vclf', 'GK vclf', 'vclf#eprod']),
#  (94220234, ['Ningli3z', 'TBD Ningli']),
#  (42025048, ['leofloresdiscor#eprod', 'leofloresdiscor']),
#  (52537574, ['Highlight Reel', 'Highlight']),
#  (16745454, ['Arrogante', 'Arrogànte']),
#  (25168320, ['Altenahue TFT', 'Altenahue']),
#  (4185469, ['k3soju1', 'k3soju1#eprod']),
#  (34073133, ['Nareba', 'DUSK Nareba', 'DUSK Nareba#eprod']),
#  (18542480, ['GGuthix', 'GGuthix#eprod', 'Gguthix']),
#  (93221102, ['Kaiweng#eprod', 'Kaiweng']),
#  (7395936, ['L3S Coco', 'L3Scoco']),
#  (53531043, ['TG Upsetmax#eprod', 'TG Upsetmax', 'Upsetmax']),
#  (94843903, ['robivankenob', 'robivankenob#eprod']),
#  (78198335, ['kubixon', 'FSK kubixon']),
#  (61422875, ['MecLove', 'Meclove', 'MecLove#eprod']),
#  (29049226, ['zzhcet#eprod', 'zzhcet']),
#  (25570816, ['dink my oiter#eprod', 'dink my oiter']),
#  (99432668, ['INF HR Rudyck', 'INF HR Rudyck#eprod', 'Rudyck']),
#  (87501644, ['phimas', 'phimas#eprod']),
#  (25853876, ['DETETIVE ALINE', 'Detetive Aline']),
#  (12893237, ['FORA Onlyteemo', 'Onlyteemo', 'FORA Onlyteemo#eprod']),
#  (89827472, ['Toddy#eprod', 'Toddy']),
#  (94772009, ['LadderSlayer#eprod', 'LadderSlayer']),
#  (92384638, ['JesusTeemo', 'JesusTeemo#eprod']),
#  (60380675,
#   ['sètsuko', 'SOJU setsuko', 'setsuko1#eprod', 'setsuko1', 'setsuko']),
#  (91277084, ['Sologesang', 'EINS Sologesang']),
#  (65134436, ['DLGODOFDEATH', 'DLGOD0FDEATH']),
#  (32953490, ['ViciuuSS#eprod', 'ViciuuSS']),
#  (52821891, ['DeliciousMilkGG', 'Milk Guy', 'MILK', 'Milk Guy#eprod']),
#  (39442765, ['caoMei VG', 'caoMei']),
#  (55417111, ['So bio', 'So bio#eprod']),
#  (38781691, ['k0nda1#eprod', 'k0nda1']),
#  (23127047, ['Goku', 'Goku#eprod']),
#  (87651887, ['Black Sheep#eprod', 'Black Sheep']),
#  (32544720, ['Liquid SV', 'Liquid SV#eprod']),
#  (53735694, ['Connerisme', 'Connerisme#eprod']),
#  (19117497, ['ego illusions', 'ego illusions#eprod']),
#  (59435853, ['Magarky', 'magarky1']),
#  (53265302, ['Kurumx#eprod', 'Kurumx']),
#  (28002550, ['Syrian', 'Syrian#eprod']),
#  (54530476, ['INF HR Hyper#eprod', 'INF HR Hyper', 'Hyper']),
#  (43069266, ['Lab 004 Rain#eprod', 'Rain', 'Lab 004 Rain']),
#  (94154485, ['DuduRMF', 'DDUDU', 'dudu']),
#  (80566850, ['Cupiditas', 'Cupiditas#eprod']),
#  (82753959, ['DUSK i agr Jose#eprod', 'i agr Jose', 'DUSK i agr Jose']),
#  (92055192, ['MEYOU#eprod', 'MEYOU']),
#  (48321885, ['FOUR vakio', 'FOUR vakio#eprod', 'vakio']),
#  (65477339, ['INF HR Poison', 'INF HR Poison#eprod', 'Poison']),
#  (88294036, ['yoohnTFT#eprod', 'yoohnTFT', 'yoohn']),
#  (19677080, ['kpk618', 'kpk618#eprod']),
#  (32155263, ['Arzoo', 'CST arzoo']),
#  (6233667, ['cn werid TFT#eprod', 'cn werid TFT', 'werid']),
#  (66216700, ['jdzielinski22', 'jdzielinski22#eprod']),
#  (48464841, ['gabymar10', 'Gabymar10']),
#  (45788176, ['Yushi', 'Yush']),
#  (84074049, ['Thun', 'stylethun95']),
#  (13409018, ['HighPana', 'HighPana#eprod']),
#  (57904488, ['TSphere#eprod', 'TSphere']),
#  (47121441, ['Marcel P1', 'Marcel P', 'MarcelP']),
#  (52048293, ['AI CE TOMA', 'AI CE TOMA#eprod']),
#  (36140255, ['JNO Kahdei', 'Kahdei']),
#  (54274152, ['Tanjo', 'Tanjo#eprod']),
#  (2856495, ['FORA Taliyent', 'Taliyent']),
#  (57675094, ['Cambulee', 'Cambulee#eprod']),
#  (87380072, ['FORA Bapzera#eprod', 'Bapzera', 'FORA Bapzera', 'GK Bapzera']),
#  (72404566, ['InvadersMD#eprod', 'InvadersMD']),
#  (57092726, ['TTV thekrayc#eprod', 'thekrayc', 'TTV thekrayc']),
#  (38944922, ['Sully TFT', 'Sully TFT#eprod', 'Sully']),
#  (89275687, ['rykomastery', 'Ryko']),
#  (38364604, ['FNC Kiyoon', 'Kiyoon']),
#  (9591235, ['Groxie', 'Groxie#eprod']),
#  (99645825,
#   ['TORONTO TOKYO#eprod',
#    'TORONTO TOKYO',
#    'TORONTOTOKYO#eprod',
#    'TORONTOTOKYO',
#    'TORONTOTOKYOTFT']),
#  (98348651, ['grea', 'TL grea', 'grea#eprod']),
#  (24524712, ['T1 Binteum', 'Binteum']),
#  (95265227, ['Slooper#eprod', 'Slooper']),
#  (79071072, ['Triple8s', 'Triple8s#eprod']),
#  (96921236, ['Xus0o', 'xus0o']),
#  (59697033, ['Bruhbruhbruh WHO', 'bruhbruhbruh']),
#  (82354990, ['tbone#eprod', 'tbone']),
#  (34485932, ['phura#eprod', 'phura']),
#  (99862408, ['Double61', 'KC Double61']),
#  (54269202, ['KC Canbizz', 'Canbizz']),
#  (96212203, ['bandit', 'bandit#eprod']),
#  (49412699, ['plumbum', 'plumbum#eprod']),
#  (8738123, ['DobZ', 'DobZ#eprod']),
#  (58485069, ['FRITZ#eprod', 'FRITZ', 'ISG FRITZ']),
#  (94913771, ['NiihiI#eprod', 'NiihiI']),
#  (56932882, ['Tacca TFT', 'CRG Tacca', 'Tacca']),
#  (67222730, ['Filup#eprod', 'Filup']),
#  (63079728,
#   ['Sealkun Mbappe',
#    'SealKun Mbappe',
#    'SealkunMbappe',
#    'SealKun Mbappe#eprod']),
#  (76659502, ['TBD LiTuChuan', 'LiTuChuan']),
#  (33110443, ['Cool Guy Dom#eprod', 'Cool Guy Dom']),
#  (39864278, ['xiao dian dian', 'xiao dian dian#eprod']),
#  (90827234, ['JDG Flancy', 'Flancy']),
#  (12224297, ['Cheche', 'ISG Cheche#eprod', 'ISG Cheche']),
#  (89887027, ['Lazuli', 'Lazuli#eprod']),
#  (89614069, ['FORA Cash', 'FORA Cash#eprod', 'Cash']),
#  (46592495, ['RYT Shaco', 'Shaco', 'RYT Shaco#eprod']),
#  (34088022, ['Phoenixaa#eprod', 'Phoenixaa']),
#  (15808909, ['Levin', 'Levi']),
#  (27811515, ['Copico', 'Copico#eprod']),
#  (86548266, ['evil one', 'FORA evil one']),
#  (99439453, ['DavidAs', 'David']),
#  (18018707, ['hsk the onlyone', 'hsk the onlyone#eprod']),
#  (16556367, ['Brucelolll', 'Brucelolll#eprod']),
#  (28902686, ['TL PockyGom', 'PockyGom']),
#  (99201566, ['60second', 'TM 60second']),
#  (97924839, ['robinsongz', 'robinsongz#eprod']),
#  (92492720, ['MattbLack', 'mattblacktft91']),
#  (19549918, ['MIH Tarteman', 'Tarteman', 'TarteMan']),
#  (94817577, ['Darvinism', 'Darvinism#eprod']),
#  (5326533, ['Aesah', 'Aesah#eprod']),
#  (30987072, ['PiratesZ', 'Pirate']),
#  (68476926, ['Ganga', 'Ganga#eprod']),
#  (49031716, ['illectr0', 'Illectro']),
#  (77458704, ['Neuro', 'FORA Neuro']),
#  (90569852, ['Swellertiger', 'SwellerTiger']),
#  (62741729, ['Carelessd', 'Carelessd#eprod']),
#  (77884674, ['Weklet#eprod', 'Weklet']),
#  (67779767, ['FNC Dishsoap', 'Dishsoap#eprod', 'Dishsoap']),
#  (62462580, ['Northern Europe', 'Eastern Europe']),
#  (32916600, ['tleyds', 'tleyds#eprod']),
#  (9231308, ['Broseph', 'Lab003 Broseph', 'Lab003 Broseph#eprod']),
#  (50866503, ['JukeYou#eprod', 'JukeYou']),
#  (89378295, ['casparwu#eprod', 'casparwu']),
#  (94798160, ['Autenticos#eprod', 'Autenticos']),
#  (86337162, ['Spencer', 'SpencerTFT', 'SpencerTFT#eprod']),
#  (13945082, ['mogumoguyummy#eprod', 'mogumoguyummy']),
#  (40909198, ['Arkjow', 'Miguel Arkjow#eprod', 'Miguel Arkjow']),
#  (26472673, ['campislife20', 'campislife20#eprod']),
#  (60566694, ['ItachiTFT#eprod', 'Itachi', 'ItachiTFT']),
#  (89259668, ['ms gwen#eprod', 'ms gwen']),
#  (2059392, ['INF HR SrCerdo', 'SrCerdo', 'INF HR SrCerdo#eprod']),
#  (7452180, ['Trebornac#eprod', 'Trebornac']),
#  (94871721, ['bossoskills', 'Bossoskills']),
#  (90456838, ['Pitzy', 'pitzy#eprod', 'pitzy']),
#  (75409583, ['Rakki Ryu', 'Rakki Ryu#eprod']),
#  (97517510, ['Aerodynamicks', 'Aerodynamicks#eprod']),
#  (34971509, ['erinkuma', 'Lab039erinkuma#eprod', 'Lab039erinkuma']),
#  (80917561, ['Stellar Minhee', 'Stellar Minhee#eprod']),
#  (98047871, ['Labl3r#eprod', 'Labl3r'])]

# %%
name = "Tacca TFT"
hash = hash_player_name(name, seed=0)

print(hash)

with engine.connect() as conn:
    
    result = conn.execute(
        text(f"""
    SELECT player_name, player_id FROM tbl_player_aliases where player_id={hash};
    """)
    )

for row in result:
    print(row[0], row[1])
# Out:
# 46528245
